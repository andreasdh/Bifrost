# %% [markdown]
# # Ukesoppgaver

# %% [markdown]
# Velg uke i menyen til venstre, eller bruk lenkene nedenfor.
#
# 1. {doc}`Uke 1 – Statistisk mekanikk og mikro–makro-sammenhengen <ukesoppgaver/uke_01__under_revision>`
# 2. {doc}`Uke 2 – Statistisk mekanikk, Boltzmann-fordelingen og Partisjonsfunskjonen <ukesoppgaver/uke_02_under_revision>`
