# %% [markdown]
# # Løsningsforslag

# %% [markdown]
# Velg uke i menyen til venstre, eller bruk lenkene nedenfor.
#
# 1. {doc}`Uke 1 – Statistisk mekanikk og mikro–makro-sammenhengen <losningsforslag/uke_01_under_revision_LF.ipynb>`
