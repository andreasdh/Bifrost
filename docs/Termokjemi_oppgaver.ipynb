# %% [markdown]
# ## Termokjemi - oppgaver
#
# ### Diskusjonsoppgaver
#
# **Hess lov**
#
# 1. Hva sier Hess lov?
#
# 2. Hvordan ville du satt opp uttrykket for entalpiendringen for følgende prosess ved hjelp av Hess lov?
#
# [bilde]
#
# **Entalpi**
#
# 1. Hva er entalpi og hvorfor er entalpi så nyttig i kjemi?
#
# 2. Hva er forskjellen på en endoterm og en eksoterm prosess og hvilken sammenheng har disse begrepene med fortegnet til entalpiendringen $\Delta H$?
#
# 3. Hvor kommer de tabulerte verdiene for dannelsesentalpier fra og hvorfor er de et nyttig verktøy?
#
# 4. Kan vi si noe om entalpiendring basert på de mikroskopiske egenskapene til stoffene som er involvert i prosessen? Bruk animasjonen under til å hjelpe deg i forklaringen din!

# %%
from IPython.display import HTML

with open("Simuleringer/eksoterm_endoterm_energigap.html", "r", encoding="utf-8") as f:
    html = f.read()

HTML(html)

# %% [markdown]
# 5. Kan du komme på noen eksempler fra labkursene du har tatt hvor du har måttet ta hensyn til entalpiendring?
#
# 6. I Organisk Kjemi 1 møtte dere på Wittig-reaksjonen! Under kan du se reaksjonslikningen for en typisk Wittig-reaksjon:
#
# ![Wittig-reaksjonen](bilder/wittig.png)
#
# a) Hva slags entalpiendring forventer du for denne reaksjonen? Hvorfor?
#
# b) Wittig-reaksjonen gjøres typisk ved $0 ^{\circ} C$ og i _tørt_ løsemiddel (vannfritt). Hva tror du ligger bak disse valgene?
#
#
# **Entropi**
#
# 1. Forklar kort og kvalitativt hva som kjennetegner entropien i de ulike aggregattilstandene gass, væske og fast stoff.
#
# 2. Hvordan kan aggregattilstander hjelpe oss å vurdere entropiendring i løpet av en prosess? Vurder entropiendring for følgende prosesser:
# a) Vann som koker
# b) Et løsemiddel kondenserer når det når en kjøler
# c) Et salt løses i vann
#
# 3. Vi har følgende kjemiske prosess: $A \longrightarrow$ B + C. Du trenger ikke tenke på aggregattilstander.
# a) Vurder kvalitativt entropiendringen du får fra prosessen.
# b) Hvordan forklarer du dette mikroskopisk? (Hint: Her kan du bruke lattice modell og Boltzmanns entropi i forklaringen din 😊)
#
# 4. Hva må vi passe spesielt på dersom vi blir bedt om å vurdere entropiendring for løsning av salter med små kationer som $Li^+$, $Mg^{2+}$ og $Al^{3+}$?
#
# 5. Bruk animasjonen til å forklare hvordan entropisk ugunstige prosesser allikevel overholder termodynamikkens 2. lov.

# %%
from IPython.display import HTML

with open("Simuleringer/entalpi-entropi-samspill.html", "r", encoding="utf-8") as f:
    html = f.read()

HTML(html)

# %% [markdown]
# **Gibbs fri energi og spontanitet**
#
# 1. Hvilket makroskopisk parameter må holdes konstant for at vi kan benytte oss av Gibbs fri energi?
#
# 2. Hva betyr det at en prosess er spontan? Hva er _endergone_ og _eksergone_ prosesser? Vil alle spontane prosesser skje raskt?
#
# 3. Hva mener vi med at en prosess er entalpisk eller entropisk drevet? Hva betyr dette matematisk i uttrykket for Gibbs fri energi?
#
# 4. Forbrenningen av etanol i luft skjer på følgende måte:
#
# $C_2H_5OH_{(l)} + 3 {O_2}_{(g)} \longrightarrow 2 {CO_2}_{(g)} + 3 H_2O_{(g)}$
#
# Og har entalpiendring lik $\Delta H = -1368 kJ/mol$. Hva tror du driver denne prosessen fremover? Hvorfor er vi ikke redde for ha en flaske etanol stående i luft når forbrenningen er såpass spontan?
#
# 5. Under kan du se strukturen til den kationiske surfaktanten Tetradecyl trimetylammonium bromid ($C_14-TAB$):
#
# ![$C_14-TAB$](bilder/C14TAB.png)
#
# Kalorimetriske målinger tatt ved å løse $C_14-TAB$ i vann ga følgende verdier for entalpi- og entropiendring: $\Delta H = -13 kJ/mol$ og $\Delta S = 103 J/Kmol$. Gi en kvalitativ forklaring på disse verdiene ved hjelp av animasjonen. (Tips: Google hva en surfaktant er hvis du er usikker). Bonus: Hva tror du skjer dersom vi forsøker å løse mange $C_14-TAB$ molekyler i vann? Tenk på den hydrofobiske effekten.

# %%
from IPython.display import HTML

with open("Simuleringer/c14tab-hydratisering.html", "r", encoding="utf-8") as f:
    html = f.read()

HTML(html)

# %% [markdown]
# 6. Hvordan kan vi få ikke-spontane prosesser til å gå?
#
#
# ### Regneoppgaver
#
# **Entalpi og Hess lov**
#
# 1. Vi kan finne den molare smelteentalpien $\Delta H_{fus}$ til is ved hjelp av et kalorimetri eksperiment! Kalorimeteret vårt er en kaffekopp i isopor og vi antar at denne er _fullstendig termisk isolert_. Vi veier ut 25.8 g is og legger det oppi kaffekoppen som inneholder 100.0 g vann med en temperatur på $35.4 ^{\circ} C$. Vi setter på et lokk og monterer et termometer som måler temperaturen til blandingen. Etterhvert er isen smeltet og temperaturen har sunket til $18.1 ^{\circ} C$. Varmekapasiteten til vann ved konstant trykk er $4.18 J.g^{-1}.K^{-1}$.
#
# a) Hvilke entalpiendringer har vi i løpet av prosessen? Hvilken lov må vi ta i bruk?
# b) Hva finner du for $\Delta H_{fus}$? Husk at vi ønsker den molare entalpien!
# c) Hvilke feilkilder har eksperimentet vårt?
#
# 2. Beregn standard molar dannelsesentalpi for $NOCl_{(g)}$ utifra følgende informasjon:
#
# Standard molar dannelsesentalpi for $NO_{(g)}$ er $90.25 kJ/mol$
#
# Reaksjonen $2 NOCl_{(g)} \longrightarrow 2 NO_{(g)} + {Cl_2}_{(g)} $ har standard molar reaksjonsentalpi $\Delta _rH ^{\circ} = 75,5 kJ/mol $
#
# Resonner kort om hvorfor dannelsesentalpien har verdien du har funnet utifra molekylstruktur.
#
# 3. Følgende reaksjoner og tilhørende standard molare reaksjonsentalpier er gitt:
#
# $${Fe_2O_3}_{(s)} + 3 C(grafitt) \longrightarrow 2 Fe_{(s)} + 3 CO_{(g)}; \Delta H_m^{\circ} = 492.6 kJ/mol$$
#
# $$C(grafitt) + {O_2}_{(g)} \longrightarrow {CO_2}_{(g)}; \Delta H_m^{\circ} = − 393.51 kJ/mol$$
#
# $$CO_{(g)} + \frac{1}{2} {O_2}_{(g)} \longrightarrow {CO_2}_{(g)}; \Delta H_m^{\circ} = − 282.98 kJ/mol$$
#
# Beregne standard molar dannelsesentalpi $\Delta _f H_m^{\circ}$ for ${Fe_2O_3}_{(s)}$.
#
# **Entropi**
#
# Beregne den absolutte entropien for ${SO_2}_{(g)}$ ved $300,0 K$ og $1,00 bar$ gitt følgende informasjon:
#
# $$S_m^{\circ}(15,0 K) = 1.26 J.K^{-1}.mol^{-1}, C_{p,m}(s) = 32.65 K^{-1}.mol^{-1}, T_{smp} = 197.64 K, \Delta _{fus}H_m^{\circ} = 7402 J.mol^{-1}, C_{p,m}(l) = 87.20 J. K^{-1}.mol^{-1}, T_{kp} = 263.08 K, \Delta _{vap}H_m^{\circ} = 24937 J.mol^{-1}, C_{p,m}(g) = 39.88 J.K^{-1}.mol{-1}$$
#
# Kommenter også på hva som øker entropien mest og hvorfor.
#
# Hint: i denne oppgaven lønner det seg (igjen) å først få en oversikt over hvilke delprosesser vi kan dele problemet opp i. Start ved å lage et enkelt diagram for hvordan entropien øker som funksjon av temperatur, fra fast stoff til gass, og identifiser ulike entropiøkninger og hvordan du kan regne de ut.
#
# **Drivkrefter og Gibbs fri energi**
#
# 1. $\Delta _{f}H_m^{\circ}$ for $KCl_{(s)}$, $K^+_{(aq)}$ og $Cl^-_{(aq)}$ er hhv $−436.75$, $−252.38$ og $–167.16 kJ/mol$.
# $S_m^{\circ}$ for $KCl_{(s)}$, $K^+_{(aq)}$ og $Cl^-_{(aq)}$ er hhv $82.6$, $102.5$ og $56.5 J.K^{−1}.mol^{−1}$.
# Molmassen for $KCl$ er lik $74.5 g.mol^{−1}$.
#
# a)	Regn ut $\Delta H_m^{\circ}$ og $\Delta S_m^{\circ}$  for prosessen:
#
# $$KCl_{(s)} \longrightarrow K^+_{(aq)} + Cl^−{(aq)}$$
# .
# b)	Hva er den termodynamiske drivkraften som får $KCl$ til å løse seg i vann? Hva skjer på molekylært nivå? Gi en kort begrunnelse for svaret.
#
# c)	Vil løseligheten av $KCl$ i vann øke eller avta når temperaturen øker? Gi en kort begrunnelse for svaret.
#
#
# 2. Standard molar entropi for benzen er $173.3 J.K^{-1}.mol^{-1}. Lag en funksjon som beregner endringen i standard molar Gibbs energi når benzen varmes opp fra $25,0 ^{\circ}C$ til en variabel sluttemperatur. Plott $∆G$ for oppvarminger i området $25.0 °C$ til $45.0 °C$.
#
#
# 3. Beregn standard molar Gibbs energi for reaksjonen
#
# $$CO_{(g)} + CH_3OH_{(l)} \longrightarrow CH_3COOH_{(l)}$$
#
# ved $298 K 4, ut fra standard molare dannelsesentropier og –entalpier du finner i pensumboka.
#
#
# 4. Finn ett eksempel på en reaksjon/prosess som hovedsakelig er drevet av entalpi, og en reaksjon/prosess som er entropisk drevet. Forklar hva som skjer med systemet og omgivelsene med hensyn på varmeoverføring og fordeling av energien (entropien). Start gjerne med å tenke gjennom reaksjoner dere har lært om i tidligere kurs, slik som KJM1111 Organisk Kjemi 1 og KJM1121 Uorganisk Kjemi 1.
