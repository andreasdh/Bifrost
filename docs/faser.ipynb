# %% [markdown]
# # Faser

# %% [markdown]
# ## Hva er en fase?
#
#
# // TEKST //
#
#
#
# :::{admonition} Definisjon - Fase
# :class: important
#
# En **fase** er en del av et system som er ensartet, både i kjemisk sammensetning og fysisk tilstand.
#
# Ofte kan fase være synonymt med **aggregattilstand**, som er de fire tilstandene et stoff kan være i - fast stoff, væske, gass eller plasma. Men en fase kan også være sammensatt av flere kjemiske forbindelser.
# :::
#
#
#
# Legg merke til at *fase* ikke er det samme som *tilstand*. Is og vann er to faser, men en blanding av isbiter i vann er også to faser, selv om isbitene er adskilte. Det avgjørende er at hver fase er homogen i seg selv, med en tydelig grenseflate mot de andre.
#
#
#
# Ved endring i for eksempel temperatur eller trykk, kan én fase endres til en annen fase. Dette kaller vi en **faseovergang**.
#
#
#
# :::{admonition} Definisjon - Faseovergang
# :class: important
#
# En **faseovergang** er en endring fra en fase til en annen, og oppstår ved endring i for eksempel trykk eller temperatur.
# :::
#
#
#
# De vanligste faseovergangene har dagligdagse navn, og er oppsummert i tabellen under:
#
# | Fra/til | Gass | Væske | Fast stoff | Plasma |
# | ------- | ---- | ----- | ---------- | ------ |
# | **Gass** | | Kondensasjon | Deposisjon | Ionisering |
# | **Væske** | Fordamping | | Frysing | |
# | **Fast stoff** | Sublimasjon | Smelting | | |
# | **Plasma** | Deionisering | | | |
#
#
#
# Som kjemikere er vi ofte interessert i *når* og *hvordan* disse faseovergangene skjer.

# %% [markdown]
# ## Kjemisk potensial som drivkraft for faseoverganger
#
#
# Ordet *potensial* beskriver muligheten for noe. I termodynamikk er derfor **kjemisk potensial** muligheten for at et stoff forandrer seg, og vi skal se at det blir viktig for å beskrive faseoverganger.
#
#
#
# :::{admonition} Definisjon - Kjemisk potensial
# :class: important
#
# Det **kjemiske potensialet** $\mu_i$ til et stoff $i$ er
#
# $\mu_i = \left( \frac{\partial G}{\partial n_i} \right)_{T,P}$
#
# der $G$ er Gibbs fri energi, $n_i$ er stoffmengden til stoffet, $T$ er temperaturen og $P$ er trykket.
# :::
#
#
#
# Kjemisk potensial gir opphav til et annet viktig konsept i termodynamikken, nemlig **likevekt**.
#
#
#
# :::{admonition} Definisjon - Likevekt
# :class: important
#
# To faser A og B er i **likevekt** når deres kjemiske potensialer er like, det vil si
#
# $\mu_A = \mu_B$
# :::
#
#
#
# Vi skal se nærmere på kjemisk potensial og likevekt i de neste kapitlene.

# %% [markdown]
# ## Fasediagrammer
#
#
# Et nyttig verktøy når man studerer faser, er et **fasediagram**. Et slikt diagram har temperatur $T$ på x-aksen, og trykk $P$ på y-aksen, og viser de ulike områdene der hver fase for et stoff er stabil. Det er noen spesielle trekk ved fasediagrammer som er verdt å merke seg:
#
# * **Koeksistenslinjer** - en linje mellom to faser A og B, der fasene er i likevekt med hverandre
#
# * **Trippelpunkt** - et punkt mellom tre faser A, B og C, der fasene er i likevekt med hverandre
#
# * **Kritisk punkt** - punktet der skillet mellom væske og gass forsvinner

# %% [markdown]
# // Tekst: hva kapittelet handler om, og link til entropi //
#
#
# ## Faser
#
# // Tekst: Kort intro //
#
# DEF: Aggregattilstand
#
# DEF: Fase
#
# DEF: Faseovergang og overgangstemperatur
#
#
# // Tekst: når skjer disse faseovergangene? //
#
#
#
# ## Kjemisk potensial og likevekt
#
# // Tekst: Hva er kjemisk potensial kort //
#
# UTLEDNING: Kjemisk potensial
#
# DEF: Kjemisk potenial
#
# DEF: Likevekt
#
# DEF: Metastabil fase
#
# FORMEL: Endring i mu med temperatur, konstant trykk
#
# FORMEL: Endring i mu med trykk, konstant temperatur
#
#
# ## Fasediagrammer
#
# // Tekst: Kort intro //
#
# DEF: Fasediagram
#
# BILDE: Eksempel på fasediagram
#
#
# ## Faseregler
#
# DEF: Damptrykk
#
# DEF: Kokepunkt
#
# DEF: Smelte-/frysepunkt
#
# DEF: Trippelpunkt
#
# DEF: Frihetsgrader
#
# FORMEL: F = C - P + 2
#
# FORMEL: F = 3 - P
#
# // Tekst: område, linje og punkt //
#
# UTLEDNING: Clapeyrons likning
