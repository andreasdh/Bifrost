# %% [markdown]
# # Uke 2 – Statistisk mekanikk, Boltzmann-fordelingen og Partisjonsfunskjonen
#
# :::{admonition} Læringsutbytte
# :class: note
# MÅ FYLLES INN
# :::

# %% [markdown]
# ## Diskusjonsoppgaver
#
# Tema for denne ukas oppgaver er Boltzmann-fordelingen og den relaterte partisjonsfunsjonen. I forrige uke så vi at systemer drives mot maksimering av entropi, og som Boltzman viste er entropien, $S$, direkte knyttet til multiplisiteten, $\Omega$, av mikrotilstander som hver makrotilstand kan ha gjennom:
#
# $$ S=k_{B} \ln(\Omega). $$
#
# Kun ved å se på hvilken tilstand som hadde høyest multiplisitet, og ved å anta at alle mikrotilstander er like sansynlige, kunne vi bruke enkle modeller til å forklare hvorfor en gass vil fylle rommet den er i, hvorfor polymerer trekker seg sammen, hvorfor vesker blandes, og hvorfor energi utgjevnes når to stoffer settes i termisk kontakt. (Diskusjonsoppgaver 2-5 i uke 1).
#
# Nå skal vi se på hva som sjer dersom det er begrensinger på hvilke mikrotilstander et system kan være i.
#
# ### Oppgave 1
#
# **a)** Litt repetisjon: Hva er multiplisitet?
#
# **b)** Hva er sammenhengen mellom entropi og likevekt, hva med den deriverte av entropien?
#
# **c)** Hvis vi har et 2 nivå-system (f.eks. 2 bokser A og B, to energinivåer 1 og 2, to mulige konformasjoner av et protein), og N partikler. Hvilken fordeling av de N partilene på de 2 tilstandene vil ha størst multiplisitet?
#
# **d)** Gitt at partiklene er fordelt slik at entropien er maksimert, hva er *sansynligheten* for å finne en partikkel i nivå 1 og nivå 2?
#
# **e)** Hva om vi hadde t-nivåer, N partikler kan fordeles på nivå 1, 2, 3, ..., t. Hvilken fordeling gir størst multiplisitet? Gitt at entropien er maksimert, hva er sannsynligheten for å finne en partikkel i et gitt nivå?
#
# **f)** I oppgavene over har sett på sammenhengen mellom multiplisitet og sannsynligheten for å finne en partikkel i et gitt nivå, men vi er ikke de første til å gjøre det. Vi har allerede sett at entorpi kan utrykkes med $ S=k_{b} \ln(\Omega)$, men entropi kan også utrykkes med sannsynligheter, hvordan ser det utrykket ut?
#
# ### Oppgave 2: Hva er sannsynligheten for å finne en partikkel i et gitt nivå når entropien er maksimert OG vi har en konstant totalenergi?
#
# Vi ser igjen på et fler-nivå system med N partikler, hvor hver av disse kan være i ett av $t$ energinivåer, med energier $\varepsilon_1$ ,$\varepsilon_2$, ... , $\varepsilon_t$. De N partiklene er fordelt slik at det er $n_1$ partikler i energi nivå 1, $n_2$ partikler i energinivå 2 og så videre. Alstå er det "n_i" partikler i energi-nivå $i$.
#
# **a)** Gitt at vi har $n_i$ av N partikler i enrginivå $i$. Hva er *sannsynligheten*, $p_i$, for at en tilfeldig valgt partikkel er i energinivå $i$? Hva vet vi om $\sum_{i=1}^t p_i$?
#
# **b)** Vi antar at den totale energien i systemet er begrenset til en konstant verdi $E$. Hvordan kan totalenergien utrykkes når vi vet at vi har $n_i$ partikler, hver med energi $\varepsilon_i$?
#
# **c)** Hvis vi antar et konstant antall partikler N, og en konstant total energi $E$, hva kan vi si om gjennomsnitsenergien $\langle \varepsilon \rangle$ per partikkel? Bruk den statistiske definisjonen av gjennomsnitt til å finne et utrykk for $\langle \varepsilon \rangle$
#
# :::{dropdown} Hint:
#
# Gjennomsnittsveriden, også kalt forventingsverdien, av en variabel $k_i$ som kan ha en av $i=1,2,...,t$ verdier med hver sin sannsynlighet $p_i$ kan defineres som:
#
# $$\langle k \rangle = \sum_{i=1}^t k_i \cdot p_i $$
#
# :::
#
# **d)** Vi ønsker nå å finne sannsynlighetene, $p_i$ for hvert nivå som gir den maksimale entropien, altså den mest sannsynlige fordelingen av partikler når systemet er i likevekt. Dette kan vi gjøre ved bruke Gibbs definisjon av entropi per partikkel:
#
# $$ S(p)=-k_B\cdot\sum_{i=1}^t p_i \cdot \ln{p_i} $$
#
# Merk at dette er en flervariabel funskjon, som avhenger $p_1,p_2,p_3,...,p_t$. Hva er den totalderiverte, dS, av denne funsjonen? Og hvordan bruker vi denne til å finne maksimum entropi?
#
# **e)** Fra deloppgave a) og c) har vi fått to betingelser, som vi videre kaller for g(p) og h(p), knyttet til sansynligheten, den første handler om summen av sannsynlighetene $p_i$ og den andre om gjennomsnittsenergien per partikkel. Vi antar nå at dere har funnet disse i henholdsvis deloppgave a) og deloppgave c), men dere kan dobbeltsjekke svarene under før dere går videre:
#
# :::{dropdown} Delsvar:
#
# a) Summen av alle sansynlihetene $p_i$ må være lik 1
#
# $$ g(p) = \sum_{i=1}^t p_i = 1 $$
#
# c) Gjennomsnittsenergien per partikkel er gitt ved:
#
# $$ h(p) = \langle \varepsilon \rangle = \frac{E}{N} = \sum_{i=1}^t \varepsilon_i \cdot p_i $$
#
# :::
#
# For å finne sansynlighetsfordelingen $p=[p_1,p_2,...,p_t]$ som maksimerer entropien $S(p)$ under disse betingelsene som vi kaller $g(p)$ og $h(p)$, kan vi bruke Lagrange multiplikatorer. Dette gir oss et sett av likninger på formen:
#
# $$ \frac{\partial S(p)}{\partial p_i} - \alpha \cdot \frac{\partial g(p)}{\partial p_i} -\beta \cdot \frac{\partial h(p)}{\partial p_i} = 0$$
#
# hvor $\alpha$ og $\beta$ er Lagrange multiplikatorene. Vi har egentlig én ligning per verdi av $i$, men formen på disse ligningene og multiplikatorene er de samme. Dermed trenger vi bare å løse en av de med hensyn på en generell variabel $p_i$.
#
# **Finn hver av de tre partiellderiverte i lingningen over.**
#
# **f)** Sett inn de partiellderiverte dere fant i likningen over og løs med hensyn på $p_i$. Hint: $\alpha$ og $\beta$ skal inngå i svaret.
#
# **g)** Vi husker på at $\sum_{i=1}^t p_i = 1$ og dermed kan vi dele utrykket for $p_i$ på $\sum_{i=1}^t p_i$, bruk dette til å bli kvitt $\alpha$ og forenkle utrykket mest mulig. I hintet under får du se hvordan det endelige utrykke skal se ut til slutt.
#
# :::{dropdown} Hint:
#
#
# $$ p_i = \frac{e^{-\beta\varepsilon_i}}{\sum_{i=1}^t e^{-\beta\varepsilon_i}} $$
#
# :::
#
# **h)** Gratulerer dere har nå kommet fram til Boltzmann fordelingen! Den forteller oss hvordan partiklene er fordelt på de ulike energinivåene git en begrenset totalenergi og maksimal entropi.
#
# Det kan vises at Lagrangemultiplikatoren $\beta$ er gitt ved:
#
#
#
#
#
# ### Oppgave 3

# %% [markdown]
# ## Regneoppgaver
#
#
# ### Oppgave 4
#
# **a)** Forklar forskjellen på skjelnbare og uskjelnbare partikler. Hvorfor skiller vi mellom dem og hvorfor er dette viktig å være klar over når vi setter opp partisjonsfunksjonen?
#
# **b)** Hva er partisjonsfunksjonen og hva brukes den til?
#
# **c)** I praksis måler vi som regel *energiendringer* i et system, ikke absolutte energier. Tenk deg at vi har målt energiendringen $\Delta E$ til et lite system (for eksempel en liten mengde gass i en beholder) relativt til grunntilstanden, flere ganger, og funnet fire mulige verdier. Multiplisiteten $\Omega(\Delta E)$ for hver av dem er gitt i tabellen under:
#
#   | $\Delta E$ (i enheter av $\Delta\epsilon$) | 0 | 1 | 2 | 3 |
#   |---|---|---|---|---|
#   | $\Omega(\Delta E)$ | 1 | 4 | 6 | 4 |
#
#   - Sett $\Delta\epsilon/k_BT=1$, og bruk tabellen til å sette opp $Q$ uttrykt ved energidifferanser, altså på formen $Q=\Omega(0)+\Omega(\Delta E_1)e^{-\Delta E_1\Delta\epsilon/k_BT}+\cdots$, og regn den ut.
#   - Bruk resultatet til å finne forholdet $p(\Delta E{=}1\Delta\epsilon)/p(\Delta E{=}0)$. (Husk at $p(\Delta E)=\Omega(\Delta E)e^{-\Delta E\Delta\epsilon/k_BT}/Q$, multiplisiteten skal være med.)
#   - Forklar hvordan $Q$ oppfører seg i de to ekstremtilfellene: hva blir $Q$ dersom $\Delta\epsilon/k_BT\to0$, og hva blir $Q$ dersom $\Delta\epsilon/k_BT\to\infty$? Bruk tabellen til å begrunne svaret ditt.
#   - Regn ut indre energi $U=\sum_{\Delta E}\Omega(\Delta E)\,\Delta E\,e^{-\Delta E\Delta\epsilon/k_BT}/Q$ (i enheter av $\Delta\epsilon$), og deretter entropien $S=k_B\ln Q+U/T$ (skriv svaret som $S/k_B$).
#
#
# ### Oppgave 5
#
# I Boltzmanns lov,
#
# $$p_j^* = \frac{e^{-E_j/k_BT}}{Q}$$
#
# kan vi se på partisjonsfunksjonen, $Q$, som det *effektive* antallet tilstander som er tilgjengelige for et system. (Dill side 177).
#
# **a)** Hvordan tolker du grenseverdiene $E_j \rightarrow 0$ og $T \rightarrow \infty$?
#
# **b)** Bruk grenseverdiene for energi og temperatur, $E_j \rightarrow 0$ eller $T \rightarrow \infty$, til å vise at for et system med *t* tilstander vil alle tilstander være like befolkede når temperaturen er høy eller energien veldig lav.
#
# **c)** Hva skjer i det motsatte tilfellet, hvor  $E_{j\neq 1} \rightarrow \infty$ eller $T \rightarrow 0$.
#
# ### Oppgave 6
#
# Hittil har vi stort sett antatt at alle utfall/mikrotilstander er like sannsynlige. Men, hva skjer med partisjonsfunksjonen og Boltzmann-fordelingen når vi legger på noen begrensninger eller antar at én mikrotilstand er mer sannsynlig enn en annen?
#
# Biased coins (ex. 5.4 Dill) - først finne antatt sannsynlighet hvis "fair" mynt, gi utfall 1 kron "scoren" 1, og mynt $ \varepsilon_m
# =2$, average score per toss is then $\langle \varepsilon \rangle =1.5$.
#
# Gi Lagrange multiplikator $\beta$ som $x=e^{-\beta}$, vis at partisjonsfunksjonen blir $q=x+x^2$ (likning 5.17 i Dill, sjekk om gått gjennom i forelesning)
#
#
# ### Oppgave 7
#
# I forrige ukes diskusjonsoppgaver skulle dere finne en oversettelse for "distinguishable" og "indistinguishable" partikler. Den praktiske betydningen av dette skillet

# %% [markdown]
# ### Oppgave 11 - uke 2
#
# Forrige uke fant vi sannsynligheten for en makrotilstand ved å *telle* mikrotilstander direkte ($\Omega(n)=\binom{N}{n}$). Boltzmanns fordelingslov gir oss i stedet sannsynligheten for **én enkelt mikrotilstand**, uten at vi trenger å telle noe som helst:
#
# $$p(\epsilon)=\frac{1}{q}e^{-\epsilon/k_BT}\text{.}$$
#
# **a)** Forklar kort forskjellen mellom det $\Omega(n)$ forteller oss og det $p(\epsilon)$ forteller oss.
#
# **b)** Bruk uttrykket
#
#   $$\frac{p(\epsilon_1)}{p(\epsilon_0)} = e^{-(\epsilon_1-\epsilon_0)/k_BT}$$
#
#   til å forklare hva som skjer med sannsynligheten for en mikrotilstand med *høyere* energi, sammenlignet med grunntilstanden, når forholdet $\Delta\epsilon/k_BT$ øker.
#
# **c)** Tenk deg et diatomisk molekyl. Molekylet har én vibrasjon, men den vibrasjonen har mange lovlige energinivåer den kan innta. La oss si at vibrasjonsnivåene er tilnærmet jevnt fordelte, $\epsilon_v=v\Delta\epsilon$ for $v=0,1,2,3,\dots$. Grafen under viser populasjonsforholdet $N(v)/N(0)$ for de fire laveste nivåene, ved $\Delta\epsilon/k_BT=1$:
#
#   ![Populasjonsforhold for vibrasjonsnivåer](../Simuleringer/vibrasjon_populasjon.png)
#
#   - Les av grafen: omtrent hvor stor andel av molekylene i $v=0$ finner du igjen i $v=2$?
#   - Regn nå ut $N(2)/N(0)$ analytisk ved $\Delta\epsilon/k_BT=1$, og sammenlign med avlesningen din.
#   - Regn til slutt ut $N(2)/N(0)$ på nytt, men denne gangen ved $\Delta\epsilon/k_BT=2$ (tenk deg at dette tilsvarer en lavere temperatur, eller et molekyl med en stivere binding). Ble forholdet større eller mindre enn ved $\Delta\epsilon/k_BT=1$? Stemmer dette med det du fant i b)?
