# %% [markdown]
# # Uke 8 – Faseoverganger
#
# ## Diskusjonsoppgaver
#
# ## Oppgave 1
#
# **a)** Hva er en fase? Prøv å definer det med maks 2 setninger.
#
# **b)** Hvor mange faser er det i følgende systemer, og hvorfor?
#   - En løsning med NaCl?
#   - En slusj av is og vann?
#   - 𝐶𝑎𝐶𝑂3(𝑠)→𝐶𝑎𝑂(𝑠)+𝐶𝑂2(𝑔)
#
# **c)** Hva er en superkritisk væske?
#
# **d)** For de tre første systemene i oppgave a, hvor mange komponenter er det i disse eksemplene? Angi så antall frihetsgrader, og hva frihetsgradene er for hvert system.
#
# **e)** Ved hvilken temperatur er Δ𝐺=0 for et system som består av is og vann? Hva betyr det egentlig når Δ𝐺=0? Når er Δ𝐺 positiv og negativ?
#
# **f)** Hva skjer med temperaturen under kontinuerlig oppvarming av vann når systemet når kokepunktet? Hvordan påvirker dette varmekapasiteten?
#
# Nedenfor er det vist en grafikk som viser hvordan forskjellige størrelser endres når et system undergår en faseovergang.
#
# **g)** Se på grafene og avgjør om det skjer en faseovergang og om denne er første eller andre ordens. Hva er forskjellen mellom en første og en andre ordens faseovergang?
#
# ![Faseovergang oppgave 1](../Simuleringer/figur6_phasenumwandlung_ABC.png)
#
#
# ## Oppgave 2
#
# Angi antall faser og frihetsgrader det er i hvert av punktene markert i figuren nedenfor.
#
# ![Faseovergang oppgave 2](../Simuleringer/fase1.png)
#
#
# ## Oppgave 3
#
# **a)** Hva er kjemisk potensial? Skriv også ned den matematiske definisjonen.
#
# **b)** Hva er forskjellen mellom kjemisk potensial og Gibbs fri energi?
#
# **c)** Se sammenhengen mellom kjemisk potensial og temperatur under. Hvorfor er avhengighetene ulike mellom fast-, væske- og gass-fase? Ta utgangspunkt i definisjonen av µ.
#
# ![Faseovergang oppgave 2](../Simuleringer/fase2.png)
#
# **d)** Hvordan ville grafen sett ut om kjemisk potensial var plottet mot trykk?
# **e)** Hvor kommer relasjonene for kjemisk potensial ifra?
#
# **f)** Se vedlagt plot av kjemisk potensial mot temperatur under. Forklar forskjellene til de to forskjellige stoffene i a og b, og kom med et eksempel på et molekyl til hvert plot som oppfører seg på denne måten.
#
# ![Faseovergang oppgave 2](../Simuleringer/fase3.png)
#
#
# ## Oppgave 4
#
# *Bruk simuleringen under til å svare på spørsmålene*

# %%
from IPython.display import HTML

with open("../Simuleringer/simulering_oppvarmingskurve_faseoverganger.html", "r", encoding="utf-8") as f:
    html = f.read()

HTML(html)
# Out:
# <!DOCTYPE html>
# <html lang="no">
# <head>
# <meta charset="utf-8">
# <title>Simulering: Oppvarmingskurve med faseoverganger</title>
# <style>
#   #s7-root { font-family:'Times New Roman', Times, serif; background:#0f1420; color:#e8ecf5; padding:12px; border-radius:12px; max-width:560px; margin:0 auto; }
#   #s7-root h2 { text-align:center; font-size:1.1em; margin:0 0 3px 0; font-weight:600; }
#   #s7-root .s7-sub { text-align:center; font-size:0.76em; color:#9aa5c0; margin-bottom:10px; line-height:1.4; }
#   #s7-root .s7-main { display:flex; flex-direction:row; align-items:flex-start; gap:8px; background:#161d2e; border-radius:8px; padding:8px; }
#   #s7-root canvas { background:#0a0e18; border-radius:6px; display:block; }
#   #s7-root .s7-cpcol { display:flex; flex-direction:column; align-items:center; }
#   #s7-root .s7-cplabel { font-size:0.68em; color:#9aa5c0; text-align:center; margin-top:4px; }
#   #s7-root .s7-cpval { font-size:0.75em; color:#ff8a8a; text-align:center; margin-top:2px; font-weight:600; }
#   #s7-root .s7-statsrow { display:flex; gap:16px; justify-content:center; margin-top:8px; font-size:0.85em; align-items:center; }
#   #s7-root .s7-statsrow b { color:#ffb15a; }
#   #s7-root .s7-icon { font-size:1.6em; }
#   #s7-root .s7-controls { display:flex; flex-wrap:wrap; gap:8px; justify-content:center; align-items:center; margin-top:10px; }
#   #s7-root select, #s7-root button {
#     font-family:'Times New Roman', Times, serif; background:#2a3652; color:#e8ecf5; border:none;
#     padding:6px 12px; border-radius:6px; cursor:pointer; font-size:0.8em;
#   }
#   #s7-root button:hover, #s7-root select:hover { background:#3a4a70; }
#   #s7-root button.s7-primary { background:#5aa9ff; color:#0a0e18; font-weight:600; }
#   #s7-root label.s7-checklabel { font-size:0.78em; display:flex; align-items:center; gap:5px; cursor:pointer; }
#   #s7-root .s7-legend { font-size:0.66em; color:#9aa5c0; text-align:center; margin-top:8px; line-height:1.5; }
#   #s7-root .s7-swatch { display:inline-block; width:16px; height:2px; margin-right:4px; vertical-align:middle; }
# </style>
# </head>
# <body>
# <div id="s7-root">
#   <h2>Oppvarmingskurve: temperatur mot tilført varme</h2>
#   <div class="s7-sub">Vann varmes jevnt opp fra &ndash;40&deg;C til 140&deg;C (1 mol, reelle verdier). Se hvor mye varme som "forsvinner" i platåene ved smelting og koking.</div>
#
#   <div class="s7-main">
#     <canvas id="s7-graph" width="400" height="260"></canvas>
#     <div class="s7-cpcol">
#       <canvas id="s7-cpbar" width="70" height="260"></canvas>
#       <div class="s7-cplabel">C<sub>p</sub> (varme&shy;kapasitet)</div>
#       <div class="s7-cpval" id="s7-cpval">37.7 J/(mol&middot;K)</div>
#     </div>
#   </div>
#
#   <div class="s7-statsrow">
#     <span class="s7-icon" id="s7-icon">&#129714;</span>
#     <span>T = <b id="s7-T">-40.0</b> &deg;C</span>
#     <span>q = <b id="s7-Q">0.0</b> kJ/mol</span>
#     <span id="s7-phase">Fast stoff</span>
#   </div>
#
#   <div class="s7-controls">
#     <button id="s7-run" class="s7-primary">Start oppvarming</button>
#     <button id="s7-reset">Reset</button>
#     <button id="s7-speed">Fart: 1x</button>
#   </div>
#   <div class="s7-controls">
#     <label class="s7-checklabel">
#       <input type="checkbox" id="s7-compare">
#       Vis alternativ: hva om smeltingen var andreordens i stedet?
#     </label>
#   </div>
#
#   <div class="s7-legend">
#     <span class="s7-swatch" style="background:#5aa9ff;"></span>faktisk oppvarming (f&oslash;rsteordens overganger, med plat&aring;er)&nbsp;&nbsp;
#     <span class="s7-swatch" style="background:#ffb15a;"></span>hypotetisk andreordens smelting (til sammenligning)<br>
#     Den r&oslash;de s&oslash;ylen viser &oslash;yeblikkelig varmekapasitet C<sub>p</sub> = dq/dT &ndash; den skyter mot uendelig n&oslash;yaktig i plat&aring;ene, siden T ikke endrer seg der selv om varme tilf&oslash;res.<br>
#     Data (1 mol vann): C<sub>p,is</sub>=37.7, C<sub>p,vann</sub>=75.3, C<sub>p,damp</sub>=33.6 J/(mol&middot;K). &Delta;H<sub>fus</sub>=6.01, &Delta;H<sub>vap</sub>=40.7 kJ/mol.
#   </div>
# </div>
#
# <script>
# (function(){
#   "use strict";
#
#   // --- fysiske konstanter (1 mol vann, reelle verdier) ---
#   const Cs = 0.0377, Cl = 0.0753, Cg = 0.0336; // kJ/(mol K)
#   const Lf = 6.01, Lv = 40.7; // kJ/mol
#   const Tstart = -40, Tm = 0, Tb = 100, Tend = 140;
#
#   // breakpoints for hovedkurven (førsteordens, "virkelig")
#   const Q0 = 0;
#   const Q1 = Q0 + Cs*(Tm-Tstart);
#   const Q2 = Q1 + Lf;
#   const Q3 = Q2 + Cl*(Tb-Tm);
#   const Q4 = Q3 + Lv;
#   const Q5 = Q4 + Cg*(Tend-Tb);
#
#   // breakpoints for sammenligningskurven (smelting = andreordens: ingen platå der)
#   const Q1c = Q1;
#   const Q2c = Q1c; // ingen platå
#   const Q3c = Q2c + Cl*(Tb-Tm);
#   const Q4c = Q3c + Lv; // koking beholdes førsteordens, til kontrast
#   const Q5c = Q4c + Cg*(Tend-Tb);
#
#   function TofQ(Q){
#     if(Q<=Q1) return Tstart + Q/Cs;
#     if(Q<=Q2) return Tm;
#     if(Q<=Q3) return Tm + (Q-Q2)/Cl;
#     if(Q<=Q4) return Tb;
#     if(Q<=Q5) return Tb + (Q-Q4)/Cg;
#     return Tend;
#   }
#   function TofQ_compare(Q){
#     if(Q<=Q1c) return Tstart + Q/Cs;
#     if(Q<=Q3c) return Tm + (Q-Q2c)/Cl; // rett kink, ingen platå
#     if(Q<=Q4c) return Tb;
#     if(Q<=Q5c) return Tb + (Q-Q4c)/Cg;
#     return Tend;
#   }
#
#   function CpOfQ(Q){
#     if(Q<=Q1) return Cs*1000;         // J/(mol K)
#     if(Q<=Q2) return Infinity;        // smelteplatå
#     if(Q<=Q3) return Cl*1000;
#     if(Q<=Q4) return Infinity;        // kokeplatå
#     return Cg*1000;
#   }
#
#   const graphCv = document.getElementById('s7-graph');
#   const gctx = graphCv.getContext('2d');
#   const cpCv = document.getElementById('s7-cpbar');
#   const cpctx = cpCv.getContext('2d');
#   const cpValEl = document.getElementById('s7-cpval');
#   const TEl = document.getElementById('s7-T');
#   const QEl = document.getElementById('s7-Q');
#   const phaseEl = document.getElementById('s7-phase');
#   const iconEl = document.getElementById('s7-icon');
#   const runBtn = document.getElementById('s7-run');
#   const resetBtn = document.getElementById('s7-reset');
#   const speedBtn = document.getElementById('s7-speed');
#   const compareChk = document.getElementById('s7-compare');
#
#   let Qdisplay = 0;
#   let playing = false;
#   let elapsed = 0;   // ms akkumulert spilletid
#   let lastTs = null;
#   let speedMult = 1;
#   const animDurationBase = 20000; // 20 sekunder ved 1x - sakte nok til å følge med
#
#   function phaseInfo(Q){
#     if(Q<=Q1) return {name:'Fast stoff', icon:'\u{1F9CA}'};
#     if(Q<=Q2) return {name:'Smelter (fast + v\u00e6ske)', icon:'\u{1F9CA}\u2192\u{1F4A7}'};
#     if(Q<=Q3) return {name:'V\u00e6ske', icon:'\u{1F4A7}'};
#     if(Q<=Q4) return {name:'Koker (v\u00e6ske + gass)', icon:'\u{1F4A7}\u2192\u{1F4A8}'};
#     return {name:'Gass (damp)', icon:'\u{1F4A8}'};
#   }
#
#   const margin = {l:42, r:14, t:14, b:30};
#   function X(Q){ return margin.l + (Q/Q5)*(graphCv.width-margin.l-margin.r); }
#   function Y(T){ return margin.t + (1-(T-Tstart)/(Tend-Tstart))*(graphCv.height-margin.t-margin.b); }
#
#   function drawAxes(){
#     const w=graphCv.width, h=graphCv.height;
#     gctx.strokeStyle='#3a4360'; gctx.lineWidth=1;
#     gctx.beginPath();
#     gctx.moveTo(margin.l, margin.t); gctx.lineTo(margin.l, h-margin.b); gctx.lineTo(w-margin.r, h-margin.b);
#     gctx.stroke();
#     gctx.fillStyle='#9aa5c0'; gctx.font='11px Times New Roman'; gctx.textAlign='center';
#     gctx.fillText('q (kJ/mol tilf\u00f8rt)', margin.l+(w-margin.l-margin.r)/2, h-6);
#     gctx.save(); gctx.translate(12, margin.t+(h-margin.t-margin.b)/2); gctx.rotate(-Math.PI/2);
#     gctx.fillText('T (\u00b0C)', 0,0); gctx.restore();
#
#     // referanselinjer for Tm og Tb
#     gctx.strokeStyle='#2a3652'; gctx.setLineDash([3,3]);
#     [Tm,Tb].forEach(function(T){
#       gctx.beginPath(); gctx.moveTo(margin.l, Y(T)); gctx.lineTo(w-margin.r, Y(T)); gctx.stroke();
#     });
#     gctx.setLineDash([]);
#     gctx.fillStyle='#7a8399'; gctx.font='10px Times New Roman'; gctx.textAlign='left';
#     gctx.fillText('0\u00b0C', margin.l+4, Y(Tm)-3);
#     gctx.fillText('100\u00b0C', margin.l+4, Y(Tb)-3);
#   }
#
#   function drawCurve(fn, Qmax, Qlimit, color, width, dash

# %% [markdown]
# - **a)** Trykk «Kjør oppvarming» og se på hvordan kurven ser ut mens den tegnes. Identifiser de fem fasene i forløpet (fast, smelting, væske, koking, gass) direkte i grafen.
# - **b)** Sammenlign bredden (langs Q-aksen) på platået ved smeltepunktet med platået ved kokepunktet. Hvilket av platåene er bredest, og hva forteller dette om forholdet mellom $\Delta H_{fus}$ og $\Delta H_{vap}$ for vann?
# - **c)** Se på stigningstallet til kurven i de tre "skrå" delene (fast, væske, gass). Hvorfor er stigningstallet forskjellig i disse tre områdene?
# - **d)** Kryss av for «Vis alternativ: hva om smeltingen var andreordens i stedet?» Sammenlign den stiplede kurven med den faktiske. Hvilken egenskap ved kurven forsvinner når overgangen er andreordens i stedet for førsteordens? Bruk dette til å forklare forskjellen mellom en første- og andreordens faseovergang, nå med et konkret eksempel å peke på.
# - **e)** Sett på pause rett før systemet når smeltepunktet, og se på den røde søylen til høyre for grafen. Hva skjer med søylen akkurat idet du krysser inn i platået? Hvorfor "eksploderer" varmekapasiteten $C_p=dq/dT$ på denne måten, når $C_p$ jo skal være en egenskap ved selve stoffet? Er det noe galt med stoffet, eller sier dette noe mer generelt om hvordan vi definerer $C_p$?
#
#
# ## Oppgave 5
#
# **a)** Under en faseovergang (f.eks. issmelting) holder temperaturen seg konstant selv om man kontinuerlig tilfører varme. Forklar dette mikroskopisk: hva brukes varmen på, siden den ikke øker den gjennomsnittlige kinetiske energien til molekylene?
#
# **b)** Bruk tankegangen bak partisjonsfunksjonen til å forklare hvorfor entropien øker når et stoff går fra fast til flytende til gass. Hva skjer med antall tilgjengelige mikrotilstander $\Omega$ i hvert av disse to trinnene?
#
# **c)** For et system av $N$ ikke-vekselvirkende partikler kan det kjemiske potensialet skrives $\mu=-k_BT\ln(q/N)$, der $q$ er den molekylære partisjonsfunksjonen. Ut fra dette uttrykket: hvorfor gir flere tilgjengelige mikrotilstander per molekyl (høyere $q$) et *lavere* kjemisk potensial? Heng dette sammen med svaret ditt i oppgave 3c om hvorfor gass har en brattere $\mu(T)$-kurve enn væske og fast stoff.
#
# **d)** Ved en førsteordens faseovergang skjer det et brått, diskontinuerlig hopp i entropi og volum akkurat idet man krysser overgangen. Er dette en brå eller gradvis endring i antall tilgjengelige mikrotilstander, sett molekyl for molekyl? Diskuter.
#
#
# ## Oppgave 6
#
# *Bruk simuleringen under til å svare på spørsmålene*

# %%
from IPython.display import HTML

with open("../Simuleringer/simulering_mikro_makro_faseoverganger.html", "r", encoding="utf-8") as f:
    html = f.read()

HTML(html)
# Out:
# <!DOCTYPE html>
# <html lang="no">
# <head>
# <meta charset="utf-8">
# <title>Simulering: Mikro og makro ved faseoverganger</title>
# <style>
#   #s8-root { font-family:'Times New Roman', Times, serif; background:#0f1420; color:#e8ecf5; padding:12px; border-radius:12px; max-width:600px; margin:0 auto; }
#   #s8-root h2 { text-align:center; font-size:1.05em; margin:0 0 3px 0; font-weight:600; }
#   #s8-root .s8-sub { text-align:center; font-size:0.74em; color:#9aa5c0; margin-bottom:10px; line-height:1.4; }
#   #s8-root .s8-main { display:flex; gap:10px; flex-wrap:wrap; justify-content:center; }
#   #s8-root .s8-col { display:flex; flex-direction:column; align-items:center; background:#161d2e; border-radius:8px; padding:8px; width:270px; box-sizing:border-box; }
#   #s8-root canvas { background:#0a0e18; border-radius:6px; display:block; }
#   #s8-root .s8-caption { font-size:0.68em; color:#9aa5c0; margin-top:5px; text-align:center; }
#   #s8-root .s8-peakinfo { font-size:0.78em; margin-top:4px; font-weight:600; }
#   #s8-root .s8-peakinfo.bimodal { color:#ff8a8a; }
#   #s8-root .s8-peakinfo.unimodal { color:#7fe0a8; }
#   #s8-root .s8-statsrow { display:flex; gap:16px; justify-content:center; margin-top:8px; font-size:0.8em; }
#   #s8-root .s8-statsrow b { color:#ffb15a; }
#   #s8-root .s8-controls { display:flex; flex-wrap:wrap; gap:6px; justify-content:center; align-items:center; margin-top:10px; }
#   #s8-root select, #s8-root button {
#     font-family:'Times New Roman', Times, serif; background:#2a3652; color:#e8ecf5; border:none;
#     padding:6px 12px; border-radius:6px; cursor:pointer; font-size:0.8em;
#   }
#   #s8-root button:hover, #s8-root select:hover { background:#3a4a70; }
#   #s8-root button.s8-active { background:#5aa9ff; color:#0a0e18; font-weight:600; }
#   #s8-root button.s8-primary { background:#5aa9ff; color:#0a0e18; font-weight:600; }
#   #s8-root .s8-slider-row { display:flex; align-items:center; gap:6px; font-size:0.78em; width:100%; justify-content:center; }
#   #s8-root input[type=range] { width:220px; }
#   #s8-root .s8-legend { font-size:0.66em; color:#9aa5c0; text-align:center; margin-top:8px; line-height:1.5; }
# </style>
# </head>
# <body>
# <div id="s8-root">
#   <h2>Mikro og makro ved smelting: is og vann</h2>
#   <div class="s8-sub">x = andel av systemet som er is (fast fase), fra 0 (alt vann) til 1 (all is). Se hvordan sannsynlighetsfordelingen (mikro) og den observerbare kurven (makro) henger sammen &ndash; og hvordan de ville sett ut om smeltingen i stedet var andreordens.</div>
#
#   <div class="s8-controls">
#     <button id="s8-mode1" class="s8-active">Ekte smelting (1. orden)</button>
#     <button id="s8-mode2">Hypotetisk 2. orden</button>
#   </div>
#
#   <div class="s8-main">
#     <div class="s8-col">
#       <canvas id="s8-micro" width="250" height="170"></canvas>
#       <div class="s8-caption">Mikro: sannsynlighetsfordeling P(x)</div>
#       <div class="s8-peakinfo" id="s8-peakinfo">...</div>
#     </div>
#     <div class="s8-col">
#       <canvas id="s8-macro" width="250" height="170"></canvas>
#       <div class="s8-caption">Makro: andel is mot T</div>
#     </div>
#   </div>
#
#   <div class="s8-statsrow">
#     <span>T = <b id="s8-Tval">-50</b> &deg;C</span>
#     <span>andel is = <b id="s8-xavg">0.00</b></span>
#   </div>
#
#   <div class="s8-controls">
#     <div class="s8-slider-row">
#       <label for="s8-T">T:</label>
#       <input type="range" id="s8-T" min="-50" max="50" step="1" value="-50">
#     </div>
#   </div>
#   <div class="s8-controls">
#     <button id="s8-run" class="s8-primary">Start sveip</button>
#     <button id="s8-reset">Reset</button>
#     <button id="s8-speed">Fart: 1x</button>
#   </div>
#
#   <div class="s8-legend">
#     F&oslash;rsteordens er ekte fysikk for is/vann (smeltepunkt 0&deg;C). Andreordens-versjonen er et <b>tenkt</b> scenario &ndash; ekte smelting er alltid f&oslash;rsteordens, men sammenligningen viser hva forskjellen faktisk best&aring;r i.<br>
#     Den smale (men ikke helt loddrette) overgangen ved f&oslash;rsteordens representerer et endelig system; i den termodynamiske grensen (N&rarr;&infin;) blir spranget fullstendig skarpt.
#   </div>
# </div>
#
# <script>
# (function(){
#   "use strict";
#
#   const Tc = 0; // ekte smeltepunkt for vann, 0°C
#   // ekte smelting (førsteordens)
#   const width1 = 2.2;
#   const xVann = 0.12, xIs = 0.88; // "andel is"-verdi for hver av de to fasene
#   const sigmaPeak = 0.045;
#   // hypotetisk andreordens-versjon
#   const width2 = 20;
#
#   let mode = 'first'; // 'first' eller 'second'
#   let Tcur = -50;
#   let playing = false;
#   let elapsed = 0, lastTs = null;
#   let speedMult = 1;
#   const sweepDuration = 16000; // ms for full sveip -50 -> 50
#
#   const microCv = document.getElementById('s8-micro');
#   const macroCv = document.getElementById('s8-macro');
#   const mctx = microCv.getContext('2d');
#   const Mctx = macroCv.getContext('2d');
#   const peakInfoEl = document.getElementById('s8-peakinfo');
#   const TvalEl = document.getElementById('s8-Tval');
#   const xavgEl = document.getElementById('s8-xavg');
#   const Tslider = document.getElementById('s8-T');
#   const mode1Btn = document.getElementById('s8-mode1');
#   const mode2Btn = document.getElementById('s8-mode2');
#   const runBtn = document.getElementById('s8-run');
#   const resetBtn = document.getElementById('s8-reset');
#   const speedBtn = document.getElementById('s8-speed');
#
#   function wSolid(T){ return 1/(1+Math.exp((T-Tc)/width1)); }
#   function xEq2(T){ return 1/(1+Math.exp((T-Tc)/width2)); }
#   function sigma2(T){ return 0.04 + 0.05*Math.exp(-Math.pow((T-Tc)/12,2)); }
#
#   function gauss(x, mu, sigma){
#     return Math.exp(-Math.pow(x-mu,2)/(2*sigma*sigma)) / (sigma*Math.sqrt(2*Math.PI));
#   }
#
#   function Pdist(x, T){
#     if(mode==='first'){
#       const w = wSolid(T);
#       return w*gauss(x,xIs,sigmaPeak) + (1-w)*gauss(x,xVann,sigmaPeak);
#     } else {
#       return gauss(x, xEq2(T), sigma2(T));
#     }
#   }
#
#   function xAvg(T){
#     if(mode==='first'){
#       const w = wSolid(T);
#       return w*xIs + (1-w)*xVann;
#     } else {
#       return xEq2(T);
#     }
#   }
#
#   function drawMicro(T){
#     const w = microCv.width, h = microCv.height;
#     mctx.clearRect(0,0,w,h);
#     const margin = {l:30,r:10,t:10,b:22};
#     const pw = w-margin.l-margin.r, ph = h-margin.t-margin.b;
#
#     let maxY = 0;
#     const steps = 150;
#     const vals = [];
#     for(let i=0;i<=steps;i++){
#       const x = i/steps;
#       const p = Pdist(x,T);
#       vals.push(p);
#       if(p>maxY) maxY = p;
#     }
#     maxY *= 1.15;
#
#     mctx.strokeStyle='#3a4360'; mctx.lineWidth=1;
#     mctx.beginPath(); mctx.moveTo(margin.l,margin.t); mctx.lineTo(margin.l,margin.t+ph); mctx.lineTo(margin.l+pw,margin.t+ph); mctx.stroke();
#     mctx.fillStyle='#9aa5c0'; mctx.font='10px Times New Roman'; mctx.textAlign='center';
#     mctx.fillText('x = andel is', margin.l+pw/2, h-4);
#
#     mctx.strokeStyle='#5aa9ff'; mctx.lineWidth=2.2;
#     mctx.beginPath();
#     for(let i=0;i<=steps;i++){
#       const x = margin.l + (i/steps)*pw;
#       const y = margin.t + ph - (vals[i]/maxY)*ph;
#       if(i===0) mctx.moveTo(x,y); else mctx.lineTo(x,y);
#     }
#     mctx.stroke();
#
#     // fyll under kurven
#     mctx.lineTo(margin.l+pw, margin.t+ph);
#     mctx.lineTo(margin.l, margin.t+ph);
#     mctx.closePath();
#     mctx.fillStyle='rgba(90,169,255,0.18)';
#     mctx.fill();
#
#     // peak-info
#     if(mode==='first'){
#       const w2 = wSolid(T);
#       if(w2>0.05 && w2<0.95){
#         peakInfoEl.textContent = '2 topper (sameksisterende faser)';
#         peakInfoEl.className = 's8-peakinfo bimodal';
#       } else {
#         peakInfoEl.textContent = '1 dominerende topp (kun én fase)';
#         peakInfoEl.className = 's8-peakinfo unimodal';
#       }
#     } else {
#       peakInfoEl.textContent = '1 topp (glir kontinuerlig)';
#       peakInfoEl.className = 's8-peakinfo unimodal';
#     }
#   }
#
#   function drawMacro(T){
#     const w = macroCv.width, h = macroCv.height;
#     Mctx.clearRect(0,0,w,h);
#     const margin = {l:30,r:10,t:10,b:22};
#     const pw = w-margin.l-margin.r, ph = h-margin.t-margin.b;
#
#     function X(TT){ return margin.l + ((TT+50)/100)*pw; }
#     function Y(x

# %% [markdown]
# **a)** Start i modusen «Ekte smelting (1. orden)» med $T=-50\,°C$. Se på venstre panel (mikro): hvor mange topper har fordelingen $P(x)$? Hva forteller plasseringen til denne ene toppen om systemet, er det is eller vann?
#
# **b)** Dra glidebryteren sakte forbi $T=0\,°C$. Beskriv hva som skjer med $P(x)$ idet du krysser smeltepunktet.
#
# **c)** Se på høyre panel (makro) mens du gjør det samme. Hva skjer med andelen is akkurat idet du krysser $0\,°C$?
#
# **d)** Bytt til «Hypotetisk 2. orden» og gjenta bevegelsen fra $-50\,°C$ til $50\,°C$. Sammenlign med det du så i b) og c): hvor mange topper har $P(x)$ nå, gjennom hele forløpet? Hvordan skiller utviklingen av andel-is-kurven seg fra den ekte smeltingen?
#
# **e)** I første ordens-modus er ikke overgangen i simuleringen helt loddrett ved $0\,°C$, men ganske smal. Dette er en forenkling, hvorfor er det urealistisk at overgangen skal være *helt* skarp i en simulering av et system med endelig mange molekyler? Hva skjer med bredden på denne overgangen når man tenker seg $N\to\infty$?
#
# **g)** Selv om ingen ekte stoffer smelter andreordens, finnes det andre fysiske systemer (f.eks. hvordan en magnet mister magnetismen sin ved høy nok temperatur) som faktisk er andreordens. Ut fra det du så i simuleringen: hva tror du er det *generelle* kjennetegnet, uavhengig av hvilket fysisk system det er snakk om, som skiller en førsteordens fra en andreordens faseovergang på mikronivå?

# %% [markdown]
# ## Regneoppgaver
#
# ## Oppgave 7
#
# Bruk følgende data for å lage et fasediagram med Python/matplotlib for systemet fenol – vann og svar på spørsmålene nedenfor (sammensetningen er gitt i masse-prosent fenol):
#
# | t/°C | 20 | 25 | 30 | 35 | 40 | 45 | 50 | 55 | 60 | 65 | 68,8 |
# |---|---|---|---|---|---|---|---|---|---|---|---|
# | vannlag | 8,40 | 8,71 | 8,92 | 9,34 | 9,78 | 10,62 | 12,08 | 13,88 | 17,10 | 22,26 | 35,90 |
# | fenollag | 72,24 | 71,38 | 69,95 | 68,28 | 66,81 | 65,02 | 62,83 | 60,18 | 56,10 | 49,34 | 35,90 |
#
# - **a)** Angi sammensetningene på de to lagene som dannes ved $30^{\circ}C$ fra en løsning av $30$ g fenol og $70$ g vann.
# - **b)** En løsning av $20$ g fenol og $80$ g vann oppbevares ved $70^{\circ}C$. Angi antall faser som foreligger.
# - **c)** Løsningen i b) kjøles ned gradvis. Ved hvilken temperatur dannes to faser?
# - **d)** Ved $30^{\circ}C$ og $30$ masseprosent av fenol, hvor mye er det relativt av de to fasene?
# - **e)** Den frie energien for blandingen av to væsker er gitt som
#
# $$ \frac{\Delta G(x)}{nRT}=x \ln (x)+(1-x)\ln (1-x)+\gamma x (1-x),$$
#
# der $\gamma$ er et mål på hvor ideelle interaksjonene mellom komponentene i blandingen er. Denne er avhengig av temperaturen, og absoluttverdien til $\gamma$ avtar med økende temperatur. Plot $\Delta G$ som en funksjon av molbrøken $x$ for forskjellige temperaturer i området $0-100^{\circ}C$. Du kan sette $\gamma=684/T$ der $T$ har enheten Kelvin.
#
# - **f)** Hvordan henger plottene sammen med antall faser som finnes?
#
#
# ## Oppgave 8
#
# Når en gitt væske med en molar masse på $46.1 \text{g mol}^{-1}$ fryser ved $-3.65^{\circ}C$ endres dens tetthet fra $0.789 \text{g cm}^{-3}$ til $0.801 \text{g cm}^{-3}$. Den molare smelteentalpien til væsken er $8.68 \text{kJ mol}^{-1}$. Estimer frysepunktet for væsken ved $1 \text{Mpa}$.
#
# ## Oppgave 9
#
# Molar fordampningsentalpi for vann ved $100^{\circ}C$ er $40.63 \text{kJ mol}^{-1}$. Finn arbeidet som utføres av systemet når $2.00 \text{mol}$ vann fordamper ved $100^{\circ}C$ og $1.00 \text{atm}$ trykk. Finn også forandringene i systemets indre energi $\Delta U$, Gibbs energi $\Delta G$ og entropi $\Delta S$. Tettheten for vann i væskeform ved $100^{\circ}C$ er $0.9584 \text{g cm}^{-3}$, og tettheten for vanndamp ved samme temperatur er $0.000596\text{g cm}^{-3}$.
#
# ## Oppgave 10
#
# Normalkokepunktet for etylenglykol ($\text{C}_2\text{H}_6\text{O}_2$) er $197^{\circ}C$, og spesifikk fordampningsentalpi er $801 \text{J g}^{-1}$. Finn temperaturen der etylenglykol koker i et destillasjonsoppsett når trykket er $50.0 \text{Torr}$.
#
# ## Oppgave 11
#
# Nedenfor er det gitt data for hvordan den indre energien til et system varierer med temperatur i et system som undergår en faseovergang.
#
# | Temperatur (°C) | 35 | 40 | 45 | 50 | 51 | 51.5 | 51.6 | 55 | 60 |
# |---|---|---|---|---|---|---|---|---|---|
# | Indre Energi (J) | 401 | 435 | 499 | 582 | 776 | 887 | 2012 | 2020 | 2031 |
#
# Lag et skript for å finne ut ved hvilken temperatur faseovergangen skjer.
#
# Hint: Husk det du har lært om numerisk derivasjon.
