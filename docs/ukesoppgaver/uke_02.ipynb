# %% [markdown]
# # Uke 2 – Statistisk mekanikk, energi, entropi og temperatur
#
# :::{admonition} Læringsutbytte
# :class: note
# Etter å ha jobbet med dette temaet skal du kunne:
#
# - forklare entropi som et mål på antall mikrotilstander som er forenlige med en gitt makrotilstand
# - beskrive hvordan sannsynlighet og antall mikrotilstander er knyttet til termodynamisk likevekt
# - forklare temperatur som et mål på sammenhengen mellom energi og entropi
# :::

# %% [markdown]
# ## Diskusjonsoppgaver
#
# ### Oppgave 1
#
# **a)** Hva sier termodynamikkens 2. lov?
#
# **b)** Hva er den makroskopiske definisjonen av entropi?
#
# **c)** Hva er den mikroskopiske definisjonen for entropi? Hva ligger det i $\Omega$?
#
# **d)** Se for dere en rekke med 10 bokser og 3 kuler. Kulene plasseres tilfeldig i boksene, og det er mulig å ha flere kuler i samme boks. Forventer dere at alle de 3 kulene skal plassere seg i samme boks? Hvorfor, eventuelt hvorfor ikke?
#
# **e)** Hva kan boksene representere i et molekylært system?
#
# **f)** Et system kan ha flere ulike frihetsgrader. Nevn noen som kan bidra til systemets entropi.
#
# **g)** Er entropi en ekstensiv eller intensiv størrelse? Hva med molar entropi?
#
# **h)** Hva er sammenhengen mellom entropi og likevekt?
#
# ### Oppgave 2
#
# Entropien til et system er gitt av antall mikrotilstander, $\Omega$, (posisjoner, energinivå, konformasjoner etc.) gjennom Boltzmanns entropi $S=k_B\ln\Omega$, der $k_B=1.38\times10^{-23}\ \mathrm{J/K}$ er Boltzmanns konstant.
#
# Et eksempel på en tilstand der tre forskjellige, skjelnbare partikler befinner seg i tre mulige bokser er skjematisk illustrert nedenfor.
#
# ![Gitter1](../Simuleringer/figur1_kuler_bokser.png)
#
# **a)** Hvor mange måter kan vi organisere partiklene på i boksene? Hva er sannsynligheten for at vi finner akkurat den konfigurasjonen vi har over? Hva er entropien til dette systemet?
#
# Tenk nå at vi har tre partikler i forskjellige bokser som kan enten være tomme eller fylt opp med identiske partikler (røde).
#
# ![Gitter2](../Simuleringer/figur2_partikler_rader.png)
#
# **b)** Hvor mange mulige konfigurasjoner (mikrotilstander) finnes det for hvert av tilfellene a–d) over? Beregn entropien.
#
# **c)** Anta at vi har en prosess som går fra a) til d). Beregn $\Delta S$ for prosessen.
#
# **d)** Gitt situasjonen i d), hva er sannsynligheten for at de tre kulene ligger direkte ved siden av hverandre? Hva er sannsynligheten for at de **ikke** alle tre ligger direkte ved siden av hverandre?
#
# **e)** Ut fra dette, hva kan du si om hvorfor stoffer ofte sprer seg og fyller hele beholdere?
#
# ### Oppgave 3
#
# Grafen under viser entropien $S=k_B\ln\Omega(n)$ som funksjon av energien $E=n\Delta\epsilon$ for et to-nivå-system (f.eks. noen partikler fordelt over to energinivåer):
#
# ![Entropi som funksjon av energi](../Simuleringer/entropi_vs_energi.png)
#
# :::{admonition} OBS
# :class: error
# Siden dette er et begrenset to-nivå-system (energien kan ikke øke uendelig, bare opp til at alle partikler er eksiterte), synker faktisk $S$ igjen etter toppunktet og stigningstallet blir negativt. Dette er ikke en feil i modellen; det er et ekte fenomen for to-nivå-systemer, kjent som "negativ temperatur". Det er greit å vite om, men i oppgavene under, **bare forhold deg til grafen frem til toppunktet.**
# :::
#
# **a)** Stigningstallet til kurven er $1/T$. Beskriv hvordan $S$ endrer seg med $E$ i starten av kurven sammenlignet med mot toppunktet.
#
# **b)** Toppunktet på kurven er der $S$ og $\Omega(n)$ er størst. Hva forteller dette om hvor mange mikrotilstander som finnes ved denne energien? Er dette alene nok til å bestemme hvilken energi systemet vil ha dersom det står i termisk kontakt med omgivelser ved en gitt temperatur?
#
# **c)** Dersom systemet står i termisk kontakt med et stort varmereservoar, må vi ta hensyn både til systemet og omgivelsene. Forklar med egne ord hvorfor likevekt bestemmes av maksimal **total entropi**, ikke bare av maksimumet til $S(E)$ for systemet alene.
#
# **d)** Sammenlign stigningstallet til kurven nær $n=0$ med stigningstallet nær toppunktet. Hva forteller dette om temperaturen som svarer til disse delene av kurven?
#
# **e)** Forklar med egne ord sammenhengen mellom de *makroskopiske* størrelsene $U$ og $\Delta S$, og de *mikroskopiske* størrelsene de er bygget fra ($\epsilon_n$ og $\Omega$). Hvorfor er det riktig å si at $U$ og $\Delta S$ er "informasjon om mikroverdenen, oversatt til noe vi kan måle i laboratoriet"?

# %% [markdown]
# ## Regneoppgaver
#
# ### Oppgave 4
#
# **a)** Hva menes med at delsystemer eller plasser kan være skjelnbare i en modell, mens identiske partikler er uskjelnbare? Hvorfor er dette viktig når vi teller mikrotilstander og setter opp partisjonsfunksjonen?
#
# **b)** Hva er partisjonsfunksjonen og hva brukes den til?
#
# **c)** I praksis måler vi som regel *energiendringer* i et system, ikke absolutte energier. Tenk deg at vi har målt energiendringen $\Delta E$ til et lite system relativt til grunntilstanden flere ganger, og funnet fire mulige verdier. Multiplisiteten $\Omega(\Delta E)$ for hver av dem er gitt i tabellen under. Her spiller $\Omega(\Delta E)$ samme rolle som degenerasjonen $g_j$: den teller hvor mange mikrotilstander som har den samme energien.
#
# | $\Delta E$ (i enheter av $\Delta\epsilon$) | 0 | 1 | 2 | 3 |
# |---|---|---|---|---|
# | $\Omega(\Delta E)$ | 1 | 4 | 6 | 4 |
#
# - Sett $\Delta\epsilon/k_BT=1$, og bruk tabellen til å sette opp $Q$ uttrykt ved energidifferanser, altså på formen $Q=\Omega(0)+\Omega(\Delta E_1)e^{-\Delta E_1\Delta\epsilon/k_BT}+\cdots$, og regn den ut.
# - Bruk resultatet til å finne forholdet $P(\Delta E{=}1\Delta\epsilon)/P(\Delta E{=}0)$. Husk at sannsynligheten for et **energinivå** er $P(\Delta E)=\Omega(\Delta E)e^{-\Delta E\Delta\epsilon/k_BT}/Q$, fordi multiplisiteten skal være med.
# - Forklar hvordan $Q$ oppfører seg i de to ekstremtilfellene: hva blir $Q$ dersom $\Delta\epsilon/k_BT\to0$, og hva blir $Q$ dersom $\Delta\epsilon/k_BT\to\infty$? Bruk tabellen til å begrunne svaret ditt.
# - Regn ut indre energi $U=\sum_{\Delta E}\Omega(\Delta E)\,\Delta E\,e^{-\Delta E\Delta\epsilon/k_BT}/Q$ (i enheter av $\Delta\epsilon$), og deretter entropien $S=k_B\ln Q+U/T$ (skriv svaret som $S/k_B$).
#
# ### Oppgave 5
#
# Figuren under viser ulike energinivåer $(E=0,1,2,3)$ der hver «partikkel»/molekyl har en energi på $Ek_BT$ avhengig av hvilket energinivå den befinner seg i. Hver makrotilstand kan ha flere mikrotilstander. Det vil si, vi skiller mellom hver partikkel sin spesifikke posisjon innen energinivåene (om partikkelen er i boks 1,2,3,4 eller 5 horisontalt). Det totale antallet mulige mikrotilstander i et system av bokser og partikler er gitt ved $n^N$, der $N$ er antallet partikler (i vårt tilfelle 5), og $n$ er antallet bokser.
#
# ![Gitter3](../Simuleringer/figur3_energiniva.png)
#
# **a)** Hva er en makrotilstand i dette systemet?
#
# **b)** Beregn den indre energien, $U$, for hver av de viste makrotilstandene. (Husk at en partikkels energi er gitt ved $Ek_BT$.)
#
# **c)** Hvor mange muligheter kan man realisere tilstandene til høyre og venstre på? Med andre ord: finn antallet mikrotilstander i hver makrotilstand.
#
# **d)** Beregn entropien i hvert av tilfellene til høyre og venstre.
#
# **e)** Hva kan du si om sammenhengen mellom entropi og indre energi ut fra dette?
#
# ### Oppgave 6
#
# Et system kan gå fra makrotilstand 1 til makrotilstand 2. Makrotilstand 1 har $U_1=100\text{ J}$ og $S_1=2{,}0\text{ J/K}$. Makrotilstand 2 har $U_2=150\text{ J}$ og $S_2=2{,}3\text{ J/K}$.
#
# **a)** Regn ut $\Delta U$ og $\Delta S$ mellom de to makrotilstandene.
#
# **b)** Bruk $\dfrac{1}{T}\approx\dfrac{\Delta S}{\Delta U}$ til å anslå temperaturen til systemet.
#
# **c)** Kan du avgjøre hvilken av de to makrotilstandene som er mest sannsynlig dersom systemet står i termisk kontakt med et varmereservoar, bare ved å sammenligne $S_1$ og $S_2$? Forklar kort hva mer du må vite.
