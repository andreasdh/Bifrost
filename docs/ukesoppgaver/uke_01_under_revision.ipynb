# %% [markdown]
# # Uke 1 – Statistisk mekanikk og mikro–makro-sammenhengen
# :::{admonition} Læringsutbytte
# :class: note
# Etter å ha jobbet med dette temaet skal du kunne:
#
# - forklare forskjellen mellom en mikrotilstand og en makrotilstand
# - forklare hvorfor statistiske beskrivelser er nødvendige for systemer som består av
# svært mange partikler
# - beskrive energi som en egenskap ved mikrotilstander og som en størrelse som kan
# fordeles mellom molekyler på mange ulike måter
# - forklare entropi som et mål på antall mikrotilstander som er forenlige med en gitt
# makrotilstand
# - forklare hvorfor makrotilstander med mange mikrotilstander er mer sannsynlige enn
# makrotilstander med få mikrotilstander
# :::

# %% [markdown]
# ## Diskusjonsoppgaver
#
# ### Oppgave 1
#
# **a)** Hva er forskjellen på en mikrotilstand og en makrotilstand? Kom med et eksempel.
#
# **b)** Hva legger vi i begrepet multiplisitet?
#
# **c)** Hvordan vil du beskrive sammenhengen mellom multiplisitet og sannsynlighet?
#
# **d)** Når vi jobber med partikler må vi skille mellom systemer med "distinguishable" og "indistinguishable" partikler. Kan du komme opp med en god forklaring på, og oversettelse, begrepene? Og hvordan tror du f.eks. multiplisitet vil påvirkes av hvilke type partikler man jobber med?

# %% [markdown]
# ### Oppgave 2 $^*$
#
# Hvorfor utøver gasser trykk?
#
# Vi ser for oss en gass som inneholder N sfæriske gasspartikler som kan fordele seg i enten et lite område eller et større område (se figur under). Intuitivt vet vi at gassen kommer til å spre seg utover i det store volumet, men hvorfor gjør den det?
#
# Gassens tendens til å spre seg utover er en annen måte å forklare *trykket* på. Mekanisk ser vi på trykket som partikler med bevegelsesenergi som utøver en kraft mot beholderen de er i. I denne oppgaven skal vi bruke statistisk mekanikk og multiplisitet til å vise at partiklene spres utover fordi dette er den mest sannsynlige tilstanden vi kan finne de i.
#
# I figuren under skalerer vi problemet ned til gitter med hhv. 3, 4 og 5 bokser ($M=3, M=4, M=5$), og N=3 gasspartikler. Bruk figuren og det du kan om multiplisitet og sannsynlighet til å forklare gass-trykk.
#
# :::{image} ../bilder/Diskusjon_2p2.png
# :alt: Illustrasjon til oppgave 2
# :width: 50%
# :align: center
# :::
#
#
#
# <!--basert på 2.2 i Dill, utvide med å skalere opp antallet bokser og/eller antallet partikler-->

# %% [markdown]
# ### Oppgave 3 $^*$
#
# Luften rundt oss er en blanding av ulike molekyler, og vi vet at dersom vi står i det ene hjørnet av rommet og stikker hull på en heliumballong så vil helium-atomene i løpet av kort tid fordele seg jevnt utover i rommet.
#
# Igjen ser vi for oss et gitter med bokser, men denne gangen har vi partikler med to ulike farger, og varierer hvor mange av hver farge befinner seg på hver side at en permeabel skillevegg. Det totale volumet er det samme i hvert tilfelle, og det er fire bokser på hver side av veggen. Frihetsgradene til systemet er nå antallet oransje og grå kuler på hver side. Se på de tre tilfellene i figuren under. Hvilken sammensetning av kuler forventer du på hver side? Bruk multiplisitet og sannsynlighet til å begrunne svaret deres.
#
# :::{image} ../bilder/Diskusjon_2p3.png
# :alt: Illustrasjon til oppgave 3
# :width: 50%
# :align: center
# :::
#
# Skaler opp: Hva tror dere skjer når vi begynner å snakke om systemer med mer realistisk antall molekyler, f.eks. 10 000 (eller et annet tall dere synes virker loigisk)?
#
# Sannsynligvis fikk kalkulatoren eller PC'en din problemer med fakultet-utregning av så store tall - så hvordan kan vi regne på store mengder, når vi sliter med en relativ enkel blanding av to typer kuler.
#
# Og er dette antallet molekyler egt. så stort? Regn ut volumet av 10 000 vannmolekyler.

# %% [markdown]
# ### Oppgave 4 $^*$
# Hvis man tøyer en gummistrikk vil den gå tilbake til sin opprinnelige form når man slipper den igjen. Denne retraktive kraften skyldes tendensen polymerene har til å folde seg i konformasjoner som maksimerer multiplisiteten. Se for deg en polymer bestående av fire kuler bundet sammen. Figuren under viser den fullt utstrekte konformasjonen målt i lengden *l*. Deres jobb er nå å tegne opp og finne multiplisiteten for hver mulige lengde *l*, og dermed bestemme hvilken konformasjon polymeren stort sett vil befinne seg i.
#
# obs! den første kulen er "limt" fast i veggen og kan ikke endre posisjon.
#
# :::{image} ../bilder/Diskusjon_2p4.png
# :alt: Illustrasjon til oppgave 4
# :width: 50%
# :align: center
# :::
#
#
# Hint: tegn opp de ulike konformasjonene for hver lengde av utstrekning
# <!--basert på 2.4 i Dill#-->

# %% [markdown]
# ### Oppgave 5 $^*$
#
# I oppgave 4 så vi på diffusjon som en utveksling av partikler, men vi vet også at vi kan utveksle energi (riktig nok ikke i form av partikler, i motsetning til Calorique-teorien). Nedenfor er det vist to systemer, A og B, med 10 partikler hver. Hver partikkel kan befinne seg i grunntilstanden ($\epsilon = 0$), eller i en eksitert tilstant ($\epsilon=1$). Anta at system A starter med energien $U_A = 2$ og system B med energien $U_B = 4$, og at de settes i termisk kontakt med hverandre. Vis at systemene i kontakt vil dele energi slik at energifordelingen ved likevekt vil være $U_A=U_B = 3$.
#
# :::{image} ../bilder/Diskusjon_3p9.png
# :alt: Illustrasjon til oppgave 5
# :width: 80%
# :align: center
# :::
#
#
# Hint: tell antallet måter A kan ha 2 partikler i eksitert tilstand og 8 i grunntilstanden, og tilsvarende for B og likevektssituasjonen. Her må man også huske å kombinere multiplisitetene til hvert system.
#
#
# $^*$ Oppgavene er inspirert av eksempler fra Dill, K. A., Bromberg, S., & Stigter, D. (2010). Molecular Driving Forces. Garland Science. https://doi.org/10.4324/9780203809075

# %% [markdown]
# ## Regneoppgaver
#
# ### Oppgave 6
#
# Vi har et system av $N = 5$ partikler, fordelt mellom to bokser, boks A og boks B. Hver partikkel kan befinne seg i enten den ene eller den andre boksen.

# %% [markdown]
# <iframe src="../Simuleringer/fem-partikler-to-bokser.html" width="100%" height="720" style="border: 0;" loading="lazy"></iframe>

# %% [markdown]
# | $n_A$ | 0 | 1 | 2 | 3 | 4 | 5 |
# |---|---|---|---|---|---|---|
# | $\Omega(n_A)$ | |  |  |  |  |  |
#
# **a)** Finn multiplisiteten, $\Omega(n_A)$, for 0, 1 og 2 partikler i boks A og fyll inn i tabellen.
#
# **b)** Vi kan nå faktisk fylle ut resten av tabellen uten å gjøre noe regning, hvordan?
#
# **c)** Skriv deretter opp alle mikrotilstandene for $n_A=2$ og $n_A=5$.
#
#
# Se på histogrammet i simuleringen, som viser $\Omega(n_A)$ for mulige $n_A$.
#
# **d)** Hvilken makrotilstand har høyest multiplisitet? Er dette som forventet?
#
# **e)** Anta at alle mikrotilstander er like sannsynlige. Hvor sannsynlig er det at *alle* fem partiklene havner i boks A, sammenlignet med at de fordeler seg 3 i A og 2 i B?
#
# **f)** Når systemene blir større er det ikke lenger hensiktsmessig å telle eller tegne opp hver mulige tilstand. Hva er formelen for å regne ut sannynslighet, gitt en binomial fordeling?
#
# **g)** Bruk nå denne formelen til igjen å regne ut $P(3 \text{ i A})$, og sjekk at svaret stemmer med oppgaven over.
#
# **f)** Diskuter: hva tror dere skjer med *formen* på denne fordelingen dersom $N$ øker fra 5 til f.eks. 50 eller 500? Dere trenger ikke regne, bare beskriv hva dere tror skjer og hvorfor.
#
# **g)** Hvorfor er dette relevant for hvordan et termodynamisk system med et enormt antall partikler ($N \sim 10^{23}$) oppfører seg i praksis?

# %% [markdown]
# ### Oppgave 7
# I diskusjonsoppgave 5 så dere hvordan utveksling av energi til en likevektssituasjon hvor $U_A=U_B$. Vi ser nå på de samme systemene som i oppgave 5, men antar at den totale energien delt mellom de to systemene er $U_{tot}=U_A+U_B =4$. Hva er den mest sannsynlige distribusjonen av energi i dette tilfellet (hvilken distribusjon gir høyest multiplisitet)?

# %% [markdown]
# ### Oppgave 8

# %%
from IPython.display import HTML

with open("../Simuleringer/to_niva_system_2.html", "r", encoding="utf-8") as f:
    html = f.read()

HTML(html)
# Out:
# <div id="tns4-root"
#      style="font-family: -apple-system, 'Segoe UI', Helvetica, Arial, sans-serif;
#             max-width: 780px; margin: 1.5rem auto; padding: 1.5rem;
#             border: 1px solid #ddd; border-radius: 10px; background: #fafafa;">
#
#   <style>
#     #tns4-root input[type=range] {
#       accent-color: #8a7355;
#     }
#     #tns4-root .tns4-btn {
#       font-size: 13px;
#       padding: 6px 14px;
#       border: 1px solid #c9c7bd;
#       background: #eeece4;
#       color: #5f5e5a;
#       border-radius: 8px;
#       cursor: pointer;
#     }
#   </style>
#
#   <!-- Kontroller for N -->
#   <div style="display:flex; align-items:center; gap:12px; margin:0 0 6px;">
#     <label for="tns4-N"
#            style="font-size:14px; color:#444; white-space:nowrap; min-width:150px;">
#       Antall partikler N
#     </label>
#     <input type="range" id="tns4-N"
#            min="4" max="100" step="1" value="4"
#            style="flex:1;" />
# ...

# %% [markdown]
# Vi ser på $N$ uavhengige delsystemer med faste, identifiserbare plasser. Hvert delsystem kan være i en av to tilstander: **grunntilstanden** ($\epsilon=0$) eller **eksitert tilstand** ($\epsilon=\Delta\epsilon$). Makrotilstanden til systemet er bestemt av $n$, antall delsystemer i eksitert tilstand, og har total energi $E=n\Delta\epsilon$. Fordi de $N$ plassene er faste og identifiserbare, er multiplisiteten til makrotilstanden $n$ gitt ved
#
# $$\Omega(n)=\binom{N}{n}$$
#
# Obs! Legg merke til at dette er en forenkling vi kan gjøre kun når vi antar at vi har to mulige utfall. Vanligvis når vi jobber med energi som kvantiserte pakker må vi bruke Boltzmannfordelingen. Dette kommer vi tilbake til senere.
#
# **a)** Se på simuleringen over med $N=4$ partikler. Selv om systemet er i likevekt, endrer mikrotilstanden seg hele tiden. Forklar hvorfor vi likevel kan si at systemet er i *likevekt*: hva er det som faktisk holder seg noenlunde konstant når mikrotilstanden ikke gjør det?
#
# **b)** Bruk simuleringen til å øke $N$ gradvis fra $4$ til $100$. Se på hvordan fordelingen $P(n)$ endrer form. Beskriv hva som skjer med *bredden* og *høyden* på fordelingen når $N$ øker, og forklar hvorfor dette er akkurat den egenskapen som gjør at et system med $N_A\approx6\cdot10^{23}$ partikler alltid ser ut til å ha én bestemt, veldefinert makrotilstand, selv om den i prinsippet svinger fra mikrotilstand til mikrotilstand hele tiden.
#
# **c)** Energien i systemet lagres ved at flere og flere delsystemer eksiteres. Bruk simuleringen til å øke $k_BT/\Delta\epsilon$-glidebryteren (mer tilgjengelig energi relativt til $\Delta\epsilon$) og se hvordan energistigen fylles opp. Forklar sammenhengen mellom mengde tilgjengelig energi og antall mikrotilstander som er forenlige med denne energien. Blir det alltid flere tilgjengelige mikrotilstander av å øke energien? (Hint: hva skjer med $\Omega(n)$ når *nesten alle* delsystemene er eksiterte?)
#
# **d)** Den røde søylen viser systemets gjennomsnittlige totalenergi (nær $U=\langle E\rangle$, avrundet til nærmeste lovlige energiverdi), mens den *høyeste* søylen i histogrammet viser den mest sannsynlige energien. Lek med glidebryterne (spesielt $N$) og sammenlign posisjonen til den røde søylen med toppen av fordelingen. Er de alltid den samme søylen? Forklar hvorfor $U$ ikke nødvendigvis lander nøyaktig på den mest sannsynlige energien, og hva du tror skjer med denne forskjellen dersom vi simulerer $N\approx6\cdot10^{23}$ partikler i stedet.

# %% [markdown]
# ### Oppgave 9 - Ekstra utfordring
# Vi skal nå se på sammenhengen mellom sannsynlighet og entropi. Tenk på alle gasspartiklene i rommet rundt deg. Intuitivt vet du at sannsynligheten for at alle oksygen-molekylene plutselig befinner seg i det ene hjørnet av rommet er omtrent lik null, og at dette har med entropi å gjøre. k partikler N bokser
#
# I denne oppgaven vil du få bruk for Stirlings approksimasjon, $\ln n! \approx n\ln n - n$, som brukes i statistisk mekanikk for å forenkle uttrykk med store fakulteter. Denne tilnærmingen kan også skrives som $n! \approx (n/e)^n$.
#
# I diskusjons-oppgave 2 skulle dere regne ut hvordan multiplisiteten økte raskt jo flere "bokser" partiklene kunne befinne seg i. Hvis vi tenker oss at vi utvider antallet bokser til et svært stort antall, N, som representerer rommet gassmolekylene (antallet gassmolekyler er $k$) kan være i.
#
#
# **a)** Vi trekker en hvilken som helst "boks". Hva er sannsynligheten for at boksen inneholder et gassmolekyl? Hva er sannsynligheten for at boksen er tom?
#
# **b)** I tidligere oppgaver har vi uttrykt multiplisiteten som $\Omega(k,N) = \frac{N!}{k!(N-k)!}$, men med et stort antall partikler vil det ikke være praktisk mulig å regne ved bruk av fakulteter. Skriv om uttrykket ved bruk av Stirlings tilnærming.
#
# **b)** Bruk svaret fra oppgave a og b, og vis at vi kan uttrykke multiplisiteten som
#
# $\Omega(k,N) = \frac{1}{p(partikkel)^{k}p(\text{tom boks})^{N-k}}$,
#
# der $p(partikkel)$ er sannsynligheten for at boksen inneholder et gassmolekyl, og $p(\text{tom boks})$ er sannsynligheten for en tom boks.
#
# **c)** I forelesningen ble Boltzmanns entropi introdusert: $S=k_B \ln{\Omega}$. Anta nå at i stedet for et enkelt system med to mulige utfall så har vi *t* utfall hvor sannsynligheten for et gitt utfall er $p_i=\frac{n_i}{N}$. Uttrykket du kom frem til i *b* kan da skrives som $\Omega = \frac{N^N}{n_1^{n_1}n_2^{n_2}...n_i^{n_i}}=\frac{1}{p_1^{n_1}p_2^{n_2}...p_t^{n_t}}$.
#
# Bruk dette til å skrive om Boltzmanns entropi uttrykt ved multiplisitet til å uttrykke entropien ved sannsynlighet. Hvordan bidrar dette til vår forståelse av entropi?
#
# **Ekstra)** Hvor god er egentlig Stirlings approksimasjon? Test numerisk ved å sammenligne den eksakte $\ln\Omega$ med Stirlings tilnærming for $N = 8$ og $q$ fra 1 til 100. Når er tilnærmingen god? Hvis vi likevel kan regne ut eksakt $\ln\Omega$ numerisk, trenger vi egentlig Stirlings approksimasjon?
