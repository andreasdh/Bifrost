# %% [markdown]
# # Uke 1 – Statistisk mekanikk og mikro–makro-sammenhengen
# :::{admonition} Læringsutbytte
# :class: note
# Etter å ha jobbet med dette temaet skal du kunne:
#
# - forklare forskjellen mellom en mikrotilstand og en makrotilstand
# - forklare hvorfor statistiske beskrivelser er nødvendige for systemer som består av
# svært mange partikler
# - beskrive energi som en egenskap ved mikrotilstander og som en størrelse som kan
# fordeles mellom molekyler på mange ulike måter
# - forklare entropi som et mål på antall mikrotilstander som er forenlige med en gitt
# makrotilstand
# - forklare hvorfor makrotilstander med mange mikrotilstander er mer sannsynlige enn
# makrotilstander med få mikrotilstander
# :::

# %% [markdown]
# ## Diskusjonsoppgaver
#
# ### Oppgave 1
#
# **a)** Hva legger vi i begrepet multiplisitet?
#
# **b)** Hvordan vil du beskrive sammenhengen mellom multiplisitet og sannsynlighet?
#
# **c)** Hva er forskjellen på en mikrotilstand og en makrotilstand? Kom med et eksempel.
#
# **d)** Når vi jobber med partikler må vi skille mellom systemer med "distinguishable" og "indistinguishable" partikler. Kan du komme opp med en god forklaring på, og oversettelse, begrepene? Og hvordan tror du f.eks. multiplisitet vil påvirkes av hvilke type partikler man jobber med?

# %% [markdown]
# ### Oppgave 2 - basert på 2.2 i Dill
# utvide med å skalere opp antallet bokser og/eller antallet partikler

# %% [markdown]
# ### Oppgave 3 - basert på 2.3 i Dill
# Skalere opp med antallet partikler - python script - hva skjer når man kommer over f.eks. 10 000 molekyler (regn ut volumet av en vanndråpe med 10 000 molekyler).

# %% [markdown]
# ### Oppgave 4 - basert på 2.4 i Dill
#
# Hint: tegn opp de ulike konformasjonene for hver lengde av utstrekning

# %% [markdown]
# ### Oppgave 5 - Baser på 3.9 i Dill

# %% [markdown]
# ## Regneoppgaver
#
# ### Oppgave 6
#
# Vi har et system av $N = 5$ partikler, fordelt mellom to bokser, boks A og boks B. Hver partikkel kan befinne seg i enten den ene eller den andre boksen.

# %%
from IPython.display import HTML

with open("../Simuleringer/fem-partikler-to-bokser.html", "r", encoding="utf-8") as f:
    html = f.read()

HTML(html)

# %% [markdown]
# **a)** Hvor mange forskjellige mikrotilstander finnes det totalt for dette systemet?
#
# **b)** La makrotilstanden være gitt ved hvor mange partikler som befinner seg i boks A, altså $n_A$. Hvilke makrotilstander er mulige?
#
# **c)** Regn ut hvor mange mikrotilstander som gir opphav til hver av makrotilstandene, altså multiplisiteten $\Omega(n_A)$ for hver $n_A$. Skriv deretter opp alle mikrotilstandene for $n_A=2$ og $n_A=5$.
#
# Se på histogrammet i simuleringen, som viser $\Omega(n_A)$ for mulige $n_A$.
#
# **d)** Hvilken makrotilstand har høyest multiplisitet? Er dette som forventet?
#
# **e)** Anta at alle mikrotilstander er like sannsynlige. Hvor sannsynlig er det at *alle* fem partiklene havner i boks A, sammenlignet med at de fordeler seg 3 i A og 2 i B?
#
# **f)** Diskuter: hva tror dere skjer med *formen* på denne fordelingen dersom $N$ øker fra 5 til f.eks. 50 eller 500? Dere trenger ikke regne, bare beskriv hva dere tror skjer og hvorfor.
#
# **g)** Hvorfor er dette relevant for hvordan et termodynamisk system med et enormt antall partikler ($N \sim 10^{23}$) oppfører seg i praksis?

# %% [markdown]
# ## Regneoppgaver
#
# ### Oppgave 7
#
# Stirlings approksimasjon $\ln n! \approx n\ln n - n$ brukes i statistisk mekanikk for å forenkle uttrykk med store fakulteter.
#
# **a)** Bruk Stirlings approksimasjon på $\Omega(q, N) = \frac{(q+N-1)!}{q!(N-1)!}$ og vis at:
#
# $$\ln\Omega \approx (q+N)\ln(q+N) - q\ln q - N\ln N$$
#
# (for store $q$ og $N$, slik at $q+N-1 \approx q+N$ og $N-1 \approx N$).
#
# **b)** Bruk dette til å utlede at likevektsbetingelsen $\frac{d}{dq_A}\ln\Omega_\mathrm{tot} = 0$ gir $\frac{q_A}{N_A} = \frac{q_B}{N_B}$, altså $T_A = T_B$ med $T = q/N$. **hvor har de T=q/N fra?**
#
# **c)** Test numerisk ved å sammenligne den eksakte $\ln\Omega$ med Stirlings tilnærming for $N = 8$ og $q$ fra 1 til 100. Når er tilnærmingen god?
#
# ### Oppgave 8 bytte med oppgave fra Dill?
#
# Et system kan befinne seg i ett av tre energinivåer: $E_0=0$, $E_1=\varepsilon$ og $E_2=2\varepsilon$. Ved en gitt temperatur $T$ er sannsynligheten for å finne systemet i hvert nivå gitt i tabellen under:
#
# | Energinivå | Energi | Sannsynlighet |
# |---|---|---|
# | Grunntilstand | $E_0 = 0$ | $P(E_0) = 0.65$ |
# | Første eksiterte | $E_1 = \varepsilon$ | $P(E_1) = 0.25$ |
# | Andre eksiterte | $E_2 = 2\varepsilon$ | $P(E_2) = 0.10$ |
#
#
# **a)** Gjennomsnittsenergien, også kalt den *indre energien* $U$, finner vi ved å vekte hver energi med sannsynligheten for at den forekommer:
#
# $$U = \langle E \rangle = \sum_i E_i \, P(E_i)$$
#
# Regn ut $U$ for fordelingen over, uttrykt i enheter av $\varepsilon$.
#
# **b)** Ved en høyere temperatur er sannsynlighetene i stedet gitt ved $P(E_0)=0.40$, $P(E_1)=0.35$ og $P(E_2)=0.25$. Regn ut $U$ også for denne fordelingen.
#
# **c)** Sammenlign svarene i a) og b). Stemmer dette med det dere forventer om sammenhengen mellom temperatur og indre energi?
#
#
# ### Oppgave 9
#
# Et system av 5 partikler kan fordele seg mellom to bokser, A og B (som i oppgave 2). Antall partikler i boks A kaller vi $n_A$. Multiplisiteten $\Omega(n_A)$, er gitt i tabellen under:
#
# | $n_A$ | 0 | 1 | 2 | 3 | 4 | 5 |
# |---|---|---|---|---|---|---|
# | $\Omega(n_A)$ | 1 | 5 | 10 | 10 | 5 | 1 |
#
# **a)** Det totale antallet mikrotilstander er $2^5=32$. Bruk dette til å regne om hver $\Omega(n_A)$ til en sannsynlighet $P(n_A) = \Omega(n_A)/32$.
#
# **b)** Regn ut gjennomsnittlig antall partikler i boks A:
#
# $$\langle n_A \rangle = \sum_{n_A=0}^{5} n_A \, P(n_A)$$
#
# **c)** Er svaret det dere ville forventet, gitt hvordan fordelingen ser ut? Begrunn kort.
#
# **d)** Hva er sannsynligheten for at *minst* 4 av de 5 partiklene befinner seg i boks A?
#
#
# ### Oppgave 10 - flytt - bytte ut med en utledningsoppgave om boltzmanns-fordelingen? Evt en oppgave om å sammenlikne boltzmann og normalfordeling?
