# %% [markdown]
# # Uke 7 – Termokjemi
#
# ## Diskusjonsoppgaver
#
# ### Oppgave 1
#
# **a)** Hva sier Hess lov?
#
# **b)** Gitt følgende delprosesser for dannelsen av diboran ${B_2H_6}_{(g)}$:
#
# (1) ${B_2H_6}_{(g)} + 3 {O_2}_{(g)} \longrightarrow {B_2O_3}_{(s)} + 3 {H_2O}_{(g)}$
#
# (2) $2 B_{(s)} + \frac{3}{2} {O_2}_{(g)} \longrightarrow {B_2O_3}_{(s)}$
#
# (3) ${H_2}_{(g)} + \frac{1}{2} {O_2}_{(g)} \longrightarrow H_2O_{(g)}$
#
# Hvordan ville du satt opp uttrykket for dannelsesentalpien $\Delta _fH^{\circ}$ av diboran ved hjelp av Hess lov? (Tips: Husk at det er lov å snu likninger for at reaksjonen skal gå "riktig" vei i forhold til prosessen du ønsker å studere, men husk da hva som skjer med entalpiendringen!)
#
# ### Oppgave 2
#
# **a)** Hva er entalpi og hvorfor er entalpi så nyttig i kjemi?
#
# **b)** Hva er forskjellen på en endoterm og en eksoterm prosess og hvilken sammenheng har disse begrepene med fortegnet til entalpiendringen $\Delta H$?
#
# **c)** Hvor kommer de tabulerte verdiene for dannelsesentalpier fra og hvorfor er de et nyttig verktøy?
#
# **d)** Kan vi si noe om entalpiendring basert på de mikroskopiske egenskapene til stoffene som er involvert i prosessen? Bruk animasjonen under til å hjelpe deg i forklaringen din!

# %%
from IPython.display import HTML

with open("../Simuleringer/eksoterm_endoterm_energigap.html", "r", encoding="utf-8") as f:
    html = f.read()

HTML(html)
# Out:
# <!DOCTYPE html>
# <html lang="no">
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width, initial-scale=1.0">
# <title>Eksoterm og endoterm prosess</title>
# <style>
# :root {
#   --bg: #ffffff;
#   --text-primary: #2C2C2A;
#   --text-secondary: #5F5E5A;
#   --border: #B4B2A9;
#   --line: #444441;
# }
#
# * { box-sizing: border-box; }
#
# body {
#   background: var(--bg);
#   color: var(--text-primary);
#   font-family: -apple-system, BlinkMacSystemFont, "Segoe UI", Roboto, Helvetica, Arial, sans-serif;
#   margin: 0;
#   padding: 32px 16px;
#   display: flex;
#   justify-content: center;
# }
#
# .card { max-width: 700px; width: 100%; }
#
# svg text { font-family: inherit; fill: var(--text-primary); }
# .th { font-size: 14px; font-weight: 600; }
# .ts { font-size: 12px; fill: var(--text-secondary); }
#
# .sr-only {
#   position: absolute;
#   width: 1px; height: 1px;
#   padding: 0; margin: -1px;
#   overflow: hidden;
#   clip: rect(0,0,0,0);
# ...

# %% [markdown]
# **e)** Kan du komme på noen eksempler fra labkursene du har tatt hvor du har måttet ta hensyn til entalpiendring?
#
# ### Oppgave 3
#
# I Organisk Kjemi 1 møtte dere på Wittig-reaksjonen! Under kan du se reaksjonslikningen for en typisk Wittig-reaksjon:
#
# ![Wittig-reaksjonen](../bilder/Wittig.png)
#
# **a)** Hva slags entalpiendring forventer du for denne reaksjonen? Hvorfor?
#
# **b)** Forklar hvorfor Wittig-reaksjonen typisk gjøres ved $0 ^{\circ} C$.
#
#
# ### Oppgave 4
#
# **a)** Forklar kort og kvalitativt hva som kjennetegner entropien i de ulike aggregattilstandene gass, væske og fast stoff.
#
# **b)** Hvordan kan aggregattilstander hjelpe oss å vurdere entropiendring i løpet av en prosess? Vurder entropiendring for følgende prosesser:
#
# - Vann som koker
# - Et løsemiddel kondenserer når det når en kjøler¨
# - Et salt løses i vann
#
# **c)** Vi har følgende kjemiske prosess: $A \longrightarrow B + C$. Du trenger ikke tenke på aggregattilstander.
#
# - Vurder kvalitativt entropiendringen du får fra prosessen.
# - Hvordan forklarer du dette mikroskopisk? (Hint: Her kan du bruke lattice modell og Boltzmanns entropi i forklaringen din 😊)
#
# **d)** Hva må vi passe spesielt på dersom vi blir bedt om å vurdere entropiendring for løsning av salter med små kationer som $Li^+$, $Mg^{2+}$ og $Al^{3+}$?
#
# **e)** Bruk animasjonen til å forklare hvordan entropisk ugunstige prosesser allikevel overholder termodynamikkens 2. lov.

# %%
from IPython.display import HTML

with open("../Simuleringer/entalpi-entropi-samspill.html", "r", encoding="utf-8") as f:
    html = f.read()

HTML(html)
# Out:
# <!DOCTYPE html>
# <html lang="no">
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width, initial-scale=1.0">
# <title>Entalpi og entropi i samspill</title>
# <style>
#   :root{
#     --ink:#2b2a27;
#     --paper:#faf8f4;
#     --card:#ffffff;
#     --line:#ddd8cd;
#     --system:#c0562f;
#     --system-dark:#8a3d20;
#     --ligand:#e0862f;
#     --surroundings:#3a6ea5;
#     --surroundings-dark:#274a72;
#     --heat:#d94f30;
#     --good:#4d7a3a;
#     --font: "Iowan Old Style","Palatino Linotype",Georgia,serif;
#     --font-ui: -apple-system, "Segoe UI", Helvetica, Arial, sans-serif;
#   }
#   *{box-sizing:border-box;}
#   body{
#     margin:0;
#     background:var(--paper);
#     color:var(--ink);
#     font-family:var(--font-ui);
#     padding:32px 16px 48px;
#     display:flex;
#     justify-content:center;
#   }
#   .card{
#     max-width:760px;
#     width:100%;
#     background:var(--card);
#     border:1px solid var(--line);
# ...

# %% [markdown]
# ### Oppgave 5
#
# **a)** Hvilke makroskopiske parametere holdes gjerne konstant når vi benytter oss av Gibbs fri energi?
#
# **b)** Hva betyr det at en prosess er spontan? Hva er _endergone_ og _eksergone_ prosesser? Vil alle spontane prosesser skje raskt?
#
# **c)** Hva mener vi med at en prosess er entalpisk eller entropisk drevet? Hva betyr dette matematisk i uttrykket for Gibbs fri energi?
#
# **d)** Forbrenningen av etanol i luft skjer på følgende måte:
#
# $$C_2H_5OH_{(l)} + 3 {O_2}_{(g)} \longrightarrow 2 {CO_2}_{(g)} + 3 H_2O_{(g)}$$
#
# Og har entalpiendring lik $\Delta H = -1368 kJ/mol$.
#
# Hva tror du driver denne prosessen fremover? Hvorfor er vi ikke redde for ha en flaske etanol stående i luft når forbrenningen er såpass spontan?
#
# ### Oppgave 6
#
# Under kan du se strukturen til den kationiske surfaktanten Tetradecyl trimetylammonium bromid ($C_{14}-TAB$):
#
# ![$C_14-TAB$](../bilder/C14TAB.png)
#
# Kalorimetriske målinger tatt ved å løse $C_{14}-TAB$ i vann ga følgende verdier for entalpi- og entropiendring: $\Delta H = -13 kJ/mol$ og $\Delta S = 103 J/Kmol$.
#
# **a)** Gi en kvalitativ forklaring på disse verdiene ved hjelp av animasjonen. (Tips: Google hva en surfaktant er hvis du er usikker). Bonus: Hva tror du skjer dersom vi forsøker å løse mange $C_{14}-TAB$ molekyler i vann? Tenk på den hydrofobiske effekten.

# %%
from IPython.display import HTML

with open("../Simuleringer/c14tab-hydratisering-automatisk.html", "r", encoding="utf-8") as f:
    html = f.read()

HTML(html)
# Out:
# <!DOCTYPE html>
# <html lang="no">
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width, initial-scale=1.0">
# <title>C&#8321;&#8324;-TAB i vann (automatisk)</title>
# <style>
#   :root{
#     --ink:#2b2a27;
#     --paper:#faf8f4;
#     --card:#ffffff;
#     --line:#ddd8cd;
#     --cation:#3a6ea5;
#     --cation-dark:#274a72;
#     --tail:#4a4a46;
#     --oxygen:#c0392b;
#     --oxygen-dark:#8a2f22;
#     --hydrogen:#f5f1e8;
#     --hbond:#b9832f;
#     --font: "Iowan Old Style","Palatino Linotype",Georgia,serif;
#     --font-ui: -apple-system, "Segoe UI", Helvetica, Arial, sans-serif;
#   }
#   *{box-sizing:border-box;}
#   body{
#     margin:0; background:var(--paper); color:var(--ink);
#     font-family:var(--font-ui); padding:32px 16px 48px;
#     display:flex; justify-content:center;
#   }
#   .card{
#     max-width:780px; width:100%; background:var(--card);
#     border:1px solid var(--line); border-radius:14px; padding:28px 32px 32px;
#   }
# ...

# %% [markdown]
# **b)** Hvordan kan vi få ikke-spontane prosesser til å gå?
#
#
# ## Regneoppgaver
#
# ### Oppgave 7
#
# Vi kan finne den molare smelteentalpien $\Delta H_{fus}$ til is ved hjelp av et kalorimetri eksperiment! Kalorimeteret vårt er en kaffekopp i isopor og vi antar at denne er _fullstendig termisk isolert_. Vi veier ut 25.8 g is og legger det oppi kaffekoppen som inneholder 100.0 g vann med en temperatur på $35.4 ^{\circ} C$. Vi setter på et lokk og monterer et termometer som måler temperaturen til blandingen. Etterhvert er isen smeltet og temperaturen har sunket til $18.1 ^{\circ} C$. Varmekapasiteten til vann ved konstant trykk er $4.18 J.g^{-1}.K^{-1}$.
#
# **a)** Hvilke entalpiendringer har vi i løpet av prosessen? Hvilken lov må vi ta i bruk?
#
# **b)** Hva finner du for $\Delta _m H_{fus}$? Husk at vi ønsker den molare entalpien!
#
# **c)** Hvilke feilkilder har eksperimentet vårt gitt at den teoretiske verdien til smelteentalpien til vann er $6.01 kJ/mol$?
#
# **d)** Beregne standard molar løsningsentalpi for $AgBr(s)$ i vann fra standard molare dannelsesentalpiene for det faste stoffet og for de to ionene i vann (finn verdier i pensumboka). Er dette en eksoterm eller endoterm prosess? Hvorfor?
#
# ### Oppgave 8
#
# **a)** Standard molar dannelsesentalpi for fenol er $-165.0 kJ/mol$. Finn relevante verdier i pensumboka og bruk Hess´ lov til å beregne standard molar forbrenningsentalpi for fenol. Er reaksjonen endoterm eller eksoterm?
#
# **b)** Beregn standard molar dannelsesentalpi for $NOCl_{(g)}$ utifra følgende informasjon:
#
# Standard molar dannelsesentalpi for $NO_{(g)}$ er $90.25 \, kJ/mol$
#
# Reaksjonen $2 \, NOCl_{(g)} \longrightarrow 2 \, NO_{(g)} + {Cl_2}_{(g)} $ har standard molar reaksjonsentalpi $\Delta _rH ^{\circ} = 75.5 \, kJ/mol $
#
# **c)** Følgende reaksjoner og tilhørende standard molare reaksjonsentalpier er gitt:
#
# $${Fe_2O_3}_{(s)} + 3 C(grafitt) \longrightarrow 2 Fe_{(s)} + 3 CO_{(g)}; \Delta H_m^{\circ} = 492.6 \, kJ/mol$$
#
# $$C(grafitt) + {O_2}_{(g)} \longrightarrow {CO_2}_{(g)}; \Delta H_m^{\circ} = − 393.51 \, kJ/mol$$
#
# $$CO_{(g)} + \frac{1}{2} {O_2}_{(g)} \longrightarrow {CO_2}_{(g)}; \Delta H_m^{\circ} = − 282.98 \, kJ/mol$$
#
# Beregne standard molar dannelsesentalpi $\Delta _f H_m^{\circ}$ for ${Fe_2O_3}_{(s)}$.
#
#
# ### Oppgave 9
#
# $\Delta _{f}H_m^{\circ}$ for $KCl_{(s)}$, $K^+_{(aq)}$ og $Cl^-_{(aq)}$ er hhv $−436.75$, $−252.38$ og $–167.16 \, kJ/mol$.
# $S_m^{\circ}$ for $KCl_{(s)}$, $K^+_{(aq)}$ og $Cl^-_{(aq)}$ er hhv $82.6$, $102.5$ og $56.5 \, J.K^{−1}.mol^{−1}$.
#
# **a)**	Regn ut $\Delta H_m^{\circ}$ $\Delta S_m^{\circ}$ og $\Delta G_m^{\circ}$  for prosessen:
#
# $$KCl_{(s)} \longrightarrow K^+_{(aq)} + Cl^−{(aq)}$$
#
# **b)**	Hva er den termodynamiske drivkraften som får $KCl$ til å løse seg i vann? Hva skjer på molekylært nivå? Gi en kort begrunnelse for svaret.
#
# **c)**	Vil løseligheten av $KCl$ i vann øke eller avta når temperaturen øker? Gi en kort begrunnelse for svaret.
#
# ### Oppgave 10
#
# Beregn standard molar Gibbs energi for reaksjonen
#
# $$CO_{(g)} + CH_3OH_{(l)} \longrightarrow CH_3COOH_{(l)}$$
#
# ved $298 \, K$, ut fra standard molare dannelsesentropier og –entalpier du finner i pensumboka.
#
# ### Oppgave 11
#
# Standard molar entropi for benzen er $173.3 J.K^{-1}.mol^{-1}$. Lag en funksjon som beregner endringen i standard molar Gibbs energi når benzen varmes opp fra $25.0 ^{\circ}C$ til en variabel sluttemperatur. Plott $∆G$ for oppvarminger i området $25.0 °C$ til $45.0 °C$. Hint! Start med å finne den differensiale formen av Gibbs fri energi.
