# %% [markdown]
# # Uke 3 – Kinetisk gassteori

# %% [markdown]
# ## Diskusjonsoppgaver
#
# ### Oppgave 1
#
# **a)** Både trykk og temperatur kan forklares på to nivåer. Forklar hva de er **makroskopisk** (målbare størrelser i laben) og **mikroskopisk** (ut fra molekylenes bevegelse), og knytt nivåene sammen. Bruk gjerne språket om *mikrotilstand* og *makrotilstand*.
#
# **b)** Det vises at temperatur og energi *ikke* er det samme, selv om de henger tett sammen. Bruk eksempelet med smeltende is til å forklare forskjellen: hvor blir det av energien når temperaturen står stille?
#
# c) Vi skiller mellom *intensive* og *ekstensive* egenskaper. Forklar forskjellen (bruk gjerne volum $V$ og antall molekyler $N$ som eksempler på det ene), og avgjør om trykk og temperatur er intensive eller ekstensive.
#
# d) Hvorfor gir det ikke mening å snakke om «trykket» eller «temperaturen» til ett enkelt molekyl? Se svaret i sammenheng med at begge er *statistiske* størrelser.
#
# ### Oppgave 2
#
# **a)** Vi begynner med å forklare *hvorfor* vi starter med gasser. Hva er det med hvordan molekylene er organisert i en fortynnet gass som gjør den så mye enklere å beskrive enn en væske eller et fast stoff?
#
# **b)** Hvilke to antakelser gjør ideelle gassmodellen om molekylene (størrelse og krefter)?
#
# **c)** I virkeligheten er ingen gass helt ideell. Forklar de to avvikene fra Del 4: molekylenes eget volum og de intermolekylære tiltrekningskreftene. Det ene trekker trykket **opp** og det andre **ned** — hvilket er hvilket, og hvorfor?
#
# **d)** Under hvilke betingelser (tetthet, trykk, temperatur) er ideelle gassmodellen god, og når bryter den sammen? Se på eksempelboksen under og begrunn.
#
# :::{admonition} Eksempel: to gasser, samme lov? 🤨
# :class: card
#
# Tenk deg to beholdere ved romtemperatur og 1 atm: én med **helium** (He) og én med **karbondioksid** (CO₂).
#
# - Helium er små, tilnærmet strukturløse atomer med svært svake tiltrekningskrefter.
# - CO₂ er større molekyler med merkbart sterkere tiltrekning.
#
# **Diskuter:** Hvilken av de to forventer du følger $PV = nRT$ best ved disse betingelsene? Hva skjer med svaret om du komprimerer begge til svært høyt trykk, eller kjøler dem kraftig ned? Koble svaret til de to avvikene i oppgave 2c.
# :::
#
# **e)** Tabellen gir hver størrelse i $PV = nRT$ en mikroskopisk betydning. Velg $P$ og $T$, og forklar med egne ord hva de «er» på molekylnivå. Hva forteller tilstandslikningen oss om systemet — og hva forteller den oss *ikke*?
#
# | Symbol | Mikroskopisk betydning |
# | --- | --- |
# | **$P$ (Trykk)** | Hvor hardt og hvor ofte molekylene kolliderer med veggen. |
# | **$V$ (Volum)** | Hvor stort rom partiklene har å bevege seg i (og dermed hvor lang tid det går mellom hver kollisjon). |
# | **$N$ (Antall)** | Hvor mange molekyler som er med på å dytte. |
# | **$T$ (Temperatur)** | Et direkte mål på partiklenes gjennomsnittlige kinetiske energi (hvor fort de beveger seg). |
#
#
# ### Oppgave 3
#
# **a)** Kapitlet understreker at $f(v)$ beskriver *sannsynligheten* (eller andelen) for at et molekyl har en bestemt fart – ikke antallet. Forklar hva det betyr at $f(v)$ er en **sannsynlighetstetthet**, og hvorfor det er $f(v)\,dv$, ikke $f(v)$ alene, som er en sannsynlighet.
#
# **b)** Hva blir arealet under hele kurven til $f(v)$, og hvorfor må det være slik? (normalisering)
#
# **c)** I simuleringen tilsvarer «andelen raskere enn $v^*$» det skraverte **arealet** under kurven til høyre for terskelen. Hvordan finner du generelt andelen molekyler med fart mellom $v_1$ og $v_2$ — er det høyden eller arealet som er relevant?
#
# **d)** Sim-spørsmål 2 viste at hvis du dobler både $V$ og $N$ ved samme temperatur, ser kurven **nøyaktig lik ut**. Forklar hvorfor, og koble det til at fordelingen (og temperaturen) er en *intensiv* størrelse.
#
# ### Opggave 4
#
# Maxwell-Boltzmann-distribusjonen som funksjon av fart er gitt ved
#
# $$ f(v) = 4\pi \left( \frac{m}{2\pi k_B T}  \right)^{3/2} v^2 \exp{-\frac{mv^2}{2k_B T}},$$
#
# der $v$ er farten, $m$ er massen, $T$ er temperaturen og $k_B$ er Boltzmanns konstant.
#
# > Simuleringen viser en 2D-gass med ekte elastiske kollisjoner. Venstre panel viser molekylene (fargen=farten), høyre panel viser fartsfordelingen (blått histogram) mot den teoretiske Maxwell-Boltzmann-kurven (oransje). Nederst leser du av tre farter og en temperatur, og en måler viser hvor nær likevekt gassen er.
#
# **a)**
# *Velg starttilstanden «Allerede i likevekt». Se på konvergensmåleren og histogrammet med én gang.*
# Hva står måleren på fra start? Passer det blå histogrammet med den oransje kurven umiddelbart? Hva betyr det at gassen «er i likevekt fra start»?
#
# **b)**
# *Velg «Alle i ro unntatt én rask partikkel» og trykk «Start på nytt». Se på histogrammet og måleren i det øyeblikket du starter.*
# Hvordan ser fordelingen ut helt i begynnelsen? Hva står konvergensmåleren på — grønt eller rødt?
#
# **c)**
# *La den samme simuleringen kjøre videre uten å røre noe. Følg med på både histogrammet og måleren.*
# Beskriv hvordan histogrammet endrer seg over tid. Hva skjer med måleren, og hvor lang tid tar det før den når «i likevekt»?
#
# **d)**
# *Trykk «Start på nytt» og velg i stedet «Alle med samme fart». La den kjøre til måleren blir grønn.*
# Ender denne opp med samme kurve som i c), selv om starten var helt annerledes? Hva forteller det deg om Maxwell–Boltzmann-fordelingen?
#
# **e)**
# *Velg «Allerede i likevekt» så du starter rolig. Dra temperatur-skyveren opp mot maks, og se på histogrammet og de tre fartene.*
# Hva skjer med hele fordelingen når temperaturen øker — flytter den seg, blir den bredere, smalere? Hva skjer med $v_\text{rms}$?
#
# **f)**
# *Dra temperaturen helt ned mot minimum i stedet.*
# Hvordan ser fordelingen ut nå sammenlignet med høy temperatur? Hvor er den samlet?
#
# **g)**
# *Se på tallet $T$ mens en simulering kjører (velg gjerne «én rask partikkel» og la den konvergere).*
# Endrer $T$ seg mens histogrammet forandrer form? Hvorfor / hvorfor ikke?
#
# **h)**
# *Sett temperaturen til en fast verdi (f.eks. midt på). Sett massen til 1×, noter omtrent hvor fordelingen ligger, og dra så masse-skyveren opp til 8×.*
# Hva skjer med fartene når molekylene blir tyngre? Blir de raskere eller tregere ved samme temperatur?
#
# **i)**
# *Tenk på et virkelig eksempel: en blanding av lette hydrogenmolekyler (H₂) og tunge oksygenmolekyler (O₂) ved samme temperatur.*
# Ut fra det du så i h): hvilke av de to beveger seg raskest i snitt? Hvorfor?
#
# **j)**
# *Se på de tre avlesningene: $\bar{v}$ (snitt), $v_\text{rms}$ og $v_\text{mp}$ (mest sannsynlig).*
# Er de tre tallene like store, eller er det et fast mønster i hvilken som er størst og minst? Prøv ved ulike temperaturer — holder mønsteret seg?

# %%
from IPython.display import HTML

with open("Maxwell.html", "r", encoding="utf-8") as f:
    html = f.read()

HTML(html)
# Out:
# <!DOCTYPE html>
# <html lang="no">
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width, initial-scale=1.0">
# <title>Maxwell–Boltzmann: hvordan gassen finner sin fordeling</title>
# <style>
#   :root{
#     --ink:#101820;
#     --panel:#16212e;
#     --panel-2:#1d2b3a;
#     --line:#2c3e52;
#     --hist:#5b9bd5;
#     --hist-edge:#8fc0ee;
#     --theory:#e8a13a;
#     --text:#dfe8f0;
#     --muted:#8fa3b5;
#     --accent:#e8a13a;
#     --good:#6fcf97;
#     --warn:#e57373;
#     --track:#2c3e52;
#   }
#   *{box-sizing:border-box;}
#   body{
#     margin:0; padding:24px;
#     background:#f4f1ea;
#     font-family:"Iowan Old Style","Palatino Linotype",Palatino,Georgia,serif;
#     color:var(--text);
#     display:flex; justify-content:center;
#   }
#   .card{
#     width:100%; max-width:860px;
#     background:var(--ink);
#     border-radius:18px;
#     padding:28px 30px 32px;
#     box-shadow:0 12px 40px rgba(0,0,0,.28);
#   }
#   h1{
# ...

# %% [markdown]
# ## Regneoppgaver
#
# Bruk $R = 8{,}314\ \text{J mol}^{-1}\text{K}^{-1}$ og $1\ \text{atm} = 101{,}325\ \text{kPa}$ der ikke annet er oppgitt. Anta ideell gass i alle oppgavene med mindre noe annet står.
#
# ### Oppgave 5
#
# Massetettheten til et stoff er definert som $\rho = m/V$.
#
# **a)** Vis at tettheten til en gass kan skrives ved den molare massen $M$ og det molare volumet $V_m$ som
#
# $$\rho = \frac{M}{V_m}.$$
#
# **b)** Ta utgangspunkt i tilstandsligningen $PV = nRT$ og vis at tettheten kan uttrykkes ved trykk og temperatur som
#
# $$\rho = \frac{PM}{RT}.$$
#
# Hva forteller dette resultatet deg om sammenhengen mellom tetthet og molar masse ved fast trykk og temperatur?
#
# **c)** Tørr luft har midlere molar masse $M = 28{,}96\ \text{g/mol}$. Beregn tettheten til luft ved $25\ ^\circ\text{C}$ og $1\ \text{atm}$. Er svaret rimelig?
#
# ### Oppgave 6
#
# I et forsøk skal den molare massen til en ukjent gass bestemmes. En prøve på $0{,}583\ \text{g}$ fyller et volum på $0{,}250\ \text{dm}^3$. Ved $303\ \text{K}$ måles trykket til $101{,}3\ \text{kPa}$.
#
# **a)** Beregn den molare massen $M$ til gassen. Hvilke(t) stoff kan dette være?
#
# **b)** Den *samme, lukkede* beholderen (samme volum, samme gassmengde) varmes opp til $317\ \text{K}$. Beregn det nye trykket i beholderen.
#
#
# ### Oppgave 7
#
# Til en beholder med volum $V = 2{,}50\ \text{L}$ tilsettes $100{,}00\ \text{g}$ nitrogen ($\text{N}_2$) og $100{,}00\ \text{g}$ karbondioksid ($\text{CO}_2$). Temperaturen holdes på $25\ ^\circ\text{C}$.
#
# **a)** Beregn antall mol av hver gass og molbrøken $x_i$ til hver komponent.
#
# **b)** Beregn partialtrykket til hver gass direkte fra $P_i = n_i RT / V$.
#
# **c)** Bruk Daltons lov til å finne totaltrykket $P_\text{tot}$, og kontroller at $P_\text{tot} = P_{\text{N}_2} + P_{\text{CO}_2}$.
#
# **d)** Trykket du finner er høyt. Vil du forvente at idealgassmodellen er en god tilnærming her? Hvilken av de to gassene tror du avviker mest fra ideell oppførsel, og hvorfor? (Knytt gjerne til boksen om reelle gasser.)
#
# ### Ooppgave 8
#
# Ved industriell produksjon av ammoniakk injiseres nitrogen i en tank med volum $V_1 = 100\ \text{m}^3$ ved trykk $P_1 = 100\ \text{atm}$ og temperatur $T_1 = 300\ \text{K}$.
#
# **a)** Gassen varmes opp til driftstemperatur $T_2 = 500\ \text{K}$ ved *konstant volum*. Beregn det nye trykket $P_2$.
#
# **b)** Fra tilstanden i **a)** ($500\ \text{K}$, $166{,}7\ \text{atm}$) komprimeres gassen til $V_3 = 10\ \text{m}^3$ mens temperaturen holdes på $500\ \text{K}$. Beregn det nye trykket $P_3$.
#
# **c)** Forklar med egne ord hva som menes med *partialtrykk*.
#
# **d)** Vi går tilbake til tilstanden i **a)** ($100\ \text{m}^3$, $500\ \text{K}$, ren $\text{N}_2$ ved $166{,}7\ \text{atm}$). Nå tilsettes $1000\ \text{mol}$ argon.
#
# - Beregn først hvor mange mol $\text{N}_2$ tanken inneholder.
# - Beregn partialtrykket til argon og det nye totaltrykket.
# - Kommenter: hvor stor andel av totaltrykket skyldes argonet? Hva forteller det deg om hvor mange molekyler som allerede er i tanken?
#
# **e) (Bonus)** Hvor mange mol argon måtte du ha tilsatt for å øke totaltrykket med $10\ \%$? Sammenlign med de $1000\ \text{mol}$ i **d)**.

# %%
from IPython.display import HTML

with open("../Simuleringer/ekspansjon.html", "r", encoding="utf-8") as f:
    html = f.read()

HTML(html)
# Out:
# <style>
# @keyframes flick { 0%,100%{opacity:1} 50%{opacity:.78} }
# #flames path { transform-box: fill-box; transform-origin: bottom; }
# @media (prefers-reduced-motion: no-preference){
#   #flames path:nth-child(odd){ animation: flick .7s ease-in-out infinite; }
#   #flames path:nth-child(even){ animation: flick .9s ease-in-out infinite .2s; }
# }
# .hbctl { display:flex; align-items:center; gap:12px; margin:10px 0 0; font-size:13px; color:var(--text-secondary); }
# .hbctl input[type=range]{ flex:1; }
# .hbread { display:flex; gap:12px; margin-top:14px; }
# .hbcard{ flex:1; background:var(--surface-1); border-radius:8px; padding:10px 12px; }
# .hbcard .lab{ font-size:12px; color:var(--text-secondary); }
# .hbcard .val{ font-size:22px; font-weight:500; color:var(--text-primary); font-variant-numeric:tabular-nums; }
# </style>
# <svg width="100%" viewBox="0 0 680 430" role="img">
# <title>Interaktivt tverrsnitt av Haber–Bosch-reaktoren</title>
# ...

# %% [markdown]
# > Simuleringen viser industriell ammoniakkproduksjon, $\text{N}_2 + 3\text{H}_2 \rightleftharpoons 2\text{NH}_3$ (blå = N₂, grønne = H₂), der jern-katalysatoren bryter bindingene så atomene kan danne NH₃ raskere. Med **trykk** øker utbyttet, fordi reaksjonen går fra 4 gassmolekyler til 2 og høyt trykk favoriserer den siden. **Temperatur** er en avveining: reaksjonen er eksoterm, så lav temperatur gir høyest utbytte, men gjør reaksjonen treg. Ingen innstilling er best på begge fronter, derfor er ekte Haber–Bosch et kompromiss (~450 °C, ~200 atm, katalysator). Dra i skyverne og finn den beste balansen.
