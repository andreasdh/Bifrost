# %% [markdown]
# # Makroskopisk termodynamikk II
#
# I forrige kapitell _Makroskopisk termodynamikk I_ lærte du om noen viktige størrelser i klassisk termodynamikk samt om de fire termodynamiske potensialene indre energi U, entalpi H, Helmholtz fri energi F og Gibbs fri energi G. I dette kapitellet skal vi ta anvendelsen av disse størrelsene et steg videre og lære om termodynamiske drivkrefter.
#
# ## Termodynamiske drivkrefter matematisk og praktisk
#
# Varme strømmer fra varmt til kaldt, gasser beveger seg fra høyt trykk til lavt trykk, stoffer diffunderer fra områder med høy konsentrasjon til områder med lav konsentrasjon. Dette virker kanskje intuitivt for oss, men hvorfor skjer disse prosessene egentlig? Hva har de til felles? Bak dem ligger de _termodynamiske drivkreftene_. Først skal vi se på hvordan vi matematisk kan definere de termodynamiske potensialene fra tilstandsfunksjonene. Dette gir opphav til _fundamentallikningene_, den matematiske definisjonen av de termodynamiske drivkreftene og _Maxwell-relasjonene_. Deretter skal vi gå videre til termokjemi.
#
# ### Fundamentallikningen for indre energi i et lukket system
#
# La oss starte fra definisjonen av indre energi igjen:
#
# $$\Delta U = q + w$$
#
# I stedet for definisjonen som inneholder stifunksjonene arbeid og varme ønsker vi nå å finne ut av hvordan vi kan uttrykke den indre energien ved hjelp av tilstandsfunksjoner som temperatur, trykk, volum og entropi. Vi benytter oss av noen uttrykk fra de forrige kapitlene og finner et nytt uttrykk for dU:
#
# $$dS = \frac{dq}{T} \leftrightarrow dq = TdS$$
# $$dw = -pdV$$
# $$dU = TdS - pdV$$
#
# Dette er en *fundamentallikning* for den indre energien og gjør indre energi til en funksjon av entropi og volum. Vi kan nå trekke ut temperatur og volum som partiellderiverte! Dersom volumet er konstant vil dV være lik 0 og vi står igjen med:
#
# $$\delta U = T\delta S \leftrightarrow T = \left(\frac{\delta U}{\delta S}\right)_V$$
#
# Temperatur viser altså hvor mye den indre energien må øke når vi får økning i entropi ved fast volum, for eksempel ved varmetilførsel. Vi sier at temperatur er _drivkraften_ for varmeoverføring.
#
# Dersom vi nå setter entropien konstant, vil dS være lik 0 og vi står igjen med:
#
# $$\delta U = -p\delta V \leftrightarrow -p = \left(\frac{\delta U}{\delta V}\right)_S$$
#
# Trykk viser altså hvor mye den indre energien må senkes når vi får økning i volum ved fast entropi. Vi sier at trykk er _drivkraften_ for volumendring.
#
# Utforsk matematikken bak temperatur og trykk som termodynamiske drivkrefter i simuleringen under.

# %%
from IPython.display import HTML

with open("Simuleringer/temperatur_trykk_drivkrefter.html", "r", encoding="utf-8") as f:
    html = f.read()

HTML(html)

# %% [markdown]
# ### Fra indre energi til entalpi og fri energi
#
# På samme måte som for den indre energien ønsker vi også å definere entalpi H og Helmholtz og Gibbs fri energi F og G ved hjelp av tilstandsfunksjoner. Dette blir enklere siden vi nå kan ta utgangspunkt i uttrykket vi fant for indre energi! Se på utledningen av fundamentalllikningen til entalpi først, samt hvordan vi kan finne de termodynamiske drivkreftene knyttet til entalpi. Deretter skal du få prøve deg på egenhånd for de frie energiene🔥
#
# *Entalpi*
# Fra forrige kapittel vet vi at entalpi er definert som den indre energien pluss pV. Vi starter utledningen vår med å differensiere uttrykket og bytte ut $dU$ med uttrykket vi fant i første del av kapittelet:
#
# $$H = U + pV$$
# $$dH = dU + d(pV) = (TdS - pdV) + (pdV + Vdp)$$
# $$dH = TdS + Vdp$$
#
# Dersom vi setter trykket konstant, blir dp lik null, og vi står igjen med:
#
# $$\delta H = T\delta S \leftrightarrow T = \left(\frac{\delta H}{\delta S}\right)_p$$
#
# Dersom vi setter entropien konstant, finner vi:
#
# $$V = \left(\frac{\delta H}{\delta p}\right)_S$$

# %% [markdown]
# ```{admonition} Din tur!
# :class: tip
# Forsøk å utlede fundamentallikningene for Helmholtz fri energi F og Gibbs fri energi G med samme metode som over! Sjekk svarene dine i nedtrekksmenyen når du er klar💪
# ```
#
# ```{dropdown} Klikk for å se svaret!
#
# *Helmholtz fri energi*
# Fra forrige kapittel vet vi at Helmholtz fri energi er definert som indre energi minus TS. Vi starter utledningen vår med å differensiere uttrykket og bytte ut $dU$ med uttrykket vi fant i første del av dette kapittelet:
#
# $$F = U - TS$$
# $$dF = dU - d(TS) = (TdS - pdV) - (TdS + SdT)$$
# $$dF = -pdV - SdT$$
#
# Dersom vi setter trykket konstant, blir dp lik null, og vi står igjen med:
#
# $$\delta H = T\delta S \leftrightarrow T = \left(\frac{\delta H}{\delta S}\right)_p$$
#
# Dersom vi setter temperaturen konstant, finner vi:
#
# $$-p = \left(\frac{\delta F}{\delta V}\right)_T$$
#
# Dersom vi setter volumet konstant, finner vi:
#
# $$-S = \left(\frac{\delta F}{\delta T}\right)_V$$
#
# *Gibbs fri energi*
# Fra forrige kapittel vet vi at Gibbs fri energi er definert som entalpi minus TS. Vi starter utledningen vår med å differensiere uttrykket og bytte ut $dH$ med uttrykket vi fant i første del av dette kapittelet:
#
# $$G = H - TS$$
# $$dG = dH - d(TS) = (TdS + Vdp) - (TdS + SdT)$$
# $$dG = Vdp - SdT$$
#
# Dersom vi setter temperaturen konstant, finner vi:
#
# $$V = \left(\frac{\delta G}{\delta p}\right)_T$$
#
# Dersom vi setter trykket konstant, finner vi:
#
# $$-S = \left(\frac{\delta G}{\delta T}\right)_p$$
#
# ```

# %% [markdown]
# ### Maxwell-relasjoner
#
# Maxwell-relasjonene tar utgangspunkt i fundamentallikningene og beskriver noen viktige sammenhenger mellom de ulike tilstandsfunksjonene. Først må vi bruke noen matematiske triks, før vi kan trekke ut de nyttige relasjonene!
#
# La oss se på noen egenskaper for en tilstandsstørrelse X, som kan ta to variable a og b:
#
# $$X = X(a,b)$$
#
# Vi kan skrive den totale differensialen for X på følgende måte, vi skal illustrere dette i praksis med fundamentallikningene straks:
#
# $$dX = \left(\frac{\delta X}{\delta a}\right)_bda + \left(\frac{\delta X}{\delta b}\right)_adb$$
#
# Dette kalles et _eksakt differensial_ fordi X er en tilstandsfunksjon av variablene a og b. For slike differensialer gjelder det at:
#
# $$\frac{\delta}{\delta b}\left(\frac{\delta X}{\delta a}\right)_b = \frac{\delta}{\delta a}\left(\frac{\delta X}{\delta b}\right)_a$$
#
# Vi sier at de _blandede andrederiverte_ er like. Denne sammenhengen er nøkkelen bak Maxwell-relasjonene!
#
#
# *Indre energi*
#
# La oss begynne med indre energi. I forrige avsnitt fant vi følgende fundamentallikning for den indre energi:
#
# $$dU = TdS - pdV$$
#
# Vi identifiserte også to uttrykk for T og -p:
#
# $$T = \left(\frac{\delta U}{\delta S}\right)_V$$
# $$-p = \left(\frac{\delta U}{\delta V}\right)_S$$
#
# La oss prøve å sette de to uttrykkene inn i fundamentallikningen og dermed bytte ut T og -p med de partiellderiverte:
#
# $$dU = \left(\frac{\delta U}{\delta S}\right)_VdS + \left(\frac{\delta U}{\delta V}\right)_SdV$$
#
# Nå ser vi at vi har fått et differensial på samme form det eksakte differensialet vi definerte med X over! Da vet vi at vi kan bruke regelen om blandede deriverte. La oss først identifisere X, a og b:
#
# $$X = U, a = S, b = V$$
#
# Vi skriver opp uttrykket for de blandede deriverte:
#
# $$\frac{\delta}{\delta V}\left(\frac{\delta U}{\delta S}\right)_V = \frac{\delta}{\delta S}\left(\frac{\delta U}{\delta V}\right)_S$$
#
# Vi kjenner igjen uttrykkene for T og -p:
#
# $$\frac{\delta}{\delta V}(T) = -\frac{\delta}{\delta S}(p)$$
#
# La oss løse høyre side først. Når vi partiellderiverer med hensyn på V, betyr det at S holdes konstant. Vi får derfor resultatet:
#
# $$\frac{\delta}{\delta V}(T) = \left(\frac{\delta T}{\delta V}\right)_S$$
#
# På venstre side partiellderiverer vi med hensyn på S, og V holdes derfor konstant. Vi står igjen med resultatet:
#
# $$-\frac{\delta}{\delta S}(p) = -\left(\frac{\delta p}{\delta S}\right)_V$$
#
# Vi kan nå skrive opp den første Maxwell-relasjonen🤩
#
# $$\left(\frac{\delta T}{\delta V}\right)_S = -\left(\frac{\delta p}{\delta S}\right)_V$$

# %% [markdown]
# ```{admonition} Din tur
# :class: tip
# Forsøk å utlede de tre neste Maxwell-relasjonene med utgangspunkt i entalpi, Helmholtz fri energi og Gibbs fri energi ved å bruke metoden over! Tips: Følg eksemplet for indre energi nøye når du utleder entalpi, prøv deretter selv for de frie energiene. Sjekk svarene dine i nedtrekksmenyen når du er klar💪
# ```
#
# ```{dropdown} Klikk for å se svaret!
#
# *Entalpi*
#
# For entalpi, skal du finne følgende fundamentallikning dersom du setter inn uttrykkene for T og V:
#
# $$dH = \left(\frac{\delta H}{\delta S}\right)_pdS + \left(\frac{\delta H}{\delta p}\right)_Sdp$$
#
# Ved å bruke metoden vi viste over, burde du finne denne Maxwell-relasjonen:
#
# $$\left(\frac{\delta T}{\delta p}\right)_S = \left(\frac{\delta V}{\delta S}\right)_p$$
#
#
# *Helmholtz fri energi*
#
# For Helmholtz fri energi, skal du finne følgende fundamentallikning dersom du setter inn uttrykkene for -p og -S:
#
# $$dF = \left(\frac{\delta F}{\delta V}\right)_TdV + \left(\frac{\delta F}{\delta T}\right)_VdT$$
#
# Ved å bruke metoden vi viste over, burde du finne denne Maxwell-relasjonen:
#
# $$\left(\frac{\delta p}{\delta T}\right)_V = \left(\frac{\delta S}{\delta V}\right)_T$$
#
# *Gibbs fri energi*
#
# For Gibbs fri energi, skal du finne følgende fundamentallikning dersom du setter inn uttrykkene for V og -S:
#
# $$dG = \left(\frac{\delta G}{\delta p}\right)_Tdp + \left(\frac{\delta G}{\delta T}\right)_pdT$$
#
# Ved å bruke metoden vi viste over, burde du finne den siste Maxwell-relasjonen:
#
# $$\left(\frac{\delta V}{\delta T}\right)_p = -\left(\frac{\delta S}{\delta p}\right)_T$$
#
# ```

# %% [markdown]
# ### Praktisk anvendelse av fundamentallikninger og Maxwell-relasjoner

# %% [markdown]
# ## Kjemisk potensial

# %% [markdown]
# ## Termokjemi
#
# Nå som vi har lært om de termodynamiske potensialene og termodynamiske drivkrefter er vi endelig klare for å studere den praktiske anvendelsen av disse størrelsene i kjemifaget: La oss gå løs på termokjemi!
#
# ### Entalpi: Ekstoterme og endoterme prosesser
#
# ...
#
# Reaksjoner kan gi fra seg eller ta opp varme. Regneeksempel
#
# ### Entropi
#
# Reaksjoner kan øke eller minske entropi
#
# ### Gibbs fri energi forutsier spontanitet
#
# Gibbs fri energi beskriver samspillet mellom reaksjoner som er entalpisk eller entropisk drevne. Vi må ta hensyn til begge når vi vurderer en reaksjons spontanitet --> Vi må tenke på dette når vi står i laben, for sikkerhet og gjennomførbarhet. Introdusere emnet aktiveringsenergi for å hinte til kinetikk-delen mot slutten
#
# Endergon og eksergon
#
# Hvorfor løses krystaller? --> Entropy is just that good

# %% [markdown]
# ## Likevekter
#
# Likevekter er minimum i Gibbs frie energi . Likevekt er ikke en statisk tilstand
#
# Le Chateliers prinsipp
