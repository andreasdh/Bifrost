# %% [markdown]
# # Ukesoppgaver

# %% [markdown]
# ## Uke 1 - tittel

# %% [markdown]
# ## Uke 2 - tittel

# %% [markdown]
# ## Uke 3 - tittel

# %% [markdown]
# ## Uke 4 - tittel

# %% [markdown]
# ## Uke 5 - tittel
