# %% [markdown]
# # Løsningsforslag

# %% [markdown]
# ## Uke 1 - Statistisk mekanikk og Mikro-makro sammenhengen
#
# ### Diskusjonsoppgaver
#
# #### Oppgave 1
#
# **a)** At energien til et atom er kvantisert betyr at atomet bare kan ha bestemte energiverdier - ikke alle mulige verdier imellom. Akkurat som en stige har trinn på faste høyder (trinn 0,1,2,...) og du ikke kan stå på trinn 1.5 eller sveve mellom trinnene, kan atomet bare "stå" på bestemte energinivåer ($\varepsilon_0, \varepsilon_1, \varepsilon_2, \dots$).
#
#
# **b)** Når et atom sender ut lys i form av et foton, hopper et elektron ned fra et høyere til et lavere energinivå, og lyset som sendes ut har en energi som er nøyaktig lik forskjellen mellom de to nivåene. Siden det bare finnes noen få bestemte, tillatte nivåer, finnes det bare noen få mulige energiforskjeller – og dermed bare noen få bestemte bølgelengder (farger) lyset kan ha. Derfor ser vi noen få skarpe linjer i stedet for et jevnt fargebånd. Et kontinuerlig fargebånd ville betydd at alle energiforskjeller var mulige, men det er de ikke.
#
# **c)** En makrotilstand beskriver systemet med størrelser vi kan måle i laboratoriet: temperatur, trykk, volum, total energi. En mikrotilstand er én bestemt måte energien er fordelt på molekylnivå, konsistent med den observerte makrotilstanden.
#
# En analogi er "en skog". På et makronivå kan flere ulike områder være skoger - de er samling av trær, busker, dyr osv. På et mikronivå er skogene forskjellige: trærne er posisjonert forskjellig, det er forskjellige antall trær osv.
#
#
# **d)** En frihetsgrad er en uavhengig måte et molekyl kan bevege seg eller lagre energi på. Hver frihetsgrad er et eget "energilager" som bidrar til molekylets totale energi. Grunnen til at et molekyl har flere frihetsgrader enn et enkeltatom, er at et molekyl har bindinger som kan vibrere og en struktur som kan rotere – ting et enkeltatom ikke har.
#
# Den totale energien til et molekyl er summen av bidragene fra hver frihetsgrad:
#
# $$\varepsilon_{tot} = \varepsilon_{elec} + \varepsilon_{trans} + \varepsilon_{rot} + \varepsilon_{vib}$$
#
# - Elektronisk ($\varepsilon_{elec}$): energien knyttet til hvilke tilstander elektronene rundt atomkjernene er i (tenk orbitaler).
# - Translasjon ($\varepsilon_{trans}$): energien fra at hele molekylet beveger seg gjennom rommet.
# - Rotasjon ($\varepsilon_{rot}$): energien fra at molekylet roterer om en akse.
# - Vibrasjon ($\varepsilon_{vib}$): energien fra at atomene svinger fram og tilbake rundt bindingene sine.
#
# Et enkeltatom har bare de to første (elektronisk og translasjon), siden det verken kan rotere eller vibrere.
#
# En mikrotilstand er én bestemt, fullstendig beskrivelse av hvordan energien er fordelt på alle frihetsgradene samtidig – altså nøyaktig hvilken elektronisk, translasjons-, rotasjons- og vibrasjonstilstand molekylet er i.
#
# En makrotilstand er derimot bare det vi kan måle utad, for eksempel den totale energien. Poenget er at mange forskjellige mikrotilstander kan gi samme makrotilstand: energien kan fordeles på frihetsgradene på mange ulike måter og likevel gi samme totale energi $\varepsilon_{tot}$.
#
#
# **e)** Statistisk mekanikk er måten vi forklarer et systems målbare, makroskopiske egenskaper (som temperatur og trykk) ut fra hva de enormt mange små partiklene i systemet gjør, ved hjelp av sannsynlighet og gjennomsnitt over alle mikrotilstandene.
#
# Forskjellen på de to lovtypene:
#
# * En empirisk lov er satt opp for å passe til noe vi har observert. Vi måler noe først, og finner så en formel som beskriver målingene. Den forteller hva som skjer, men ikke hvorfor.
# * En statistisk lov er utledet fra grunnleggende antakelser om hvordan partiklene oppfører seg. Den følger av teorien og forklarer hvorfor den makroskopiske oppførselen blir som den blir.
#
# Kort sagt: den empiriske loven beskriver, den statistiske loven forklarer.

# %% [markdown]
# #### Oppgave 2
#
# **a)** Hver partikkel kan velge enten boks A eller boks B - dette er $2$ muligheter for hver av de $5$ partiklene som totalt gir
#
# $2 \cdot 2 \cdot 2 \cdot 2 \cdot 2 = 2^5 = 32 \ \text{mikrotilstander}$
#
#
# **b)** Makrotilstadnen er antall partikler i boks A, altså $n_A$. Dette kan være alt fra $0$ (ingen i A) til $5$ (alle i A):
#
# $n_A = 0,1,2,3,4,5$
#
# Altså; $6 \ \text{makrotilstander}$
#
#
# **c)** Vi ønsker å regne ut hvor mange mikrotilstander som gir opphav til hver av makrotilstandene, altså multiplisiteten $\Omega (n_A)$ til hver $n_A$. Spørsmålet vi stiller oss er: hvor mange måter kan vi velge $n_A$ partikler fra totalt $N=5$ partikler?
#
# Dette kan regnes ut ved binomialkoeffisienten:
#
# $\binom{n_A}{5}=\frac{5!}{n_A!(5-n_A)!}$
#
# Vi får dermed:
#
# | $n_A$ | $0$ | $1$ | $2$ | $3$ | $4$ | $5$ |
# | ----- | --- | --- | --- | --- | --- | --- |
# | $\binom{5}{n_A}$ | $\binom{5}{0}=1$ | $\binom{5}{1}=5$ | $\binom{5}{2}=10$ | $\binom{5}{3}=10$ | $\binom{5}{4}=5$ | $\binom{5}{5}=1$ |
#
#
# La oss se på $n_A=2$ og $n_A=5$, og vi nummererer de $5$ partiklene fra 1-5.
#
# Hvordan kan vi velge $2$ partikler ut av totalt $5$ partikler?
#
# $(1,2), (1,3), (1,4), (1,5), (2,3), (2,4), (2,5), (3,4), (3,5), (4,5)$
#
# Dette gir $\Omega (2) = 10$, som vi fant tidligere.
#
# Hvordan kan vi velge $5$ partikler ut av totalt $5$ partikler?
#
# $(1,2,3,4,5)$
#
# Dette gir $\Omega (5) = 1$, som vi også fant tidligere.
#
# Merk! For eksempel, $(1,2)$ er det samme som $(2,1)$. Det spiller ikke hvilken rekkefølge vi har valgt dem i.
#
#
# **d)** Makrotilstandene $n_A=2$ og $n_A=3$ har samme, høyeste multiplisitet. Dette er som forventet fordi de jevneste fordelingene (omtrent like mange i hver boks) kan realiseres på flest måter, mens de ekstreme (alle i én boks) bare kan skje på én måte. Derfor "klumper" multiplisiteten seg i midten.
#
#
# **e)** Sannsynligheter finner man generelt ved å dele antall måter å realisere en hendelse på, på antall måter totalt (gitt at alle måtene er like sannsynlige). For oss betyr det følgende:
#
# $P(n_A)=\frac{\Omega (n_A)}{\text{\# mikrotilstander}}$
#
# Derfor får vi
#
# $P(5)=\frac{\Omega (5)}{32}=\frac{1}{32}$
#
# $P(3)=\frac{\Omega (3)}{32}=\frac{10}{32}=\frac{5}{16}$
#
# Vi ser at det er 10 ganger så sannsynlig at partiklene fordeler seg med 3 i A og 2 i B, enn at alle havner i boks A!
#
#
# **f)** Når $N$ øker, blir fordelingen mer klokkeformet (en normalfordeling) og relativt smalere og skarpere rundt midten. Toppen ved den jevne fordelingen (omtrent halvparten i hver boks) blir stadig mer dominerende, mens de ekstreme utfallene (alle i én boks) blir forsvinnende usannsynlige.
#
# Grunnen er at antall partikler i boks A er en sum av mange uavhengige "myntkast". Sentralgrenseteoremet sier at slike summer nærmer seg en normalfordeling, og den relative bredden krymper som $1/\sqrt{N}$ – så jo flere partikler, jo tettere presses sannsynligheten sammen rundt midten.
#
#
# **g)** Med $N \approx 10^{23}$ partikler er toppen i fordelingen så ekstremt skarp at systemet i praksis *alltid* befinner seg i (eller uendelig nær) makrotilstanden med flest mikrotilstander – altså den jevneste fordelingen. Avvik fra denne er så usannsynlige at de aldri observeres. At all luften i et rom spontant samler seg i det ene hjørnet er ikke forbudt, bare så astronomisk usannsynlig (som "alle i boks A", men med $N \approx 10^{23}$) at det aldri skjer.
#
# Dette er kjernen i termodynamikkens andre lov: systemet utvikler seg mot maksimal multiplisitet, og siden entropien er $S = k_B \ln \Omega$, betyr det at entropien øker mot et maksimum. Likevekt er rett og slett den fordelingen som kan realiseres på overveldende flest mikroskopiske måter.

# %% [markdown]
# #### Oppgave 3
#
# **a)** En mikrotilstand her er én bestemt måte å plassere de to type 1- og to type 2-molekylene på de fire plassene A, B, C, D. I bildet: 1 på A og B, 2 på C og D.
#
# Det er ikke det samme som mikrotilstanden til ett enkelt atom, fordi tilstanden er en egenskap ved hele systemet (konfigurasjonen av alle fire plassene samtidig), ikke ved én partikkel alene. Ett atoms tilstand sier ingenting; det er fordelingen over alle plassene som utgjør mikrotilstanden.
#
#
# **b)** En mikrotilstand er den fullstendige, detaljerte konfigurasjonen - nøyaktig hvilken type sitter på hver enkelt plass (A, B, C, D).
#
# En makrotilstand er det overordnede som vi observerer eller kan måle som en konsekvens av mikrotilstanden, her energien. Flere ulike mikrotilstander kan gi samme energi og hører derfor til samme makrotilstand. Makrotilstanden bryr seg bare om totalverdien (energien), ikke om hvilken plass hvert molekyl sitter på.
#
#
# **c)** Husk at det er to type-1 og to type-2 molekyler. Hver mikrotilstand er på formen (A,B,C,D), og vi ser på antall måter å plassere ut $2$ type-1 molekyler på denne rekken. Det er gitt ved
#
# $\binom{4}{2}=6 \ \text{mikrotilstander}$
#
# Her er de ulike mikrotilstandene som svarer til de ulike energiene:
#
# 1) $\varepsilon=2\Delta \varepsilon$ (2 stk 1-2-kontakter)
#
# (1,1,2,2), (1,2,1,2), (2,2,1,1), (2,1,2,1)
#
# 2) $\varepsilon=4\Delta \varepsilon$ (4 stk 1-2-kontakter)
#
# (1,2,2,1), (2,1,1,2)
#
# Totalt er dette $6 \ \text{mikrotilstander}$, som vi fant tidligere.
#
#
# **d)** Vi fant $2$ ulike energiverdier i oppgave c), slik at det er $2$ makrotilstander blant de $6$ mikrotilstandene.
#
# Med $N_A \approx 6 \cdot 10^{23}$ molekyler eksploderer antall mikrotilstander (kombinatorisk i $N$), mens antall makrotilstander vokser bare omtrent lineært. Da er det umulig å telle hver mikrotilstand for hånd. I stedet teller vi *hvor mange* mikrotilstander som hører til hver makrotilstand (multiplisiteten) og bruker sannsynligheter — systemets oppførsel bestemmes av de mest sannsynlige makrotilstandene.

# %% [markdown]
# #### Oppgave 4
#
# **a)** Det som holder seg noenlunde konstant er makrotilstanden, altså antall eksiterte partikler $n$ (og dermed energien $E = n\Delta\epsilon$), ikke selve mikrotilstanden. Systemet bytter hele tiden hvilke partikler som er eksiterte, men $n$ endrer seg lite fordi svært mange mikrotilstander gir samme $n$. Likevekt betyr derfor at de målbare størrelsene svinger rundt en stabil middelverdi, ikke at ingenting skjer på mikronivå.
#
#
# **b)** Når $N$ øker, blir toppen på $P(n)$ høyere og skarpere. Den absolutte bredden vokser som $\sqrt{N}$, men den relative bredden (bredde delt på middelverdi) går som $\sqrt{N}/N = 1/\sqrt{N}$ og krymper mot null. For $N \approx 6\cdot10^{23}$ blir $1/\sqrt{N} \approx 10^{-12}$, så fordelingen er i praksis en uendelig smal nål ved én verdi, og det er derfor et makroskopisk system alltid ser ut til å ha én bestemt, veldefinert makrotilstand.
#
#
# **c)** Når $k_BT/\Delta\epsilon$ øker, blir mer energi tilgjengelig og flere partikler eksiteres, så $n$ øker. Multiplisiteten $\Omega(n) = \binom{N}{n}$ er størst ved $n = N/2$ og synker mot 1 i begge ender. Så det blir ikke alltid flere mikrotilstander av mer energi: opp mot $n = N/2$ øker $\Omega$, men når nesten alle er eksiterte synker $\Omega$ igjen, og ved $n = N$ finnes bare én mikrotilstand — akkurat som ved $n = 0$.
#
#
# **d)** Den røde søylen ($U = \langle E \rangle$, gjennomsnittet) og den høyeste søylen (mest sannsynlige $n$) faller bare sammen når fordelingen er symmetrisk. Ved liten $N$ eller energi langt fra $n = N/2$ blir $P(n)$ skjev, så gjennomsnittet trekkes mot den lange halen og lander litt ved siden av toppen. For $N \approx 6\cdot10^{23}$ blir fordelingen ekstremt smal og nærmest symmetrisk, så forskjellen mellom $U$ og mest sannsynlige energi blir forsvinnende liten.

# %% [markdown]
# #### Oppgave 5
#
# **a)** Når $E_i$ øker ved fast $T$, blir eksponenten $-E_i/k_BT$ mer negativ, så $P(E_i)$ synker. Høyere energitilstander er altså mindre sannsynlige.
#
#
# **b)** Når $T$ øker ved fast $E_i$, går $E_i/k_BT$ mot null og $e^{-E_i/k_BT}$ mot 1, så tilstanden blir mer sannsynlig relativt til lavere tilstander. Fordelingen jevnes ut, slik at høyere energitilstander får en større andel.
#
#
# **c)**
#
# $\frac{P(E_2)}{P(E_1)} = e^{-(E_2-E_1)/k_BT}$
#
# Når $T \to \infty$ går eksponenten mot 0 og forholdet mot 1, altså blir de to tilstandene like sannsynlige. Når $T \to 0$ går eksponenten mot $-\infty$ og forholdet mot 0, så den høyere tilstanden $E_2$ blir uendelig mye mindre sannsynlig enn $E_1$.
#
#
# **d)** Ved svært lav temperatur befinner systemet seg så godt som alltid i grunntilstanden (lavest energi). Grunnen er at det knapt finnes termisk energi til å eksitere systemet, så alle høyere tilstander blir undertrykt av Boltzmann-faktoren.
#
#
# **e)** Ved svært høy temperatur blir forskjellen i sannsynlighet mellom lave og høye energitilstander liten — alle tilgjengelige tilstander blir tilnærmet like sannsynlige. Den termiske energien er da så stor at energiforskjellene nesten ikke betyr noe.
#
#
# **f)** Det er forholdet $E_i/k_BT$ som avgjør, fordi det er dimensjonsløst og sammenligner energien med den tilgjengelige termiske energien $k_BT$. En energi er bare "stor" eller "liten" i forhold til $k_BT$: samme $E_i$ kan være utilgjengelig ved lav $T$ og lett tilgjengelig ved høy $T$, så det er forholdet, ikke $E_i$ eller $T$ alene, som bestemmer sannsynligheten.

# %% [markdown]
# ### Regneoppgaver
#
# #### Oppgave 6
#
# **a)** Vi løser først det ubestemte integralet:
#
# $\int C dx= Cx + D$
#
# Husk at når vi løser ubestemte integraler, må vi alltid ha med en konstant slik som $D$.
#
# Vi løser så det bestemte integralet mellom start-tilstand $i$ og slutt-tilstand $f$:
#
# $\int_{i}^{f} C dx = [Cx]^{f}_{i}=Cf-Ci=C(f-i)$
#
#
# **b)**
#
# Vi løser først det ubestemte integralet:
#
# $\int f(x) dx=\int \frac{1}{x} dx = \ln \left| x \right| +C$
#
# Igjen har vi med en integrasjonskonstant $C$ siden vi har løst et ubestemt integral.
#
# Vi løser så det bestemte integralet mellom start-tilstand $i$ og slutt-tilstand $f$:
#
# $\int_{i}^{f} f(x) dx=\int_{i}^{f} \frac{1}{x} dx = [\ln \left| x \right|]_{i}^{f}=\ln \left| f \right|-\ln \left| i \right|=\ln{\frac{|f|}{|i|}}$

# %% [markdown]
# #### Oppgave 7
#
# **a)** Vi starter med
#
# $\Omega(q,N) = \frac{(q+N-1)!}{q!\,(N-1)!}$
#
# Vi tar så logaritmen av uttrykket og bruker at $\ln(\frac{a}{b}) = \ln a - \ln b$:
#
# $\ln\Omega = \ln(q+N-1)! - \ln q! - \ln(N-1)!$
#
# For store $q$ og $N$ bruker vi $q + N - 1 \approx q + N$ og $N - 1 \approx N$:
#
# $\ln\Omega \approx \ln(q+N)! - \ln q! - \ln N!$
#
# Deretter bruker vi Stirlings approksimasjon $\ln n! \approx n\ln n - n$ på hvert ledd, slik at
#
# $\ln(q+N)! \approx (q+N)\ln(q+N) - (q+N)$
#
# $\ln q! \approx q\ln q - q$
#
# $\ln N! \approx N\ln N - N$
#
# Vi setter inn hvert av leddene og får
#
# $\ln\Omega \approx \big[(q+N)\ln(q+N) - (q+N)\big] - \big[q\ln q - q\big] - \big[N\ln N - N\big] = (q+N)\ln(q+N) - q\ln q - N\ln N$
#
#
#
# bVi har to systemer i kontakt med total energi
#
# $q_\text{tot} = q_A + q_B \Longrightarrow q_B = q_\text{tot} - q_A$
#
# Den totale multiplisiteten er
#
# $\Omega_\text{tot} = \Omega_A \cdot \Omega_B$
#
# slik at vi får
#
# $\ln\Omega_\text{tot} = \ln\Omega_A(q_A) + \ln\Omega_B(q_B)$
#
# Likevektsbetingelsen er der $\ln\Omega_\text{tot}$ er maksimal, altså der den deriverte med hensyn på $q_A$ er null
#
# $\frac{d}{dq_A}\ln\Omega_{tot} = 0$
#
# Vi deriverer først ved bruk av kjerneregelen
#
# $\frac{d}{dq_A}\ln\Omega_{tot} = \frac{d}{dq_A} \left( \ln\Omega_A(q_A) + \ln\Omega_B(q_B) \right) = \frac{d}{dq_A} \ln\Omega_A(q_A) + \frac{d}{dq_A} \ln\Omega_B(q_B) = \frac{d\ln\Omega_A(q_A)}{dq_A} + \frac{d\ln\Omega_B(q_B)}{dq_B}\cdot\frac{dq_B}{dq_A}$
#
# og krever at uttryket skal være lik null
#
# $\frac{d\ln\Omega_A(q_A)}{dq_A} + \frac{d\ln\Omega_B(q_B)}{dq_B}\cdot\frac{dq_B}{dq_A} = 0$
#
# Siden $q_B = q_\text{tot} - q_A$ er $dq_B/dq_A = -1$, så
#
# $\frac{d\ln\Omega_A(q_A)}{dq_A} + \frac{d\ln\Omega_B(q_B)}{dq_B}\cdot(-1) = 0 \Longrightarrow \frac{d\ln\Omega_A(q_A)}{dq_A} = \frac{d\ln\Omega_B(q_B)}{dq_B}$
#
# Nå kan vi bruke approksimasjonen for $\ln\Omega$ vi fant i a), og deriverer uttrykkene før vi setter dem inn:
#
# $\frac{d\ln\Omega(q)}{dq} = \frac{d}{dq} \big[(q+N)\ln(q+N) - q\ln q - N\ln N \big] = \frac{d}{dq} \big[(q+N)\big] \ln(q+N) - \frac{d}{dq} \big[ q\ln q \big] - \frac{d}{dq} \big[ N \ln N \big]$
#
# Vi kan derivere hvert ledd for seg
#
# $\frac{d}{dq} \big[ (q+N) \ln(q+N) \big] = \frac{d}{dq} \big[q+N\big] \cdot \ln(q+N) + \frac{d}{dq} \big[ \ln(q+N) \big] \cdot (q+N) = \ln(q+N) + \frac{q+N}{q+N}= \ln (q+N) + 1$
#
# $\frac{d}{dq} \big[ q\ln q \big] = \frac{d}{dq} \big[q \big] \cdot (\ln q) + \frac{d}{dq} \big[\ln q] \cdot q = \ln q + \frac{q}{q} = \ln q + 1$
#
# $\frac{d}{dq} \big[ N \ln N \big] = 0$
#
# og setter dem inn igjen
#
# $\frac{d\ln\Omega(q)}{dq} = \frac{d}{dq} \big[(q+N)\ln(q+N) - q\ln q - N\ln N \big] = \ln (q+N) + 1 - (\ln q + 1) = \ln (q+N) - \ln q = \ln \left( \frac{q+N}{q} \right)$
#
# Vi setter inn den deriverte for A og B:
#
# $\ln\!\left(\frac{q_A+N_A}{q_A}\right) = \ln\!\left(\frac{q_B+N_B}{q_B}\right) \Longrightarrow \frac{q_A+N_A}{q_A} = \frac{q_B+N_B}{q_B} \Longrightarrow \frac{q_A+N_A}{q_A}-1 = \frac{q_B+N_B}{q_B}-1 \Longrightarrow \frac{q_A+N_A-q_A}{q_A} = \frac{q_B+N_B-q_B}{q_B} \Longrightarrow \frac{N_A}{q_A} = \frac{N_B}{q_B} \Longrightarrow \frac{q_A}{N_A} = \frac{q_B}{N_B}$
#
# Med definisjonen $T = q/N$ får vi ved likevekt:
#
# $T_A = T_B$

# %% [markdown]
# #### Oppgave 8
#
# **a)** Vi har at
#
# $P(E_0)+P(E_1)+P(E_2)=0.65+0.25+0.10=1$
#
# Sannsynligheten for at systemet er i energinivå $E_0$, $E_1$ eller $E_2$ er $1$. Det er dermed garantert at vi finner systemet i ett av disse energinivåene.
#
#
# **b)** Vi bruker formelen gitt i oppgaven og regner ut:
#
# $U=\left< E \right>=E_0 \cdot P(E_0)+E_1 \cdot P(E_1)+E_2 \cdot P(E_2)=0 \cdot 0.65 + \epsilon \cdot 0.25 + 2\epsilon \cdot 0.10=0.45 \epsilon$
#
# Merk at $0.45 \epsilon$ ikke er en energi systemet faktisk kan befinne seg i, de tillate er jo bare $0, \epsilon$ eller $2\epsilon$ - dette er bare gjennomsnittet.
#
#
# **c)** Vi bruker formelen oppgitt i forrige deloppgave og regner ut:
#
# $U=\left< E \right>=E_0 \cdot P(E_0)+E_1 \cdot P(E_1)+E_2 \cdot P(E_2)=0 \cdot 0.40 + \epsilon \cdot 0.35 + 2\epsilon \cdot 0.25=0.85 \epsilon$
#
#
# **d)** Fra Boltzmanns fordelingslov har vi at sannsynligheten $P_i$ for en mikrotilstand $i$ er gitt ved
#
# $P_i = \frac{1}{Q} e^{-\frac{E_i}{k_B T}}$
#
# Husk at vi har vi to variabler som varierer: $E_i$ og $T$.
#
# Ved lav $T$, blir $k_B T$ liten. Da vil $-\frac{E_i}{k_B T}$ bli større for små $E_i$ enn for større $E_i$. Da blir også $P_i$ større for lavere energitilstander enn høyere energitilstander, ergo grunntilstanden vil dominere.
#
# Ved høy $T$, blir $k_B T$ stor. Da vil $-\frac{E_i}{k_B T}$ gå mot $0$ for alle energitilstander, og $e^{-\frac{E_i}{k_B T}}$ går mot $1$. Sannsynligheten $P_i$ jevnes ut for alle energitilstandene.
#
# Nå - gir det mening at $\left< U \right >$ blir større ved større $T$?
# Ja! Ved lav $T$ er stort sett de laveste energinivåene befolket og sannsynlighetnee $P_i$ for de høyere energini

# %% [markdown]
# #### Oppgave 9
#
# **a)** Vi har $32$ mikrotilstander og antar at sannsynligheten for hver av de er lik. Antall måter vi kan ha $0,1,2,3,4$ eller $5$ partikler i boks A på er gitt i tabellen, og vi finner sannsynlighetene for hver av disse:
#
# | $n_A$ | 0 | 1 | 2 | 3 | 4 | 5 |
# | ----- | - | - | - | - | - | - |
# | $\Omega (n_A)$ | 1 | 5 | 10 | 10 | 5 | 1 |
# | $P(n_A)=\frac{\Omega (n_A)}{32}$ | $\frac{1}{32}$ | $\frac{5}{32}$ | $\frac{5}{16}$ | $\frac{5}{16}$ | $\frac{5}{32}$ | $\frac{1}{32}$ |
#
#
# **b)** Vi bruker formelen i oppgaven til å regne ut gjennomsnittlig antall partikler i boks A:
#
# $\left< n_A \right> = \sum_{n_A=0}^{5} n_A P(n_A) = 0 \cdot \frac{1}{32} + 1 \cdot \frac{5}{32} + 2 \cdot \frac{5}{16} + 3 \cdot \frac{5}{16} + 4 \cdot \frac{5}{32} + 5 \cdot \frac{1}{32}=\frac{5}{2}=2.5$
#
#
# **c)** Ja. Fordelingen er symmetrisk om midten (samme verdier fra hver ende), så tyngdepunktet må ligge midt mellom $0$ og $5$, altså $2.5$. Fysisk gir dette mening: med to like bokser forventer vi i snitt like mange partikler i hver, og $5/2 = 2.5$.
#
#
# **d)** "Minst $4$" betyr "enten $4$ eller $5$", slik at vi får
#
# $P(n_A \ge 4) = P(n_A = 4) + P(n_A = 5) = \frac{5}{32} + \frac{1}{32} = \frac{3}{16}$

# %% [markdown]
# #### Oppgave 10
#
# **a)** Multiplisiteten $\Omega (E)$ er antallet ulike mikrotilstander (konkrete måter å arrangere molekylene på) som alle gir samme makroskopiske energi $E$. Jo flere mikrotilstander som gir en gitt energi, jo flere måter kan systemet «realisere» den energien på, og jo mer sannsynlig er det å finne systemet der. Sannsynlighet handler om å telle muligheter: en energi som kan oppnås på mange måter, treffes oftere enn en energi som bare kan oppnås på én måte.
#
#
# **b)** I oppgave 2c) fant vi følgende
#
# 1) $\varepsilon=2\Delta \varepsilon$ (2 stk 1-2-kontakter)
#
# (1,1,2,2), (1,2,1,2), (2,2,1,1), (2,1,2,1)
#
# 2) $\varepsilon=4\Delta \varepsilon$ (4 stk 1-2-kontakter)
#
# (1,2,2,1), (2,1,1,2)
#
# Dette kan oppsummeres slik
#
# | $E$ (i enheter av $\Delta \varepsilon$) | $2$ | $4$ |
# | --------------------------------------- | --- | --- |
# | $\Omega (E)$ | $4$ | $2$ |
#
#
# c) Entropien $S$ er gitt ved
#
# $S=k_B \ln{\Omega}$
#
# slik at vi får
#
# $S(\Omega (2\Delta \varepsilon))=(1.38 \cdot 10^{-23} \ \text{J}/\text{K}) \cdot \ln{(4)}=1.91 \cdot 10^{-23} \ \text{J}/\text{K}$
#
# $S(\Omega (4\Delta \varepsilon))=(1.38 \cdot 10^{-23} \ \text{J}/\text{K}) \cdot \ln{(2)}=9.57 \cdot 10^{-24} \ \text{J}/\text{K}$
#
# Vi har at
#
# $\frac{S(\Omega (2\Delta \varepsilon))}{S(\Omega (4\Delta \varepsilon))}=\frac{1.91 \cdot 10^{-23} \ \text{J}/\text{K}}{9.57 \cdot 10^{-24} \ \text{J}/\text{K}}=2$
#
# Altså er entropien for energien $2\Delta \varepsilon$ dobbelt så stor som entropien for energien $4\Delta \varepsilon$.
#
#
# **d)** Vi ønsker nå å plotte $\Omega(E)$ mot $E$, og gjør dette i Python.

# %%
# Importerer pyplot til plotting
import matplotlib.pyplot as plt

# Lager to lister E og Omega basert på verdiene gitt i tabellen i oppgaveteksten
E = list(range(5,24))
Omega = [8, 20, 104, 402, 1112, 2662, 5864, 11166, 18656, 26078, 30216, 29126, 23312, 15328, 8444, 3568, 940, 90, 4]

# Plotter et barplott for Omega basert på E
plt.bar(E, Omega)

# Inkluderer tittel, x-aksetittel og y-aksetittel for plottet
plt.title(r'Multiplisitet $\Omega(E)$ for 25-plassers gitteret')
plt.xlabel(r' $E$ [$\Delta \varepsilon$]')
plt.ylabel(r' $\Omega(E)$')

# Setter x-aksens verdier til heltall
plt.xticks(E)

# Legger til tynne horisontale gridlines
plt.grid(axis='y', linewidth=0.2)

# Viser plottet
plt.show()

# %% [markdown]
# Grunntilstandsenergien $E_0$ er den laveste energien, slik at vi får
#
# $E_0 = 5\Delta \varepsilon$
#
# med multiplisitet
#
# $\Omega(E_0)=8$
#
# Den mest sannsynlige energien $E$ er den energien som svarer til den største multiplisiteten, slik at vi får
#
# $E=15\Delta \varepsilon$
#
# med multiplisitet
#
# $\Omega(E)=15$
#
# Den mest sannsynlige energien er derfor ikke grunntilstandsenergien. I et lite system er det få plasser å fordele molekylene på, så antall mikrotilstander endrer seg lite fra energinivå til energinivå, og den ordnede lavenergitilstanden kan fint ha flest. I et stort system er det derimot enormt mange flere måter å arrangere molekylene på ved gjennomsnittlige energier (uordnede konfigurasjoner) enn ved den ene ordnede grunntilstanden, så $\Omega$ vokser mye raskere enn energien "koster", og toppen flytter seg vekk fra grunntilstanden.
#
#
# e)
#
# $S(\Omega(8\Delta\varepsilon))=(1.38 \cdot 10^{-23} \ \text{J}/\text{K}) \cdot \ln{(402)}=8.28 \cdot 10^{-23} \ \text{J}/\text{K}$
#
# $S(\Omega(9\Delta\varepsilon))=(1.38 \cdot 10^{-23} \ \text{J}/\text{K}) \cdot \ln{(1112)}=9.68 \cdot 10^{-23} \ \text{J}/\text{K}$
#
# Vi anslår stigningstallet
#
# $\frac{1}{T}=\frac{\partial S}{\partial E} \approx \frac{\Delta S}{\Delta E}=\frac{9.68 \cdot 10^{-23} \ \text{J}/\text{K}-8.28 \cdot 10^{-23} \ \text{J}/\text{K}}{9\Delta \varepsilon-8\Delta\varepsilon \text{J}}=\frac{1.4 \cdot 10^{-23} \text{J} / \text{K}}{1 \text{J}} = 1.4 \cdot 10^{-23} \ \text{K}^{-1}$

# %% [markdown]
# #### Oppgave 11
#
# **a)** $\Omega(n)$ er multiplisiteten, og teller antall mikrotilstander som svarer til én bestemt makrotilstand. Husk at $\Omega(n)$ er proporsjonal med sannsynligheten for én bestemt makrotilstand. På en annen side har vi $p(\varepsilon)$ som gir sannsynligheten for å finne systemet i én spesifikk mikrotilstand med energi $\varepsilon$.
#
#
# **b)** Når $\Delta\varepsilon/k_B T$ øker, blir eksponenten mer og mer negativ. I gjengjeld vil $\frac{p(\varepsilon_1)}{p(\varepsilon_0)}$ bli veldig liten, og gå mot null. Det betyr at en mikrotilstand med høyere energi $\varepsilon_1$ blir mindre og mindre sannsynlig enn grunntilstanden med energi $\varepsilon_0$ når $\Delta\varepsilon/k_B T$ øker.
#
#
# **c)**
#
# * For $v=0$ er andelen $N(v)/N(0)=1.00$, mens for $v=2$ er andelen $N(v)/N(0)=0.14$. Det betyr at andelen av molekylene i $v=0$ som man finner igjen i $v=2$ er
#
# $0.14=14 \%$
#
# * Vi kan finne sannsynligheten for et vibrasjonsnivå $v$, $p(v)$, ved å dele antallet molekyler i tilstand $v$, $N(v)$, på det totale antallet molekyler $N$:
#
# $p(v)=\frac{N(v)}{N}$
#
# Derfor er
#
# $\frac{N(v)}{N(0)}=\frac{p(v)/N}{p(0)/N}=\frac{p(v)}{p(0)}=e^{-(\varepsilon_v-\varepsilon_0)/k_B T}$
#
# Husk at $\Delta\epsilon/k_B T=1$, og vi får dermed
#
# $\frac{N(2)}{N(0)}=e^{-(2\Delta\varepsilon-0)/k_B T}=e^{-2 \cdot (\Delta\varepsilon/k_B T)}=e^{-2} \approx 0.135$
#
# Ved avlesning på plottet har får vi $0.14$, slik at estimatet vårt stemmer godt med vår verdi på $0.135$.
#
# * Vi har nå $\Delta\epsilon/k_B T=2$, og får
#
# $\frac{N(2)}{N(0)}=e^{-(2\Delta\varepsilon-0)/k_B T}=e^{-2 \cdot (\Delta\varepsilon/k_B T)}=e^{-2 \cdot 2} \approx 0.0183$
#
# Vi har funnet ut at andelen molekyler i $v=2$ sammenlignet med $v=0$ avtar når vi øker $\Delta\epsilon/k_B T$ fra $1$ til $2$. Det betyr at $v=2$ er mindre befolket. I b) fant vi at når $\Delta\epsilon/k_B T$ øker, så blir tilstander med høyere energi enn grunntilstanden mindre sannsynlige.

# %% [markdown]
# ## Uke 2 - Statistisk mekanikk, Energi, Entropi og Temperatur
#
# ### Diskusjonsoppgaver

# %% [markdown]
# #### Oppgave 1
#
# **a)** Under er termodynamikkens 2.lov formulert på flere ulike måter:
#
# * Entropien i et isolert system avtar aldri ved en forandring
# * Enhver prosess fører til at entropien til et system enten øker eller forblir konstant
# * $\Delta S \ge 0$
# * Prosesser som minker entropien til et isolert system er umulige
# * Et isolert system vil gjennom en prosess enten forbli like ordnet eller bli mer uordnet
#
#
# **b)** Den makroskopiske definisjonen av entropi er
#
# $dS=\frac{\partial q}{T}$
#
# der $dS$ er en liten endring i entropi, $\partial q$ er endringen i varme (overført varme) og $T$ er temperatur.
#
# Husk at $S$ er en tilstandsfunksjon - den avhenger kun av start-tilstand og slutt-tilstand, ikke veien mellom disse. På en annen side er $q$ en stifunksjon - endringen avhenger av veien fra start-tilstand til slutt-tilstand. Derfor skriver vi $d$ for entropi $S$, og $\partial$ for varme $q$.
#
#
# **c)** Den mikroskopiske definisjonen av entropi er
#
# $S=k_B \ln{\Omega}$
#
# der $S$ er entropi, $k_B$ er Boltzmanns konstant og $\Omega$ er multiplisitet (antall mikrotilstand som gir en bestemt makrotilstand).
#
# Du har sett flere eksempler på systemer som har mange mikrotilstander, men hvor flere mikrotilstander resulterer i én spesielt makrotilstand. Det er nettopp dette antallet $\Omega$ beskriver.
#
#
# **d)** Vi har 10 bokser og 3 kuler. Vi har tre valg: 3 i én boks, 2 i én boks og 1 i en annen, og 1 i hver sin boks.
#
# Skal vi ha alle kulene i samme boks, er det 10 bokser å velge mellom, og vi får
#
# $10 \ \text{muligheter}$
#
# Skal vi ha 2 kuler i én boks er det 10 bokser å velge mellom, og den siste kulen har da 9 bokser å velge mellom, og vi får
#
# $10 \cdot 9 = 90 \ \text{muligheter}$
#
# Skal vi ha 1 i hver sin boks, er det antall måter å velge 3 kuler på 10 plasser gitt ved
#
# $\binom{10}{3}=120 \ \text{muligheter}$
#
# Hva sier dette oss? Det er langt flere måter å spre kulene ut enn å holde de samlet. Hvis alle kombinasjonene har lik sannsylighet, er det derfor mest sannsynlig spredning av kulene.
#
#
# **e)** Flere typer bevegelse (frihetsgrader) bidrar til entropien: translasjon (bevegelse gjennom rommet), rotasjon, vibrasjon, og elektroniske tilstander. I tillegg bidrar konfigurasjonen (hvordan partikler eller energi er fordelt i rommet).
#
#
# **f)** Ved likevekt er entropien maksimal for et isolert system. Systemet utvikler seg spontant mot den makrotilstanden med flest mikrotilstander (høyest $\Omega$), og likevekt er nettopp der denne er størst og entropien ikke lenger kan øke.

# %% [markdown]
# #### Oppgave 2
#
# **a)** Vi har 3 plasser og 3 skjelnbare kuler. På første plass har vi 3 valg av kule, på andreplass har vi 2 valg og på siste har vi kun 1 valg. Dette gir
#
# $3! = 3 \cdot 2 \cdot 1 = 6 \ \text{mikrotilstander}$
#
# Dette er antall mikrotilstander for systemet, altså $\Omega=6$.
#
# Hvis vi antar at alle mulighetene er like sannsynlige, er sannsynligheten for å finne akkurat den spesifikke konfigurasjonen på bildet lik:
#
# $\frac{1}{6}$
#
# Entropien til systemet blir
#
# $S=k_B \ln{\Omega}=(1.38 \cdot 10^{-23} \ \text{J}/\text{K}) \cdot \ln{6}=2.47 \cdot 10^{-23} \ \text{J}/\text{K}$
#
#
# **b)** Vi har nå 3 identiske kuler. Husk at vi kan finne antall måter å velge $n$ objekter fra $N$ objekter når rekkefølgen ikke spiller noen rolle ved binomialkoeffisienten, altså
#
# $\Omega(N,n)=\binom{N}{n}=\frac{N!}{n!(N-n)!}$
#
# I vårt tilfelle skal vi velge ut 3 plasser (til 3 kuler) av forskjellige antall plasser for hvert alternativ a)-d). Rekkefølgen spiller ikke noen rolle fordi kulene er identiske.
#
# Entropien finner vi ved $S=k_B \ln{(\Omega(N,n))}$
#
# | Alternativ | a | b | c | d |
# | ---------- | - | - | - | - |
# | $N$ | $3$ | $4$ | $5$ | $6$ |
# | $\Omega(N,3)=\binom{N}{3}$ | $\binom{3}{3}=1$ | $\binom{4}{3}=4$ | $\binom{5}{3}=10$ | $\binom{6}{3}=20$ |
# | $S \ [\text{J}/\text{K}]$ | $0$ | $1.91 \cdot 10^{-23}$ | $3.18 \cdot 10^{-23}$ | $4.13 \cdot 10^{-23}$ |
#
#
# **c)** Siden $S$ er en tilstandsfunksjon kan vi finne $\Delta S$ som differansen mellom slutt-entropi og start-entropi, det vil si
#
# $\Delta S = S_{slutt}-S_{start}=4.13 \cdot 10^{-23} \ \text{J}/\text{K} - 0 \ \text{J}/\text{K} = 4.13 \cdot 10^{-23} \ \text{J}/\text{K}$
#
#
# **d)** Vi har 6 posisjoner og ønsker å ha de 3 kulene ved siden av hverandre. Da kan vi ha følgende konfigurasjoner:
#
# (1,2,3), (2,3,4), (3,4,5), (4,5,6)
#
# Av de totalt $20$ mikrotilstandene, er det derfor $4$ av de som svarer til at kulene ligger ved siden av hverandre. Hvis vi antar at alle mikrotilstandene er like sannsynlige, får vi
#
# $P(3 \ \text{kuler ved siden av hverandre})=4 \cdot \frac{1}{20}=\frac{1}{5}$
#
# Den motsatte hendelsen er at kulene er spredt utover (minst 1 mellomrom mellom kulene), og vi får
#
# $P(\text{kulene er spredt utover})=1-P(3 \ \text{kuler ved siden av hverandre})=1-\frac{1}{5}=\frac{4}{5}$
#
#
# **e)** Flere av mikrotilstandene svarer til at kulene er blandet enn at de ligger ved siden av hverandre, og derfor er det overveiende mer sannsynlig at stoffer blander seg og fyller hele beholdere enn at de samles. Systemene vi ser på her er veldig små, så for reelle systemer med mange flere mikrotilstander blir sannsynligheten for blanding enda større.

# %% [markdown]
# #### Oppgave 3
#
# **a)** Stigningstallet $\partial S/\partial E = 1/T$ er stort og positivt i starten av kurven (bratt oppover), og synker gradvis mot null når vi nærmer oss toppunktet. Entropien øker altså raskt med energi i begynnelsen, men saktere og saktere jo nærmere toppen vi kommer.
#
#
# **b)** Toppunktet er der $\Omega(n)$ er størst, altså der det finnes flest mikrotilstander. Siden systemet spontant søker mot makrotilstanden med flest mikrotilstander (høyest sannsynlighet), er dette nettopp likevektstilstanden — der entropien er maksimal og ikke lenger kan øke. Fra sannsynlighetenes perspektiv, er det ikke umulig å komme seg vekk fra denne makrotilstanden, men sannsynligheten for det er såpass liten at det praktisk talt er umulig.
#
#
# **c)** Systemet starter i en svært usannsynlig tilstand med bare én mikrotilstand ($n = 0$, $\Omega = 1$). Når det får utveksle energi fritt, vil $n$ øke over tid fordi det finnes langt flere mikrotilstander ved høyere $n$. Grafen viser at systemet beveger seg oppover kurven mot toppunktet, der $\Omega$ og entropien er størst, og blir værende der.
#
#
# **d)** Nær $n = 0$ er stigningstallet $1/T$ stort, mens det nær toppunktet er nesten null. Et stort stigningstall betyr høy "drivkraft" mot likevekt: langt fra likevekt drives systemet sterkt mot større entropi, mens det nesten ved likevekt knapt har noen netto drivkraft igjen. Systemet endrer seg altså raskt i starten og stadig saktere når det nærmer seg toppen.
#
#
# **e)** De makroskopiske størrelsene $U$ (indre energi) og $\Delta S$ (entropiendring) er bygget opp fra mikroskopiske størrelser: $U$ er summen av energipakkene $\varepsilon_n$ over alle partikler, og $S = k_B \ln \Omega$ kommer direkte fra antall mikrotilstander $\Omega$. Det er riktig å si at de er "informasjon om mikroverdenen oversatt til noe vi kan måle", fordi $\Omega$ og $\varepsilon_n$ hører til den usynlige mikroskopiske skalaen, mens $U$ og $\Delta S$ er nettopp de målbare størrelsene i laboratoriet som disse mikroskopiske egenskapene summerer seg opp til.

# %% [markdown]
# #### Oppgave 4
#
# **a)** Skjelnbare partikler kan skilles fra hverandre (de har fast, identifiserbar posisjon, som atomene i et fast stoff), mens uskjelnbare partikler er identiske og kan ikke merkes fra hverandre (som molekyler i en gass). Vi skiller mellom dem fordi det påvirker tellingen av mikrotilstander: for uskjelnbare partikler gir det ingen ny mikrotilstand å bytte om på to like partikler, så vi må ikke telle slike ombytter som distinkte. Dette er viktig når vi setter opp partisjonsfunksjonen, fordi vi ellers overteller tilstandene (typisk med en faktor $N!$) og får feil entropi og fri energi.
#
#
# **b)** Partisjonsfunksjonen
#
# $Q = \sum_i e^{-\epsilon_i / k_B T}$
#
# er en sum over alle tilgjengelige mikrotilstander, vektet med Boltzmann-faktoren, og fungerer som en normeringsfaktor som sørger for at sannsynlighetene summerer til 1. Den brukes til å regne ut sannsynligheten for hver tilstand ($P_i = e^{-\epsilon_i/k_BT}/Q$) og til å utlede makroskopiske størrelser som indre energi, entropi og fri energi. Kort sagt inneholder $Q$ all statistisk informasjon om systemet, og er broen mellom mikrotilstandene og de målbare termodynamiske størrelsene. Husk at vi bruker $q$ for én partikkel, og $Q$ for systemer med mange partikler.
#
#
# **c)**
#
# * Vi ønsker å sette opp partisjonsfunksjonen $Q$ for systemet uttrykt ved energidifferanser, gitt verdiene i tabellen og at $\Delta \varepsilon / k_B T = 1$.
#
# Vi starter med definisjonen av $Q$ som en sum av Boltzmann-faktorer over **alle enkeltmikrotilstander** $i$:
#
# $Q = \sum_{i} e^{-E_i / k_B T}$
#
# Energidifferansen $\Delta E_i$ er differansen mellom mikrotilstandens energi $E_i$ og grunntilstandsenergien $E_0$. Vi finner et uttrykk for $E_i$:
#
# $\Delta E_i = E_i - E_0 \Longrightarrow E_i = \Delta E_i + E_0$
#
# For å forenkle uttrykket enda mer definerer $E_0 =0$, slik at
#
# $\Delta E_i = E_i$
#
# Vi setter uttrykket inn i $Q$ og får
#
# $Q = \sum_{i}  e^{-\Delta E_i / k_B T}$
#
# Husk nå at dette er summen over **alle mikrotilstander**. Mange mikrotilstander deler samme $\Delta E$. Vi grupperer derfor summen etter de distinkte energiverdiene og lar $\Omega(\Delta E)$ være antallet mikrotilstander med den energien:
#
# $Q = \sum_{j} \Omega(\Delta E_j)\, e^{-\Delta E_j/k_BT}$
#
# Her refererer $j$ til makrotilstanden. Uttrykkene vi får er dermed
#
# $Q = \Omega(\Delta E_0)\, e^{-\Delta E_0 / k_B T} + \Omega(\Delta E_1)\, e^{-\Delta E_1 / k_B T} + \Omega(\Delta E_2)\, e^{-\Delta E_2 / k_B T} + \Omega(\Delta E_3)\, e^{-\Delta E_3 / k_B T}$
#
# $Q = 1 + 4 e^{-\Delta \varepsilon / k_B T} + 6 e^{-2 \Delta \varepsilon / k_B T} + 4 e^{-3 \Delta \varepsilon / k_B T}$
#
# Ved $\Delta \varepsilon / k_B T = 1$ blir verdien
#
# $Q= 1 + 4 \cdot e^{-1} + 6 \cdot e^{-2} + 4 \cdot e^{-3}=3.48$
#
#
#
# * Vi ønsker å finne $\frac{p(\Delta E_1)}{p(\Delta E_0)}$ fra partisjonsfunksjonen $Q$.
#
# Fra Boltzmanns fordelingslov har vi at sannsynligheten for en **mikrotilstand** $i$ er gitt ved
#
# $p(E_i) = \frac{1}{Q} \, e^{-E_i/k_B T} = \frac{1}{Q} \, e^{-\Delta E_i/k_B T} = p(\Delta E_i)$
#
# Sannsynligheten for en **makrotilstand** (energi) $j$ finner vi ved å summere alle sannsynlighetene for mikrotilstanden som gir den energien, med andre ord, multiplisere med multiplisiteten $\Omega (E_j)$. Vi får dermed
#
# $p(E_j) = \frac{1}{Q} \, \Omega(\Delta E_j) \, e^{-\Delta E_j/k_B T}$
#
# Forholdet er dermed gitt ved
#
# $\frac{p(\Delta E_1)}{p(\Delta E_0)} = \frac{\frac{1}{Q} \, \Omega(\Delta E_1) \, e^{-\Delta E_1/k_B T}}{\frac{1}{Q} \, \Omega(\Delta E_0) \, e^{-\Delta E_0/k_B T}}=\Omega(\Delta E_1) \, e^{-\Delta E_1/k_B T} = 4 \cdot e^{-\Delta \varepsilon / k_B T} = 4 \cdot e^{-1}$
#
# $\frac{p(\Delta E_1)}{p(\Delta E_0)} = 1.47$
#
#
#
# * Vi ønsker å se på $Q$ i grensetilfellene $\Delta \varepsilon / k_B T \to 0$ og $\Delta \varepsilon / k_B T \to \infty$.
#
# Husk at uttrykkene vi fant for $Q$ er
#
# $Q = \Omega(\Delta E_0)\, e^{-\Delta E_0 / k_B T} + \Omega(\Delta E_1)\, e^{-\Delta E_1 / k_B T} + \Omega(\Delta E_2)\, e^{-\Delta E_2 / k_B T} + \Omega(\Delta E_3)\, e^{-\Delta E_3 / k_B T} = 1 + 4 e^{-\Delta \varepsilon / k_B T} + 6 e^{-2 \Delta \varepsilon / k_B T} + 4 e^{-3 \Delta \varepsilon / k_B T}$
#
# Når $\Delta \varepsilon / k_B T \to 0$ (høy $T$), vil $e^{\Delta E_i \varepsilon / k_B T} \to 1$ for alle $E_i$, slik at
#
# $Q \to \Omega(\Delta E_0) + \Omega(\Delta E_1) + \Omega(\Delta E_2) + \Omega(\Delta E_3) = 1 + 4 + 6 + 4 = 15$
#
# Dette er summen av alle mikrotilstandene, som betyr at ved høy $T$ blir alle mikrotilstander like tilgjengelige.
#
# Når $\Delta \varepsilon / k_B T \to \infty$ (lav $T$), vil $e^{\Delta E_i \varepsilon / k_B T} \to 0$ for alle $E_i$, slik at
#
# $Q \to \Omega(\Delta E_0) + \Omega(\Delta E_1) \cdot 0 + \Omega(\Delta E_2) \cdot 0 + \Omega(\Delta E_3) \cdot 0 = 1 + 0 + 0 + 0 = 1$
#
# Dette er grunntilstanden, og bare denne er tilgjengelig ved lav $T$.
#
#
# * Vi ønsker å finne indre energi $U$ og entropien $S$.
#
# Vi har at
#
# $U = \langle E \rangle = \ = \langle \Delta E \rangle = \sum_{i} \Delta E_{i} \, p(\Delta E_i) = \sum_{j} \Delta E_{j} \left( \frac{1}{Q} \, \Omega(\Delta E_j) \, e^{-\Delta E_j/k_B T} \right) = \frac{1}{Q} \sum_{j} \Delta E_j \, \Omega(\Delta E_j) \, e^{-\Delta E_j/k_B T}$
#
# Dermed får vi
#
# $U = \frac{1}{3.48} \left( \Delta E_0 \, \Omega(\Delta E_0) \, e^{-\Delta E_0/k_B T} + \Delta E_1 \, \Omega(\Delta E_1) \, e^{-\Delta E_1/k_B T} + \Delta E_2 \, \Omega(\Delta E_2) \, e^{-\Delta E_2/k_B T} + \Delta E_3 \, \Omega(\Delta E_3) \, e^{-\Delta E_3/k_B T} \right)$
#
# $U = \frac{1}{3.48} \left( 0 \Delta \varepsilon \cdot 0 \cdot 1 + \Delta \varepsilon \cdot 4 \cdot e^{-1} + 2\Delta \varepsilon \cdot 6 \cdot e^{-2} + 3\Delta \varepsilon \cdot 4 \cdot e^{-3} \right) = \frac{1}{3.48} \left( 3.69 \Delta \varepsilon \right)$
#
# $U = 1.060 \, \Delta \varepsilon$
#
# Videre har vi at
#
# $S = k_B \ln Q + \frac{U}{T} \Longrightarrow \frac{S}{k_B} = \ln Q + \frac{U}{k_B T}$
#
# Husk at vi har
#
# $\Delta \varepsilon / k_B T = 1 \Longrightarrow k_B T = \Delta \varepsilon$
#
# slik at vi får
#
# $S = \ln (3.48) + \frac{1.060 \, \Delta \varepsilon}{1 \, \Delta \varepsilon}$
#
# $S = 2.31$

# %% [markdown]
# #### Oppgave 5
#
# **a)** En makrotilstand er den overordnede beskrivelsen av systemet: hvor mange partikler som befinner seg på hvert energinivå, uten å bry seg om nøyaktig hvilken partikkel som ligger hvor. Den angis ved fordelingen $(n_0, n_1, n_2, n_3)$, altså antall partikler i $E=0$, $E=1$, $E=2$ og $E=3$. Venstre figur har makrotilstanden $(5,0,0,0)$, mens høyre har $(2,2,1,0)$. En mikrotilstand er derimot den fullstendige beskrivelsen, der vi også vet hvilken boks hver enkelt partikkel ligger i.
#
#
# **b)** Energien til én partikkel på nivå $E$ er $E k_B T$, så systemets indre energi er summen over alle partiklene, $U=\sum_i n_i \cdot E_i k_B T$.
#
# Venstre: alle fem partikler ligger i $E=0$, så
#
# $U = 5 \cdot 0 \cdot k_B T = 0$
#
# Høyre: to i $E=0$, to i $E=1$, én i $E=2$:
#
# $U = (2\cdot 0 + 2 \cdot 1 + 1 \cdot 2)\,k_B T = 4\,k_B T$
#
#
# **c)** Antall mikrotilstander er antall måter å fordele de fem skjelnbare partiklene på slik at makrotilstanden bevares. Med fordelingen $(n_0,n_1,n_2,n_3)$ er dette
#
# $\Omega = \frac{N!}{n_0!\,n_1!\,n_2!\,n_3!}$
#
# som er nettopp det uordnede utvalget fra kombinatorikkdelen.
#
# Venstre: $\Omega = \dfrac{5!}{5!\,0!\,0!\,0!} = 1$. Det finnes bare én måte å ha alle i grunntilstanden.
#
# Høyre: $\Omega = \dfrac{5!}{2!\,2!\,1!\,0!} = \dfrac{120}{2 \cdot 2 \cdot 1} = 30$.
#
#
# **d)** Entropien er $S = k_B \ln \Omega$.
#
# Venstre: $S = k_B \ln 1 = 0$.
#
# Høyre: $S = k_B \ln 30 \approx 3{,}40\,k_B \approx 4{,}70 \times 10^{-23} \text{ J}/\text{K}$ .
#
#
# **e)** Sammenligningen viser at høyere indre energi henger sammen med høyere entropi. Venstretilstanden har lavest mulig energi ($U=0$), men også lavest mulig entropi ($S=0$), fordi det bare finnes én eneste måte å realisere den på - alle partiklene må ligge i grunntilstanden. Når energien øker, blir det flere måter å fordele den på mellom partiklene, og dermed flere mikrotilstander og høyere entropi.
#
# Dette er kjernen i termodynamikken: et system trekkes ikke bare mot lav energi, men mot mange mikrotilstander. Grunntilstanden er energimessig gunstig, men entropisk fattig, og det er balansen mellom disse to som avgjør hvilken makrotilstand systemet faktisk havner i ved en gitt temperatur - akkurat den avveiningen Boltzmann-fordelingen beskriver.

# %% [markdown]
# #### Oppgave 6
#
# **a)** Både indre energi og entropi er tilstandsfunksjoner, slik at vi kan finne $\Delta U$ og $\Delta S$ ved å ta differansen mellom sluttverdien og startverdien. Vi får dermed
#
# $\Delta U = U_2 - U_1 = 150 \text{ J}-100 \text{ J} = 50.0 \text{ J}$
#
# $\Delta S = S_2 - S_1 = 2.3 \text{ J}/\text{K} - 2.0 \text{ J}/\text{K}=0.30 \text{ J}/\text{K}$
#
#
# **b)** Vi skal estimere temperaturen $T$, og kan gjør dette ved å
#
# $\frac{1}{T} \approx \frac{\Delta S}{\Delta U} \Longrightarrow T \approx \frac{\Delta U}{\Delta S} = \frac{50.0 \text{ J}}{0.30 \text{ J}/\text{K}} = 167 \text{ K}$
#
#
# **c)** Siden makrotilstand 2 har høyere entropi, vil systemet mest sannsynlig befinne seg der. At entropien er høyere der betyr at det er flere mikrotilstander som svarer til den makrotilstanden.

# %% [markdown]
# ## Uke 3 - Kinetisk gassteori MÅ FYLLES INN
#
# ### Diskusjonsoppgaver
#
# ### Regneoppgaver

# %% [markdown]
# ## Uke 4 - Makroskopisk termodynamikk MÅ LAGES
#
# ### Diskusjonsoppgaver
#
# ### Regneoppgaver

# %% [markdown]
# ## Uke 5 - Intermolekylære interaksjoner
#
# ### Diskusjonsoppgave
#
# #### Oppgave 1
#
# $$u(r) = 4\varepsilon\left[\left(\frac{\sigma}{r}\right)^{12} - \left(\frac{\sigma}{r}\right)^{6}\right], \qquad \sigma = 3{,}93\ \text{Å}, \quad \varepsilon/k_B = 148\ \text{K}$$
#
# **a)** Kurven starter nær null når avstanden $(r)$ er stor. Da påvirker molekylene hverandre svært lite. Når molekylene kommer nærmere hverandre, synker energien og danner en «brønn». Den laveste energien finner vi ved $r \to 0$, som er den mest stabile avstanden mellom molekylene.
#
# Videre øker energien igjen og blir lik null ved $r = \sigma$. På dette punktet er de attraktive og frastøtende kreftene akkurat like sterke og opphever hverandre. For avstander større enn $\sigma$ dominerer tiltrekningen, slik at den potensielle energien er negativ. For avstander mindre enn $\sigma$ blir frastøtningen svært sterk, og energien øker raskt til store positive verdier når molekylene presses enda nærmere hverandre.
#
# Verdien $\sigma$ kan derfor tolkes som en effektiv «hard» molekylstørrelse, en grense der molekylene begynner å frastøte hverandre kraftig.
#
#
# **b)** Likevektsavstanden ligger *utenfor* $\sigma$ fordi $\sigma$ bare er der den potensielle energien er lik null, ikke der *kreftene* balanserer. Det frastøtende $r^{-12}$-leddet avtar raskere enn det tiltrekende $r^{-6}$-leddet. Derfor vil tiltrekningen fortsatt dominere når vi beveger oss litt utover $\sigma$, og den potensielle energien fortsetter å synke.
# Først ved likevektsavstanden $r_0$ er de tiltrekkende og frastøtende kreftene akkurat like store. Da er energien på sitt laveste, og systemet er mest stabilt.
#
#
# **c)** Sett $r^* = 2^{1/6}\sigma$ inn: $(\sigma/r^*)^6 = (2^{-1/6})^6 = \tfrac12$, og $(\sigma/r^*)^{12} = \tfrac14$. Dermed
#
# $$u(r^*) = 4\varepsilon\left[\tfrac14 - \tfrac12\right] = -\varepsilon.$$
#
# Brønndybden er altså nettopp $\varepsilon$, tilsvarende 148 K, eller $\varepsilon = k_B \cdot 148 \approx 2{,}0\times10^{-21}\ \text{J}$. Til sammenligning er en kovalent C–H-binding rundt $7\times10^{-19}\ \text{J}$ — flere hundre ganger sterkere. Bindingen mellom to metanmolekyler er derfor *svak*: den rives lett fra hverandre av termisk bevegelse, og metan koker allerede ved 112 K.
#
# **d)** Kraften er $f(r) = -\dfrac{du}{dr}$. Den er null i bunnen av brønnen ($r = r^*$) — et *stabilt* likevektspunkt. For $r < r^*$ er kraften frastøtende (peker utover), for $r > r^*$ er den tiltrekkende (peker innover). Enhver forskyvning fra $r^*$ gir en gjenopprettende kraft, derav stabiliteten.
#
# ![3e](bilder/LJ_3e.svg)
#
# **e)** Å dele $\varepsilon$ på $k_B$ gir en temperaturskala:
# * Når $k_B T \gg \varepsilon$ er den termiske energien langt større enn brønndybden, bevegelsen river molekylene fra hverandre, og stoffet er gass.
# * Når $k_B T \approx \varepsilon$ er de to sammenlignbare, og molekylene begynner å bli fanget i brønnen: kondensasjon setter inn. $\varepsilon/k_B$ er derfor grovt sett temperaturen der kondensasjon skjer, og metans kokepunkt (112 K) ligger nettopp i nærheten av 148 K.
#
# #### Oppgave 2
#
# | Molekyl | $\varepsilon/k_B$ (Kelvin) | $\sigma$ (Å) |
# |---|---|---|
# | Helium (He) | 10,22 | 2,58 |
# | Etan (C₂H₆) | 205 | 4,23 |
# | Benzen (C₆H₆) | 440 | 5,27 |
#
# **a)** $\sigma$-kolonnen er størrelse, $\varepsilon$-kolonnen er bindingsstyrke. Benzen er både størst ($\sigma = 5{,}27$ Å) og binder sterkest ($\varepsilon/k_B = 440$ K); helium er minst og svakest.
#
# **b)** Ingen av dem har permanent dipol, så Keesom-krefter (dipol–dipol) og Debye-krefter (dipol–indusert dipol) er utelukket. Tiltrekningen kommer fra **London-dispersjonskrefter**: øyeblikkelige fluktuasjoner i elektronskyen skaper flyktige dipoler, som induserer korrelerte dipoler i nabomolekylet.
#
# **c)** Størrelsen på $\varepsilon$ øker med antall elektroner og hvor lett elektronskyen kan forskyves, altså **polariserbarheten**. Helium har bare to elektroner som er sterkt bundet til kjernen. Elektronskyen er derfor lite polariserbar, noe som gir svake tiltrekningskrefter og en potensialbrønn med liten dybde. Benzen har derimot mange elektroner, inkludert et lett polariserbart $\pi$-elektronsystem. Dette gjør at det lett dannes store øyeblikksdipoler, som gir sterkere tiltrekning mellom molekylene og dermed *en dypere potensialbrønn*.
#
#
# **d)** Rangering etter $\varepsilon$: He < etan < benzen. Reelle kokepunkter: He $-269\,^\circ$C (4 K), etan $-89\,^\circ$C (184 K), benzen $+80\,^\circ$C (353 K). Rangeringen stemmer helt — dypere brønn gir høyere kokepunkt, og størrelsesordenen på $\varepsilon/k_B$ ligger nær de faktiske kokepunktene i kelvin.
#
# ![LJ_op2](bilder/LJ_op2.svg)
#
# **e)** Oppover alkanrekka øker både antall elektroner og kontaktflaten mellom molekylene. Det er den *samme* London-dispersjonen som virker hele veien, men den summerer seg opp langs kjeden: flere CH₂-ledd betyr flere bidrag, så $\varepsilon$ (og $\sigma$) vokser jevnt. Derfor er de korteste alkanene (metan–butan) gasser, mellomlange (ca. pentan–heksadekan) væsker, og de lengste voksaktige faste stoffer ved romtemperatur — stearinlys er nettopp lange alkaner holdt sammen av akkumulert dispersjon.
#
#
# #### Oppgave 3
#
# | Stoff | $a$ (L²·bar·mol⁻²) | $b$ (L·mol⁻¹) |
# |---|---|---|
# | Helium (He) | 0,035 | 0,0238 |
# | Argon (Ar) | 1,355 | 0,0320 |
# | Nitrogen (N₂) | 1,370 | 0,0387 |
# | Metan (CH₄) | 2,30 | 0,0431 |
# | Karbondioksid (CO₂) | 3,64 | 0,0427 |
# | Benzen (C₆H₆) | 18,24 | 0,1193 |
#
# **a)** $a$ hører til den **attraktive** delen av $u(r)$ (den $-(\sigma/r)^6$-halen), altså til $\varepsilon$: den senker trykket fordi molekylene trekkes svakt mot hverandre i stedet for mot beholderveggen. $b$ hører til den **repulsive** delen (den harde veggen ved liten $r$), altså til $\sigma$: molekylene har et endelig egenvolum, så det tilgjengelige volumet blir $V_m - b$.
#
# **b)**
# * Etter størrelse ($b$): He < Ar < N₂ < CO₂ ≈ CH₄ < benzen.
# * Etter tiltrekning ($a$): He < Ar ≈ N₂ < CH₄ < CO₂ < benzen.
#
# Generelt følger de to parameterne hverandre: større molekyler har flere elektroner, høyere polariserbarhet og dermed sterkere dispersjonskrefter. Sammenhengen er likevel ikke perfekt. Et godt eksempel er CO₂ og metan, som har nesten samme verdi av $b$ (0,0427 mot 0,0431), men der CO₂ har en betydelig større verdi av $a$ (3,64 mot 2,30). Årsaken er at CO₂ i tillegg til dispersjonskreftene har et kvadrupolmoment og høy elektrontetthet i C=O-bindingene. Dette gir ekstra tiltrekning mellom molekylene. Parameteren $a$ avhenger derfor ikke bare av molekylstørrelsen, men også av hvordan elektronene er fordelt i molekylet.
#
# **c)**
# * Stor $a$, liten $b$: tiltrekningsdominert, avviker mest ved **lav temperatur**, der tiltrekningen får molekylene til å samle seg og trykket faller under idealverdien (til slutt kondensasjon).
# * Stor $b$, liten $a$: egenvolum-dominert, avviker mest ved **høyt trykk / høy tetthet**, der molekylene presses tett og den endelige størrelsen skyver trykket over idealverdien. **Kort sagt: $a$ styrer avviket ved lav $T$, $b$ styrer det ved høyt $P$.**
#
# **bonus** I hard-kule-modellen finnes ingen tiltrekning, så $a = 0$. Molekylene opptar fortsatt plass, så $b$ er endelig (proporsjonal med molekylvolumet). Vi sitter igjen med en gass av harde kuler som aldri tiltrekker hverandre — den avviker fra idealgassen kun gjennom egenvolumet, gir alltid *høyere* trykk enn idealgassen ved høy tetthet, og kondenserer aldri.
#
#
# #### Oppgave 4
#
# **a)** *Gass:* etter det korte forbudte området (der molekylene ikke kan overlappe) flater $g(r)$ raskt ut mot 1 — nesten ingen struktur. *Væske:* en tydelig første topp (nærmeste naboskall), etterfulgt av noen få, gradvis svakere topper — korttrekkende orden. *Fast stoff:* en serie skarpe topper som fortsetter over lange avstander — langtrekkende orden.
#
# **b)** $g(r) = 0$ ved svært små $r$ speiler den repulsive delen av $u(r)$: den harde veggen gjør at to molekyler ikke kan komme nærmere enn omtrent $\sigma$. Sannsynligheten for å finne en nabo innenfor den avstanden er derfor null.
#
# **c)** Posisjonen til første topp er den mest sannsynlige naboavstanden (nær $r^*$, bunnen av parpotensialet). At toppene *dør ut* på litt lengre avstand betyr at ordenen kun er lokal — hvert molekyl «kjenner» sine nærmeste naboer, men korrelasjonen forsvinner over noen få skall. Dette er signaturen til en væske.
#
# **d)** *Fast* argon gir skarpe **Bragg-topper**: den periodiske ordenen gjør at konstruktiv interferens kun oppstår ved bestemte vinkler, gitt ved $n\lambda = 2d\sin\theta$. *Flytende* argon gir brede, diffuse ringer, siden bare korttrekkende orden finnes — ingen skarpe, veldefinerte plan å reflektere fra.
#
# **e)** Sett inn verdiene:
#
# | $r$ | $u_1 = -1/r$ | $u_2 = -1/r^6$ |
# |---|---|---|
# | 1 | $-1$ | $-1$ |
# | 2 | $-0{,}5$ | $-1/64 \approx -0{,}016$ |
#
# Ved $r = 1$ er de like sterke; ved $r = 2$ er Coulomb-potensialet $u_1$ omtrent 32 ganger sterkere. $1/r$ dør altså mye saktere med avstanden enn $1/r^6$. Derfor rekker monopol–monopol-vekselvirkningen (ione–ione) langt og gir **langtrekkende orden** — som i en NaCl-krystall, der hvert ion føler mange skall av naboer. Dispersjon ($1/r^6$) dør raskt og merkes bare mellom nærmeste naboer, så en edelgassvæske får bare **korttrekkende orden**. Dette illustrerer kapittelets poeng om at høyere multipolmomenter (dipol $\sim 1/r^3$, dispersjon $\sim 1/r^6$, …) gir stadig svakere og mer korttrekkende vekselvirkninger enn den langtrekkende monopolen.
#
# #### Oppgave 5
#
# $$F = U - TS$$
#
# **a)** Ved **høy** temperatur er $T$ stor, så $-TS$-leddet veier tungt: entropien vinner, og systemet velger den fasen med flest tilgjengelige mikrotilstander — gassen. Ved **lav** temperatur er $-TS$-leddet lite, så $U$-leddet avgjør: systemet velger lavest potensiell energi — den kondenserte fasen. Temperaturen er «vekten» som avgjør hvor tungt entropien teller mot energien i $F = U - TS$.
#
# **b)** Energien «vil» ha molekylene nær hverandre, i bunnen av den attraktive brønnen i $u(r)$ (lav $U$) — det er dette $a$-leddet i van der Waals-likningen fanger. Entropien «vil» spre dem utover (gass, mange mikrotilstander, høy $S$). Ved høy $T$ vinner entropien. Når du kjøler ned, blir $-TS$-leddet mindre viktig, og energigevinsten ved å ligge i brønnen blir avgjørende — molekylene samler seg, og gassen kondenserer.
#
# **c)** *Sublimasjon* (tørris, fast CO₂ → gass): entropien favoriseres sterkt, og ved lavt trykk hoppes væskefasen over. *Smelting* (is → vann): entropien øker, og noe av hydrogenbindingsenergien gis opp. I begge tipper oppvarming balansen mot den fasen med høyest entropi, mens avkjøling tipper mot den med lavest energi / mest orden. (De fullstendige fasediagrammene kommer i et senere kapittel.)
#
# **d)** At is er *mindre* tett enn vann viser at «lavest energi» ikke alltid betyr tettest pakking. De retningsbestemte hydrogenbindingene tvinger vannmolekylene inn i et åpent, «hullete» gitter som er energetisk gunstig, men romslig. Det er altså geometrien til bindingene — ikke bare styrken — som avgjør strukturen, og balansen energi/entropi kan gi et mindre tett fast stoff enn væsken.
#
# ---
#
# #### Bonusoppgave
#
# **a)** Vannmolekyler binder sterkt til hverandre gjennom hydrogenbindinger. En upolar hydrokarbonhale kan ikke delta i dette nettverket, og «forstyrrer» det der den ligger. Halene trives derfor dårlig omgitt av vann.
#
# **b)** Rundt hver eksponert hale må vannmolekylene ordne seg i et strukturert «bur» (klatrat-lignende) for å bevare flest mulig hydrogenbindinger seg imellom — det gir *lav* entropi for disse vannmolekylene. Skjuler man halene inni en micelle, frigjøres burvannet til å bevege seg fritt igjen. Vannets entropiøkning overgår da entropitapet ved å ordne halene, slik at **total entropi øker**. Selvorganiseringen er derfor entropidrevet — dette er den hydrofobe effekten.
#
# **c)** For kondensasjon (Oppgave 5) er det $\Delta U < 0$ som driver: energien senkes, og entropitapet ($TS$) aksepteres fordi $T$ er lav. For den hydrofobe effekten er det $\Delta S_\text{total} > 0$ som driver, via det frigjorte vannet. Begge senker den frie energien $F = U - TS$, men fra hver sin ende av uttrykket. Poenget er fint: at ting «klumper seg sammen» er *ikke* alltid energidrevet — her er det entropien som gjør jobben.
#
# **d)** Lipiddobbeltlag og flytende krystaller gir diffuse XRD-topper, ikke skarpe Bragg-topper. Det forteller at en membran har *flytende*, korttrekkende orden — nærmere en todimensjonal væske enn en krystall. Molekylene er ordnet lokalt (regelmessig avstand mellom hodegrupper, halene pakket sammen), men uten langtrekkende krystallinsk orden.
#
# **e)** *(Åpen diskusjon)* Den samme balansen går igjen i proteinfolding (hydrofobe sidegrupper gjemmes i en kjerne), i cellemembraner, i DNA-basestabling, i emulsjoner og i at olje og vann ikke blandes. Det er rimelig å si at det er **samme fysikk** hele veien — svake krefter (dispersjon, dipol, hydrogenbinding) i konkurranse med entropi, styrt av $F = U - TS$ — ikke bare en analogi. Forskjellen fra tilfelle til tilfelle er hvilket ledd som dominerer, og om entropibidraget kommer fra molekylene selv eller fra omkringliggende vann.

# %% [markdown]
# ## Uke 6 - Termokjemi
#
# ### Diskusjonsoppgaver
#
# #### Oppgave 1
#
# **a)** I tilstandsfunksjoner kan veien mellom start- og sluttilstand velges fritt. Det å dele prosessen opp i delprosesser svarer til å endre veien men så lenge start- og sluttilstanden er de samme vil endringen i tilstandsfunksjonen _totalt_ være den samme. Det å finne termodynamiske størrelser eksperimentelt kan være utfordrende. Istedenfor holder det å vite start og slutt-tilstandene. Veien mellom tilstandene kan da konstrueres ved å legge sammen kjente reaksjoner og man kan regne ut mange termodynamiske størrelser basert på tabeller over eksperimentelt målte verdier. Hess lov gjelder for alle tilstandsfunksjoner, men uttrykkes for eksempel slik for entalpi:
#
# $$\Delta H = \sum \Delta H(produkter) - \sum \Delta^{\circ} _f H(reaktanter)$$
#
# Dersom vi har delprosessene A, B, C, vil vi heller bruke loven slik:
#
# $$\Delta H = \Delta H(A) + \Delta H(B) + \Delta H(C)$$
#
# Innad i disse delprosessene har allerede forskjellen i entalpi mellom start- og sluttilstand blitt beregnet eller målt i henhold til formelen over. I neste oppgave vil du se et eksempel på dette.
#
# **b)** La oss begynne med delprosess (1), vi ser at produktet vi ønsker å danne er på venstre (reaktant) side av likningen. Derfor må vi "snu" denne likningen for å få diboran som produkt.
#
# $${B_2O_3}_{(s)} + 3\, {H_2O}_{(g)} \longrightarrow {B_2H_6}_{(g)} + 3\, {O_2}_{(g)}$$
#
# Dette fører til at vi må bytte fortegn på entalpiendringen til delprosessen $\Delta H^{\circ}(1)$. Vi har laget den første delen av likningen vår:
#
# $$\Delta _fH{\circ} = -\Delta H^{\circ}(1) ...$$
#
# Vi ser at vi trenger ${B_2O_3}_{(s)}$ og $3\, {H_2O}_{(g)}$ for å gjøre delprosess (1). Dette kan vi få fra delprosess (2) og (3). Vi får ${B_2O_3}_{(s)}$ "direkte" fra prosess (2) og kan derfor legge entalpiendringen for prosessen rett inn i uttrykket vårt:
#
# $$\Delta _fH^{\circ} = -\Delta H^{\circ}(1) + \Delta H^{\circ}(2) ...$$
#
# Vi får ${H_2O}_{(g)}$ "direkte" fra prosess (3), men kun ett vannmolekyl av gangen. Derfor må vi gange delprosessen med tre og vi får derfor også en tre ganger så høy entalpiendring:
#
# $$\Delta _fH^{\circ} = -\Delta H^{\circ}(1) + \Delta H^{\circ}(2) + 3 \times \Delta H^{\circ}(3)$$
#
# Vi har funnet uttrykket vi trenger, og er klare for å regne ut dannelsesentalpien ved hjelp av tabellverdier.
#
#
# #### Oppgave 2
#
# **a)** Entalpi har som matematisk uttrykk:
#
# $$\Delta H = \Delta U - pV$$
#
# Dersom trykket holdes konstant, er entalpien lik:
#
# $$\Delta H = q_p$$
#
# Det vil si varmeoverføringen ved konstant trykk. Utledningen av dette er forklart i detalj på "Makroskopisk termodynamikk" - siden. Entalpi er svært nyttig fordi vi "slipper" å tenke på arbeidsleddet til den indre energien. I kjemi er entalpi en særlig nyttig størrelse fordi de fleste kjemiske prosesser foregår ved konstant trykk. Entalpien lar oss dermed regne på varmeoverføringen som skjer i løpet av slike prosesser.
#
# **b)** En _endoterm_ prosess er en prosess som tar opp varme fra omgivelsene. For slike prosesser har vi som konvensjon at entalpiendringen $\Delta H$ har positivt fortegn. En _eksoterm_ prosess er en prosess som gir fra seg varme til omgivelsene. For slike prosesser har vi som konvensjon at entalpiendringen har negativt fortegn.
#
# **c)** Dannelsesentalpier er tabulerte verdier for mange vanlige kjemiske prosesser. De er enten direkte målt eksperimentelt eller beregnet fra eksperimentelle data. Vi har som utgangspunkt at dannelsesentalpien til grunnstoffer i sin mest stabile tilstand er lik 0. Dannelsesentalpier er verdiene vi benytter oss av når vi bruker Hess lov for å beregne entalpiendringer for ulike prosesser. Vi må bryte ned prosessene våre til delprosesser som har kjente, tabulerte dannelsesentalpier.
#
# **d)** I løpet av en kjemisk prosess ser vi ofte en endring i sammensetningen til systemet vi er interesserte i: I kjemiske reaksjoner forvandles reagenser til produkter ved at kjemiske bindinger brytes og dannes. I faseoverganger endres de _intermolekylære_ kreftene som holder molekylene i systemet sammen. Og i løsninger kan for eksempel salter _solvatiseres_ ved at ionene omringes av løsemiddel molekyler. For enkelte prosesser er det ikke sikkert vi har tilgang på dannelsesentalpiene vi trenger for å regne på $\Delta H$. Da kan det være nyttig å kunne resonnere seg frem til hva slags entalpiendring vi forventer for prosessen basert på de molekylære kreftene i systemet.
#
# Kort fortalt kan vi gjøre dette ved å vurdere den relative styrken til bindingene som brytes og dannes i løpet av prosessen! _Svake bindinger_ gir atomene mye frihet til å vibrere, rotere og bevege seg rundt og ligger derfor høyt i energi. Fordi et system alltid tenderer mot å minimere energien sin, byttes gjerne svake bindinger ut med _sterke bindinger_ som ligger lavere i energi da systemet blir mer rigid og atomene har mindre frihet til vibrasjon, rotasjon og translasjon. Energigapet mellom de to tilstandene frigjøres som varme, og det er slik vi ender opp med **eksoterme prosesser**. Vi kan også gå motsatt vei: I faseoverganger fra væske til gass bytter vi ut _sterke interaksjoner_ som gjør at væsken holdes sammen med _svake interaksjoner_ som lar gassen flyte fritt i rommet. I dette tilfellet må systemet ta opp varme fra omgivelsene som det bruker til å "tette" energigapet mellom tilstandene. Slik får vi **endoterme prosesser** hvor vi må tilføre varme til systemet.
#
# **e)** Se tilbake i laboppgavene du har hatt for å finne eksempler! I alle reaksjoner hvor du har måttet kjøle ned eller varme en løsning eller blanding har du mest sannsynlig tatt hensyn til en entalpiendring.
#
# #### Oppgave 3
#
# **a)** La oss se på bindingene som dannes og brytes i reaksjonen! Vi legger særlig merke til $P=O$ som er en veldig sterk binding. Også den nye $C=C$ bindingen er litt sterkere enn $C=O$ på reaktantsiden, men det er først og fremst dannelsen av $P=O$ bindingen som driver reaksjonen fremover. Fordi denne bindingen er sterkere og dermed mer stabil må energigapet mellom reaktanter og produktet tettes ved at systemet frigir energi på form av varme. Vi tror derfor at prosessen er _eksoterm_.
#
# **b)** Siden reaksjonen er eksoterm er det tryggest og mest praktisk å gjøre reaksjonen ved lav temperatur for å kontrollere varmeutviklingen.
#
#
# #### Oppgave 4
#
# **a)**
#
# _Faste stoffer_
#
# Faste stoffer kjennetegnes ved at de er _ordnede_ systemer, i hvert fall når vi sammenlikner dem med væsker og gasser. Partiklene i et fast stoff sitter i gittere. Nesten alle posisjonene i gitteret er opptatt av partikler og derfor er det lite mulighet for hver enkelt partikkel å bevege seg rundt. Disse faste posisjonene gjør at systemet kan arrangeres på få måter, og derfor har det tilgang til få mikrotilstander for å realisere sin makroskopiske tilstand. Dette forklarer hvorfor faste stoffer generelt har lav entropi. Dette forklarer også de makroskopiske karakteristikkene til faste stoffer: De kan ofte være harde og flyter ikke utover slik væsker og gasser gjør.
#
# _Væsker og løsninger_
#
# Væsker og løsninger eksisterer et sted mellom faste stoffer og gasser, det er verken fullstendig ordnede eller fullstendig uordnede. De flyter mye friere rundt enn et fast stoff gjør, men henger fremdeles sammen i motsetning til gasser som får spre seg i et åpent rom. I kjemi er vi særlig interesserte i løsninger. Et fast stoff som løses i en væske øker entropien sin, men løsemiddelet ordnes også i større grad enn før rundt det løste stoffet. Nyansene rundt entropi og løsninger forklarer vi nærmere senere i avsnittet.
#
# _Gasser_
#
# Gasser kjennetegnes ved at de er _uordnede_ systemer i forhold til faste stoffer og væsker. I et åpent system får gass slippe ut og vil derfor oppta et stort volum, for eksempel et helt avtrekksskap. Dette gjør at gassen har utrolig mye plass å boltre seg på! Gasspartiklene har utallige plasser de kan være og derfor kan systemet arrangeres på svært mange måter. Med andre ord har det tilgang på mange mikrotilstander for å realisere sin makrotilstand og vil derfor ha en høy entropi! De fleste prosesser som innebærer dannelse av gass er entropisk drevne.
#
# **b)** Å observere aggregattilstandene til speciene på reagens- og produktside av en reaksjonslikning er en av de letteste måtene å vurdere entropiendringen i løpet av en prosess på. Aggregattilstandene fast stoff (subskript (s)), løst stoff (i vann subskrift (aq)), væske (subskrift (l)) og gass (subskrift (g)) har økende grad av uorden som beskrevet over.
#
# Når vann koker får vi dannelse av vanndamp. Siden gass har høyere entropi enn væske får vi en positiv entropiendring.
#
# Et løsemiddel som kokes vil gå over i gassfase. For at reaksjonsblandingen ikke koker tørt bruker vi en kjøler. Når løsemiddel-molekyler i gassfase når kjøleren, kjøles de ned og blir til væske igjen. Siden væske har lavere entropi enn gass har prosessen en negativ entropiendring. **Bonus**: Hvilken drivkraft tar over når temperaturen går ned i det gassen treffer kjøleren? Jo, ved denne lavere temperaturen blir i stedet entalpien dominerende: Det blir gunstig for systemet å gå tilbake i væskeform fordi sterkere bindinger kan dannes mellom molekylene.
#
# Et salt som løses i vann får økt entropi fordi ionene i løsningen har langt flere måter å arrangere seg på enn i saltstrukturen. Vi må allikevel passe på koordinerende egenskaper. Alle ladde partikler i vann vil i variende grad koordineres til vannmolekyler via ione-dipol bindinger. For noen kationer med høy ladningstetthet (små eller høy positiv ladning), er den koordinerende effekten på vann så kraftig at entropien faktisk går ned ved å forsøke å løse saltet i vann!
#
# **c)** Når vi går fra én til to specier i løpet av en prosess forventer vi at entropien øker. Tenk på et salt som løses til to ioner eller et stort gassmolekyl som splittes i to mindre. Gå tilbake til siden om termokjemi og avsnittet om entropitrender. Der finner du en animasjon og oppgaver som hjelper deg i den mikroskopiske forklaringen.
#
# **d)** Enkelte små ioner med sterk positiv ladning som $Li^+$, $Mg^{2+}$ og $Al^{3+}$ trekker sterkt på vannmolekyler slik at de koordineres rundt ionet: Selv om vi får en entropigevinst ved å løse saltene, blir vannet så sterkt koordinert rundt ionene at vi får et totalt entropitap fordi vannet blir mye mer ordnet enn det var før! For eksempel danner ${MgSO_4}_{(s)}$ så sterke bindinger til vann at vi bruker stoffet som tørkemiddel i organisk kjemi: Dersom vi har bittelitt vann igjen i den organiske fasen vår, kan magnesiumsulfat trekke det til seg slik at vi får en vannfri fase. Dersom vi har en del vann i prøven vår, vil tørkingen gi fra seg litt varme og slik observerer vi at prosessen er eksoterm.
#
# **e)** Så lenge entropien totalt i universet øker, er det greit at den minsker lokalt i systemet vårt. Dersom prosessen _ikke er_ entropisk drevet vet vi at den er entalpisk drevet, altså gir den fra seg varme til omgivelsene slik som tørking. Denne varmeoverføringen øker entropien i omgivelsene og lar dermed prosessen overholde termodynamikkens andre lov🤓 Animasjonen viser en komplekseringsreaksjon som likner den vi har beskrevet for magnesiumsulfat. Varme kommer ut av systemet når komplekset dannes (små streker) og gir molekylene i omgivelsene rundt begerglasset mer energi og dermed høyere entropi. Totalt har entropien økt i universet!
#
#
# #### Oppgave 5
#
# **a)** Vi vet at entalpien beskriver varmeoverføring ved konstant trykk. Siden entalpien inngår i uttrykket for Gibbs fri energi er det vanligst at vi bruker Gibbs fri energi når vi har en situasjon hvor trykket er konstant. Siden de fleste kjemiske prosesser foregår ved konstant trykk er Gibbs fri en nyttig størrelse for oss! Vi regner ut Gibbs fri energi ved en gitt temperatur T som også holdes konstant.
#
# **b)** En prosess som er spontan vil gå uten å behøve kontinuerlig påvirkning av ytre krefter som elektrisk arbeid, varme eller lys. To forskjellige situasjoner blir ofte omtalt som spontane prosesser, og dette kan virke litt forvirrende: En prosess er spontan dersom den går av seg selv når den først har startet, selv om det kanskje var behov for en ytre påvirkningskraft for å starte den. Et eksempel på dette kan være forbrenninger: De går av seg selv, men trenger ofte en gnist eller flamme for å kunne starte. Vi sier også spontan om en prosess som både starter og går helt av seg selv. Pass også på at vi snakker om spontanitet gitt en viss temperatur T. Ofte vil det være behov for å varme reaksjoner for at de skal skje, fordi de er spontane veden høyere temperatur enn romtemperatur.
#
# Eksergon: $\Delta G < 0$ — prosessen frigjør fri energi og er spontan.
#
# Endergon: $\Delta G > 0$ — prosessen krever tilførsel av fri energi for å skje, altså ikke-spontan i den retningen.
#
# Nei, spontane prosesser skjer ikke nødvendigvis raskt. Her må vi skille mellom _termodynamikken_ og _kinetikken_! Mens Gibbs fri energi kun måler om start- eller sluttilstanden til prosessen er mest gunstig (gir best stabilitet), bestemmes farten av _aktiveringsbarrieren_ mellom de to tilstandene. Hva slags _mellomtilstand_ må vi innom for å danne produkt? Et kjent eksempel er prosessen Diamant $\longrightarrow$ Grafitt. Prosessen er svært eksergon, men går så sakte at det er nesten umulig å spore endringen. Tenk på en diamantring i en skuff. En slik ring kan gå i arv i generasjoner uten å bli til grafitt.
#
# **c)** Dette handler om hvilket av leddene i $\Delta G = \Delta H - T\Delta S$ som dominerer og "trekker" $\Delta G$ i negativ retning:
#
# Entalpisk drevet: $\Delta H$ er sterkt negativ og dominerer over $-T\Delta S$ (som kan være ubetydelig, eller til og med ugunstig). Typisk for reaksjoner med sterk binding/frigjøring av varme, f.eks. forbrenning.
#
# Entropisk drevet: $-T\Delta S$ er sterkt negativ (altså $\Delta S$ er stor og positiv) og dominerer, selv om $\Delta H$ kan være tilnærmet null eller positiv. Typisk for blanding, oppløsning av ioner, og den hydrofobe effekt.
#
# **d)** Med $\Delta H = -1368 \text{ kJ/mol}$ er entalpibidraget enormt, og reaksjonen er i all hovedsak entalpisk drevet — dette ene tallet er langt større i størrelse enn $T\Delta S$ vanligvis vil være ved romtemperatur for en slik reaksjon. I tillegg dannes det flere mol gass på produktsiden enn på reaktantsiden (fra 3 mol $O_2$​ til 2 mol $CO_2$​ + 3 mol $H_2O_{(g)}​ =$ 5 mol gass), noe som gir et positivt entropibidrag. Begge termer trekker altså $\Delta G$ i negativ retning — reaksjonen er sterkt spontan!
#
# At vi likevel ikke er redde for en åpen flaske etanol i romluft, handler om _kinetikk_, ikke _termodynamikk_: forbrenning har en betydelig aktiveringsenergi (man må tilføre en flamme eller gnist for å bryte O=O- og C–H-bindinger og starte radikalreaksjonene som skal til for forbrenningen). Uten denne "tenningsenergien" er reaksjonshastigheten ved romtemperatur neglisjerbar, selv om $\Delta G$ er svært negativ.
#
# #### Oppgave 6
#
# **a)** Med $\Delta H = -13 \text{ kJ/mol}$ (svakt negativ) og $\Delta S = +103 \text{ J/Kmol}$ (stor og positiv) er dette et tydelig eksempel på en entropisk drevet prosess: ved $T = 298 \, K$ er $-T\Delta S \approx -30.7 \text{ kJ/mol}$ klart mer negativt enn $\Delta H$-bidraget, og det er entropileddet som dominerer $\Delta G$.
#
# Kvalitativt: $C_{14}​-TAB$ er et ionisk fast stoff. Når det løses opp, brytes krystallgitteret og ionene (surfaktant-kationet og $Br^-
# Br$) får langt større translasjonsfrihet i løsning — dette gir en stor, positiv entropigevinst. Samtidig hydrateres det ladede hodet ($-N(CH_3)_3^+$) gunstig av vann (bidrar til det svakt negative $\Delta H$). Den lange hydrofobe halen derimot tvinger vannmolekylene rundt seg til å danne ordnede, hydrogenbundne "bur" — dette er i seg selv entropisk ugunstig lokalt. Nettoresultatet av disse motstridende bidragene er likevel en stor positiv $\Delta S$, fordi gitterbrudd + iondesolvatisering dominerer over den lokale vannordningen rundt halen.
#
# Bonus: Ved høyere konsentrasjoner, vil $C_{14}​-TAB$-molekylene selvorganisere seg til miceller: de hydrofobe halene samler seg i en kjerne bort fra vann, mens de ladede hodegruppene vender ut mot vannet. Drivkraften er nettopp den hydrofobe effekten — når halene klumper seg sammen, frigjøres de ordnede "vannburene" som omga hver enkelt hale tilbake til bulkvann, noe som øker den totale entropien i systemet, selv om halenes egen konfigurasjonsfrihet reduseres noe. Micelledannelse er dermed en entropisk drevet prosess.

# %%
from IPython.display import HTML

with open("Simuleringer/c14tab-micelle-dannelse.html", "r", encoding="utf-8") as f:
    html = f.read()

HTML(html)
# Out:
# <!DOCTYPE html>
# <html lang="no">
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width, initial-scale=1.0">
# <title>Micelldannelse &mdash; C&#8321;&#8324;-TAB</title>
# <style>
#   :root{
#     --ink:#2b2a27;
#     --paper:#faf8f4;
#     --card:#ffffff;
#     --line:#ddd8cd;
#     --cation:#3a6ea5;
#     --cation-dark:#274a72;
#     --tail:#4a4a46;
#     --oxygen:#c0392b;
#     --oxygen-dark:#8a2f22;
#     --hydrogen:#f5f1e8;
#     --hbond:#b9832f;
#     --font: "Iowan Old Style","Palatino Linotype",Georgia,serif;
#     --font-ui: -apple-system, "Segoe UI", Helvetica, Arial, sans-serif;
#   }
#   *{box-sizing:border-box;}
#   body{
#     margin:0;
#     background:var(--paper);
#     color:var(--ink);
#     font-family:var(--font-ui);
#     padding:32px 16px 48px;
#     display:flex;
#     justify-content:center;
#   }
#   .card{
#     max-width:780px;
#     width:100%;
#     background:var(--card);
#     border:1px solid var(--line);
# ...

# %% [markdown]
# **b)** En ikke-spontan prosess har $\Delta G > 0$ under de gitte betingelsene. Vi kan likevel få den til å skje ved å endre situasjonen slik at netto $\Delta G$ blir negativ. De vanligste strategiene er:
#
# - Koble prosessen til en sterkt eksergon prosess (energikobling). Hvis en ikke-spontan reaksjon ($\Delta G_1 > 0$) skjer samtidig med en sterkt spontan reaksjon ($\Delta G_2 < 0$, med $|\Delta G_2| > |\Delta G_1|$), blir summen $\Delta G_{tot} = \Delta G_1 + \Delta G_2 < 0$, og den koblede totalprosessen blir spontan. Dette er selve grunnprinsippet bak biologisk energiomsetning: hydrolyse av $ATP$ til $ADP + P_i$​ er sterkt eksergon ($\Delta G \approx -30 \text{ kJ/mol}$) og kobles til utallige ellers ikke-spontane prosesser i cellen: Muskelkontraksjon, aktiv transport over membraner, biosyntese av makromolekyler osv. Nøkkelen er at prosessene deler et felles mellomtrinn eller intermediat (f.eks. et fosforylert enzym), slik at de reelt er koblet og ikke bare skjer parallelt.
#
# - Tilføre arbeid utenfra. Man kan drive en ikke-spontan prosess ved å tilføre energi i en annen form enn varme, for eksempel typisk elektrisk arbeid eller lys:
#
#  Elektrolyse er et klassisk eksempel: nedbryting av vann til $H_2$​ og $O_2$​ er sterkt ikke-spontant ($\Delta G > 0$), men ved å påtrykke en ytre spenning (tilføre elektrisk arbeid $w_{elek}$​) kan vi likevel drive reaksjonen.
#
#  Fotosyntese er naturens variant: lysenergi driver den sterkt ikke-spontane omdannelsen av $CO_2$​ og $H_2O$ til glukose og $O_2$.
#
# - Katalyse: En katalysator senker aktiveringsenergien og øker dermed reaksjonshastigheten — den endrer altså _kinetikken_, ikke termodynamikken. Siden G er en tilstandsfunksjon (avhenger kun av start- og sluttilstand), påvirker en katalysator verken $\Delta G$, $\Delta H$ eller $\Delta S$ for reaksjonen i det hele tatt. En katalysator senker aktiveringsenergien slik at det blir lettere for prosessen å gå mellom start- og sluttilstanden: Veien endres. I praksis skjer dette ofte ved at katalysatoren bidrar til å stabilisere overgangstilstanden.

# %% [markdown]
# ### Regneoppgaver
#
# #### Oppgave 7
#
# **a)** La oss tenke over entalpiendringene vi har i løpet av prosessen. Vi har to faser i systemet vårt som til slutt vil blandes fordi isen smelter. Det innebærer at _vannet i koppen må avkjøles_ av isen og at _vannet i isen må varmes opp_ av vannet i koppen. Dette er de to entalpiendringene våre som sammen utgjør smelteentalpien! Da kan vi bruke Hess lov til å summere over entalpiendringene til delprosessene for å finne smelteentalpien. I oppgave b) går vi løs på beregningene.
#
# **b)** Fordi vi er ved konstant trykk, har vi $\Delta H = q_p$ og $q_p = \delta T \times C_p \times m$. Denne relasjonen kan vi bruke til å regne på $\Delta H _{vann}$ og $\Delta H _{isvann}$:
#
# $$\Delta H_{vann} = (T_{slutt} - T_{start}) \times C_p \times m_{vann} = (18.1 - 35.4) \, K \times 4.18 \, J.g^{-1}.K^{-1} \times 100.0 \, g$$
#
# $$\Delta H_{vann} = -7.23 \, kJ$$
#
# $$\Delta H_{isvann} = (T_{slutt} - T_{start}) \times C_p \times m_{isvann} = (18.1 - 0) \, K \times 4.18 \, J.g^{-1}.K^{-1} \times 25.8 \, g$$
#
# $$\Delta H_{isvann} = 1.95 \, kJ$$
#
# Hvordan slår vi sammen disse for å finne smelteentalpien? Siden vi antar at koppen er termisk isolert skjer det kun varmeoverføringer innad i vann-is systemet. Isen og isvannet tar opp varme, mens vannet i koppen gir fra seg varme. Summen av varmeoverføringene må være lik 0 og vi står igjen med:
#
# $$q_{vann} + q_{is} + q{isvann} = 0$$
#
# Siden vi er interesserte i smelteentalpien er det $q_{is}$ vi vil finne da dette er likt $\Delta H_{is}$ fordi vi er ved konstant trykk!
#
# $$\Delta H_{is} = q_{is} = -q_{vann} - q_{isvann} = - \Delta H_{vann} - \Delta H_{isvann}$$
#
# $$\Delta H_{is} = 7.23 \, kJ - 1.95 \, kJ = 5.28 \, kJ$$
#
# Dette er smelteentalpien for $25.8 \, g$ is! Vi ønsker å finne den molare smelteentalpien:
#
# Antall mol is er gitt ved:
#
# $$n = \frac{m_{is}}{M_{H_2O}} = \frac{25.8 \, g}{18.01 \, g/mol} = 1.43 \, mol$$
#
# Vi kan nå finne den molare smelteentalpien:
#
# $$\Delta _mH_{fus} = \frac{\Delta H_{is}}{n} = \frac {5.28 \, kJ}{1.43 \, mol} = 3.69 \, kJ/mol$$
#
# **c)** Vi ser at den beregnede verdien vår er betydelig lavere enn den teoretiske! Dette tyder på at ikke all varme som avgis fra vannet i koppen brukes til å varme opp isen og isvannet slik vi har antatt. I realiteten har vi varmeutveksling også med omgivelsene: Varmen kan lekke ut til bordet, luften, termometeret eller materiale i koppen. Mindre varme er tilgjengelig til å smelte isen enn det vi har antatt og derfor er den faktiske verdien for smelteentalpien høyere. Dersom isen kom rett fra fryseren kan det også hende den egentlig var kaldere enn $0^{\circ} C$, og da har ikke vi tatt hensyn til dette i beregningene våre. I tillegg har vi vanlige usikkerheter som lese- og kalibreringsfeil i termometeret, veieusikkerhet osv.
#
# **d)** Start med å finne dannelsesentalpiene du trenger fra læreboka eller et annet oppslagsverk. Her må vi bruke Hess lov:
#
# $$\Delta H = \sum \Delta H(produkter) - \sum \Delta^{\circ} _f H(reaktanter)$$
#
# Produktet her er de to ionene i løsning $Ag^+_{(aq)}$ og $Br^-_{(aq)}$, og reaktanten er sølvbromid-saltet $AgBr_{(s)}$:
#
# $$\Delta _{solv} H_m^{\circ} = \Delta_fH_m^{\circ}(Ag^+_{(aq)}) + \Delta_fH_m^{\circ}(Br^-_{(aq)}) - \Delta_fH_m^{\circ}(AgBr_{(s)})$$
#
# Nå kan vi sette inn tabellverdiene:
#
# $\Delta _{solv} H_m^{\circ} = (105.58 + (- 121.55) – ( - 100.37)) \, kJ/mol = 84.40 \, kJ/mol$
#
# Prosessen er endoterm. Det krever altså energi å få sølvbromid til å løses i vann og dette stemmer overens med at vi kjenner igjen sølvbromid som et tungtløselig salt. Grunnen til dette er at løsningsentalpien ikke er sterk nok til å veie opp for de svært sterke bindingene mellom sølv- og brom-ionene i saltet.
#
# #### Oppgave 8
#
# **a)** For organiske stoffer gir en forbrenningsreaksjon produktene vann og karbondioksid-gass. Siden fenol er et organisk stoff, får vi følgende balanserte likning for forbrenningsreaksjonen når fenol brenner i luft (oksygen):
#
# $$C_6H_5OH_{(s)} + 7 {O_2}_{(g)} \longrightarrow 6 {CO_2}_{(g)} + 3 H_2O_{(l)}$$
#
# Vi bruker igjen Hess lov:
#
# $$\Delta H = \sum \Delta^{\circ} _f H(produkter) - \sum \Delta^{\circ} _f H(reaktanter)$$
#
# Husk å ta hensyn til støkiometrien når vi løser for forbrenningsentalpien:
#
# $$\Delta _c H_m^{\circ} = 6\Delta_fH_m^{\circ}({CO_2}_{(g)}) + 3\Delta_fH_m^{\circ}(H_2O_{(l)}) - \Delta_fH_m^{\circ}(C_6H_5OH_{(s)}) - 7\Delta_fH_m^{\circ}({O_2}_{(g)})$$
#
# $$\Delta _c H_m^{\circ} = (6(-393.51) + 3(-285.83) – (-165.0) – 7(0)) \, kJ/mol = -3053.6 \, kJ/mol$$
#
# Reaksjonen er sterkt eksoterm.
#
# **b)** Reaksjonen vi har fått oppgitt har $NOCl_{(g)}$ som reaktant. Vi må derfor "snu om på reaksjonslikningen slik at vi får stoffet vi ønsker å danne på produktsiden:
#
# $$2 \, NO_{(g)} + {Cl_2}_{(g)} \longrightarrow 2 \, NOCl_{(g)}$$
#
# Dette innebærer at vi må bytte fortegn på den molare reaksjonsentalpien: $\Delta _r H_m^{\circ} = -75.5 \, kJ/mol$.
#
# Vi har fått oppgitt dannelsesentalpien for $NO_{(g)}$, og vi vet at dannelsesentalpien til klorgass er lik null fordi dette er elementets mest stabile tilstand. Vi er nå klare for å bruke Hess lov:
#
# $$\Delta_rH_m^{\circ} = 2\Delta _f H_m^{\circ} (NOCl_{(g)}) - 2\Delta_fH_m^{\circ}(NO_{(g)})$$
#
# Siden vi kjenner $\Delta_rH_m^{\circ}$ og $\Delta_fH_m^{\circ}(NO_{(g)})$, skriver vi om likningen litt:
#
# $$2\Delta _f H_m^{\circ} (NOCl_{(g)}) = \Delta_rH_m^{\circ} + 2\Delta_fH_m^{\circ}(NO_{(g)})$$
#
# $$2\Delta _f H_m^{\circ} (NOCl_{(g)}) = ((-75.5) + 2(90.25)) \, kJ/mol = 105 \, kJ/mol$$
#
# $$\Delta _f H_m^{\circ} (NOCl_{(g)}) = 52.5 \, kJ/mol$$
#
# **c)** Vi ønsker å danne ${Fe_2O_3}_{(s)}$ og vil derfor ha dette på produktsiden. For å få til dette må vi "snu" reaksjonslikningen til delprosess 1:
#
# $$2 Fe_{(s)} + 3 CO_{(g)} \longrightarrow {Fe_2O_3}_{(s)} + 3 C(grafitt)$$
#
# Dette innebærer at vi må bytte fortegn på reaksjonsentalpien til delprosessen:  $-\Delta H_m^{\circ}(1) = -492.6 \, kJ/mol$
#
# For å gjøre denne reaksjonen ser vi at vi trenger 3 mol $CO_{(g)}$-gass. Dette får vi som produkt ved å snu delprosess 3 og gjennomføre prosessen 3 ganger:
#
# $$3 \times ({CO_2}_{(g)} \longrightarrow CO_{(g)} + \frac{1}{2} {O_2}_{(g)})$$
#
# Siden vi trenger tre mol av disse molekylene og har snudd reaksjonslikningen, må vi både bytte fortegn på og gange reaksjonsentalpien til delprosessen med tre: $-3\Delta H_m^{\circ}(3) = -3(− 282.98) \, kJ/mol$.
#
# For å gjennomføre delprosess 3 trenger vi derimot 3 mol karbondioksid-gass. Det kan vi få ved å gjøre delprosess 2 3 ganger:
#
# $$ 3 \times (C(grafitt) + {O_2}_{(g)} \longrightarrow {CO_2}_{(g)})$$
#
# Vi må gange reaksjonsentalpien til delprosessen med 3: $3\Delta H_m^{\circ}(2) = 3(− 393.51) \, kJ/mol$
#
# Vi kan se bort ifra dannelsesentalpien til $C(grafitt)$, $Fe_{(s)}$ og ${O_2}_{(g)}$ da disse er grunnstoffene i sin mest stabile form ($\Delta _f H_m^{\circ} = 0 \, kJ/mol$). Vi kan nå summere sammen entalpiendringene for hver av delprosessene ved hjelp av Hess lov:
#
# $$\Delta _f H_m^{\circ}({Fe_2O_3}_{(s)}) = -\Delta H_m^{\circ}(1) + (-3\Delta H_m^{\circ}(3)) + 3\Delta H_m^{\circ}(2)$$
#
# $$\Delta _f H_m^{\circ}({Fe_2O_3}_{(s)}) = (-492.6 + (-3(− 282.98)) + 3(− 393.51)) \, kJ/mol = -824.2 \, kJ/mol$$
#
#
# #### Oppgave 9
#
# **a)** Vi bruker Hess lov til å regne ut tilstandsfunksjonene:
#
# $$\Delta H = \sum \Delta H(produkter) - \sum \Delta H(reaktanter)$$
#
# $$\Delta H_m^{\circ} = \Delta H_m^{\circ}(K^+_{(aq)}) + \Delta H_m^{\circ}(Cl^-_{(aq)}) - \Delta H_m^{\circ}(KCl_{(s)})$$
#
# $$Delta H_m^{\circ} = (−252.38 + (–167.16) - (−436.75)) \, kJ/mol = 17.21 \, kJ/mol$$
#
# $$\Delta S = \sum S(produkter) - \sum S(reaktanter)$$
#
# $$\Delta S_m^{\circ} = S_m^{\circ}(K^+_{(aq)}) + S_m^{\circ}(Cl^-_{(aq)}) - S_m^{\circ}(KCl_{(s)})$$
#
# $$\Delta S_m^{\circ} = (102.5 + 56.5 - 82.6) \, J.K^{−1}.mol^{−1} = 76.4 \, J.K^{−1}.mol^{−1}$$
#
# Vi kan nå regne ut Gibbs fri energi:
#
# $$\Delta G = \Delta H - T\Delta S$$
#
# $$\Delta G_m^{\circ} = Delta H_m^{\circ} - T\Delta S_m^{\circ}$$
#
# $$\Delta G_m^{\circ} = 17.21 \, kJ/mol - 298.15 \, K \times (76.4 \times 10^{-3}) \, J.K^{−1}.mol^{−1} = -5.57 \, kJ/mol$$
#
# **b)** Vi ser at reaksjonen er endoterm fra det positive fortegnet til entalpiendringen. Vi har derimot en positiv entropiendring! Det er denne økningen i entropi når saltet løses i vann som driver reaksjonen fremover.
#
# **c)** Dersom vi øker temperaturen vil $-T\Delta S$ leddet blitt mer negativt, altså vil reaksjonen bli _mer_ spontan (\Delta G blir mer negativ).
#
# #### Oppgave 10
#
# **a)** Vi bruker igjen Hess lov til å regne ut tilstandsfunksjonene:
#
# $$\Delta H = \sum \Delta H(produkter) - \sum \Delta H(reaktanter)$$
#
# $$\Delta _r H_m^{\circ} = \Delta H_m^{\circ}(CH_3COOH_{(l)}) - \Delta H_m^{\circ}(CO_{(g)}) - \Delta H_m^{\circ}(CH_3OH{(l)})$$
#
# $$\Delta _r H_m^{\circ} = (-484.5 - (-238.66) - (-110.53)) \, kJ/mol = -135.3 \, kJ/mol$$
#
# $$\Delta S = \sum S(produkter) - \sum S(reaktanter)$$
#
# $$\Delta _r S_m^{\circ} = S_m^{\circ}(CH_3COOH{(l)}) - S_m^{\circ}(CO_{(g)}) - S_m^{\circ}(CH_3OH_{(l)})$$
#
# $$\Delta _r S_m^{\circ} = (159.8 - 126.8 - 197.67) \, J/Kmol = -164.7 \, J/Kmol$$
#
# Nå har vi det vi trenger for å regne ut Gibbs fri energi:
#
# $$\Delta _rG_m^{\circ} = \Delta _r H_m^{\circ} - T\Delta _r S_m^{\circ}$$
#
# $$\Delta _rG_m^{\circ} = -135.3 \, kJ/mol - 298 \, K \times (-164.7 \times 10^{-3}) \, J/Kmol = -86.2 \, kJ/mol$$
#
# #### Oppgave 11
#
# Vi starter med å finne den differensiale formen av Gibbs fri energi:
#
# $$G = H - TS = U + pV - TS$$
#
# La oss finne noen differensielle former:
#
# Fra termodynamikkens første lov har vi:
#
# $$dU = dq + dw = dq - pdV$$
#
# Fra relasjonen mellom entropi og varme har vi:
#
# $$dS = \frac{dq_{rev}}{T} \leftrightarrow dq_{rev} = TdS$$
#
# Dette gir $dU$:
#
# $$dU = TdS - pdV$$
#
# La oss nå finne differensialet av den frie energien:
#
# $$dG = dU + d(pV) - d(TS)$$
#
# $$dG = TdS -pdV + pdV + Vdp - TdS - SdT$$
#
# Vi forkorter og får:
#
# $$dG = Vdp - SdT$$
#
# Den molare formen vil se slik ut:
#
# $$dG_m = V_mdp - S_mdT$$
#
# I temperaturintervallet oppgaven er interessert i er benzen en væske, så vi antar at trykket er konstant og får funksjonen:
#
# $$dG_m = - S_mdT$$
#
# Nå har vi alt vi trenger for å plotte!

# %%
import numpy as np
import matplotlib.pyplot as plt 

def dG(T_slutt, T_start = 298): 
    Sm = 173.3 #J/molK
    return -Sm * (T_slutt - T_start)

T_start = 298
T_slutt = np.linspace (T_start, 318, 20)

plt.plot(T_slutt, dG(T_slutt), color = "hotpink")
plt.xlabel ("Sluttemperatur (K)")
plt.ylabel ("Endring i Gibbs fri energi (J/Kmol)")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Uke 7 - Faseoverganger
#
# ### Diskusjonsoppgaver
#
# **Oppgave 1**
#
# - a) En fase er et system/område i rommet der alle fysiske egenskaper er uniforme. Med fysiske egenskaper menes for eksempel tetthet, kjemisk sammensetning, refraksjonsindeks, magnetisering osv.
#
# - b) i. Vi har én fase. Vi antar at løsningen vil være homogen siden vi forventer at $Na^{+}_{(aq)}$ og $Cl^-_{(aq)}$ ionene er spredt jevnt utover i løsningen. Dersom saltet ikke var løst hadde vi at hatt to faser.
#
# ii. Vi har to faser. Is og vann har veldig forskjellig tetthet og danner hver sin fase.
#
# iii. Vi har tre faser. Selv om både $CaCO_3$ og $CaO$ er i fast fase er det ingen grunn til å tro at de blandes til én fase der begge er spredt jevnt. Altså er $CaCO_3$, $CaO$ og $CO_2$ distinkte faser.
#
# - c) En superkritisk væske fås ved ekstreme betingelser når tettheten til væskeformen og gassformen til et stoff blir lik. Da viskes grensen mellom de to formene ut. Dette skjer ved en kritisk temperatur og trykk. For vann er det ved $374 ^{\circ} C$ og $218 \, atm$.
#
# - d) Vi har uttrykket:
#
# $$ C = s - r$$
#
# Der $C$ er antall komponenter, $s$ er antall specier og $r$ er antall relasjoner mellom dem. Gibbs faseregel gir oss antall frihetsgrader $F$:
#
# $$ F = C - P + 2 $$
#
# Der $P$ er antall faser ("**p**hases"). For de tre første systemene i oppgaven over får vi:
#
# i. Vi har fem specier $s$: $H_2O$, $H^+$, $OH^-$ i vannet og $Na^+$, $Cl-$ fra saltet.
#
# Vi har tre relasjoner $r$:
#
# $$ {H_2O}_{(l)} \leftrightharpoons H^+_{(aq)} + OH^-_{(aq)} $$
#
# $$ NaCl_{(s)} \leftrightharpoons Na^+_{(aq)} + Cl^-_{(aq)} $$
#
# Ladningsbalansen: Antall negative og positivt ladde specier må være balansert.
#
# Satt sammen får vi antall komponenter: $C=5-3=2$.
#
# Vi er klare for å bruke Gibbs faseregel:
#
# $$ F=2-1+2=3$$
#
# Her er frihetsgradene _sammensetning, temperatur og trykk_.
#
# ii. Vi har bare én specie $s$: Vann.
#
# Vi har ingen relasjoner mellom fasene, altså $r=0$ ¨
#
# Satt sammen får vi antall komponenter: $C=1-0=1$.
#
# Vi er klare for å bruke Gibbs faseregel:
#
# $$ F=1-2+2=1$$
#
# Her er frihetsgraden _temperatur eller trykk_.
#
# 3. Vi har tre specier $s$: $CaCO_3$, $CaO$ og $CO_2$
#
# Det er kun én reaksjon som binder speciene sammen (reaksjonen i oppgaveteksten), så vi for $r = 1$.
#
# Satt sammen får vi antall komponenter: $C = 3 - 1 = 2$.
#
# Vi er klare for å bruke Gibbs faseregel:
#
# $$ F=2-3+2=1$$
#
# Her er frihetsgraden enten _sammensetning, temperatur eller trykk_.
#
# - e) Når $ΔH=TΔS$ er $ΔG=0$. Det betyr at faseovergangstemperaturen (T) er hvor $ΔH$ er lik størrelsen av $TΔS$. $ΔG$ er positiv under frysepunktet (i eksempelet med vann og is) og denne faseovergangen er ikke spontan. $ΔG$ er negativ over frysepunktet, og dette er en spontan prosess. Frysepunktet er punktet hvor det går fra å være en ikke-spontan prosess til en spontan prosess, og systemet kan gå frem og tilbake mellom de to fasene reversibelt. Det vil si at $∆G= 0$ ved likevekt.
#
# - f) Ved kokepunktet til vann vil temperaturen være konstant selv om man tilfører varme. Da vil all energi gå med på å endre fra en fase (væske) til en annen (gass). Selv når vi har dannet noe gass vil det fremdeles gjenstå vann i væskeform som må omdannes for at overgangen blir fullstendig, og varmen går nettopp til å gjøre om vann i væskefase til vanndamp. Varmekapasiteten er definert som:
#
# $$C_{v}={\left(\frac{\partial U}{\partial T}\right)}_{V}$$
#
# Når U øker imens T holdes konstant divergerer Cv mot uendelig. Dette kalles også for en _første ordens faseovergang_.
#
# - g) Det finnes to typer faseoverganger som er relevante for kurset, _første_ og _andre ordens faseoverganger_. En første-ordens faseovergang er definert ved at den første deriverte til kjemisk potensial er diskontinuerlig. Det er kanskje kjent for deg at:
#
# $${\left(\frac{\partial \mathrm{\mu }}{\partial p}\right)}_{T}=V_{m}$$
#
# og at
#
# $${\left(\frac{\partial \mathrm{\mu }}{\partial T}\right)}_{p}={-S}_{m}$$
#
# Vi ser at Vm og Sm er diskontinuerlige i det midterste panelet som altså viser en første-ordens faseovergang. Fysisk forstår vi dette som at dersom fasen endres, får vi et plutselig hopp i molart volum og derfor i den molare entropien til stoffet. Tenk for eksempel på disse forskjellene i en væske versus en gassfase. Varmekapasiteten divergerer mot uendelig (se forklaring i oppgave f)). En andre-ordens faseovergang er definert ved at den andre-deriverte av kjemisk potensial er diskontinuerlig. Her er det ingen latent varme, entalpien er kontinuerlig og det er kun stigningstallet til entalpien som endrer seg. Dette fører til at varmekapasiteten er diskontinuerlig. En slik faseovergang er vist i det tredje panelet. Det øverste panelet viser ingen faseovergang.
#
#
# **Oppgave 2**
#
# - a) Punktet befinner seg innenfor et felt i diagrammet, så vi har én fase. Vi kan endre både temperatur og trykk uten å skifte felt, så vi har to frihetsgrader.
#
# - b) Punktet befinner i krysningen av to linjer, så her er to faser til stede samtidig. Dersom vi endrer temperaturen, må trykket øke/minske slik at vi holder oss langs linjen og vice versa. Derfor kan vi bare endre på ett parameter av gangen og har derfor kun én frihetsgrad.
#
# - c) Punktet befinner seg i krysningen av tre felter, så her er det faktisk tre faser til stede samtidig. Vi kan verken endre temperatur eller trykk uten at punktet må bryte med én av linjene og derfor har vi null frihetsgrader: Det er for spesifikt dette trykket og denne temperaturen at de tre fasene sameeksisterer i systemet. Vi kaller dette et _trippelpunkt_.
#
# - d) På samme måte som for punkt b) ligger punktet d) i grensen mellom to faser: Her er det altså to faser til stede samtidig. Vi kan endre temperaturen, men da avhenger trykket av temperaturen for at punktet fremdeles skal ligge på linja.
#
# I animasjonen under kan du undersøke svarene på oppgaven ved å stille på trykk og temperatur, hva skjer med likvektene mellom fasene i hvert punkt?

# %%
from IPython.display import HTML

with open("Simuleringer/fasediagram_embed.html", "r", encoding="utf-8") as f:
    html = f.read()

HTML(html)
# Out:
# <div id="phase-widget" style="
#   font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif;
#   background: #ffffff;
#   color: #1a1a1a;
#   padding: 2rem 1rem;
#   border: 1px solid #e0e0e0;
#   border-radius: 12px;
#   max-width: 620px;
#   margin: 0 auto;
#   box-sizing: border-box;
# ">
#
# <style>
# @keyframes pulseWarn { 0% { transform: scale(1); opacity: 0.55; } 100% { transform: scale(2.4); opacity: 0; } }
# .pulse-warn { animation: pulseWarn 0.85s ease-out infinite; transform-origin: center; transform-box: fill-box; }
# </style>
#
# <p style="text-align:center; font-size: 13px; color: #666; margin: 0 0 1rem;">
# Velg et punkt, og prøv så å endre bare temperaturen (uten å endre trykket). Se hvordan status endrer seg.
# </p>
#
# <svg id="phase-svg" width="100%" viewBox="0 0 600 500" style="display:block; margin-bottom: 1rem;"></svg>
#
# <div style="display: flex; justify-content: center; gap: 10px; margin-bottom: 1.25rem; flex-wrap: wrap;">
# ...

# %% [markdown]
# **Oppgave 3**
#
# - a) Kjemisk potensial er et mål på endring av fri energi på grunn av en endring i antall partikler. Kjemisk potensial er matematisk definert som den partielldervierte av den frie energien med hensyn på stoffmengde ved konstant volum ($C_V$)/trykk($C_p$) og temperatur:
#
# $$\mathrm{\mu }={\left(\frac{\partial G}{\partial N}\right)}_{V,T}$$
#
# - b) 	For et én-komponent system har vi:
#
# $$µ=G_{m}=\frac{H}{N}-\frac{TS}{N}=H_{m}-TS_{m}$$
#
# Grafen viser hvordan µ varierer med temperatur. Vi finner stigningstallet ved å derivere med hensyn på T:
#
# $${\left(\frac{\partial \mu }{\partial T}\right)}_{p}={\left(\frac{\partial G_{m}}{\partial T}\right)}_{p}=-S_{m}$$
#
# Så jo høyere entropi, jo større negativt stigningstall vil vises i et plot av kjemisk potensial mot temperaturen. Siden entropien er høyere for en gass (energien er mer spredt utover, flere antall frihetsgrader, tilgjengelige energinivåer osv) er stigningstallet for gassfasen størst. Vi ser noe av den samme trenden ved overgangen til væske fra fast stoff, men denne er svakere enn for overgangen fra væske til damp.
#
# - c) Fra fundamentallikningen for Gibbs fri energi vet vi at:
#
# $$dG=Vdp-SdT={\left(\frac{\partial G}{\partial p}\right)}_{T}dp+{\left(\frac{\partial G}{\partial T}\right)}_{p}dT$$
#
# Altså har vi:
#
# $${\left(\frac{\partial G}{\partial p}\right)}_{T}=V slik at {{\left(\frac{\partial G_{m}}{\partial p}\right)}_{T}=\left(\frac{\partial \mu }{\partial p}\right)}_{T}=\ V_{m}$$
#
# Gass har størst molart volum. Så stigningstallet ville vært størst for gassfasen. Men i dette tilfelle ville stigningen vært motsatt av forrige eksempel da
#
# $${\left(\frac{\partial \mu }{\partial p}\right)}_{T}=\ V_{m}$$
#
# Væsker har stort sett et større molart volum enn fast fase (bortsett fra vann), så stigningstallet for denne ville i de fleste tilfeller vært nest størst. Så grafen ville sett noe liknende ut som vist under:
#
# ![Kjemisk potensial vs. trykk](\bilder\kjemisk_potensial_trykk_faser.png)
#
# - d) For én-komponent stoffer har vi som sagt:
#
# $$\mu =G_{m}=V_{m}dp-S_{m}dT$$
#
# Avhengigheten av μ av trykk ved konstant temperatur er altså:
#
# $${\left(\frac{\partial G_{m}}{\partial p}\right)}_{T}={\left(\frac{\partial \mu }{\partial p}\right)}_{T}=\ V_{m}$$
#
# Avhengigheten av μ av temperatur ved konstant trykk er:
#
# $${\left(\frac{\partial G_{m}}{\partial T}\right)}_{p}={\left(\frac{\partial \mu }{\partial T}\right)}_{p}=\ -S_{m}$$
#
# - e) Figuren viser kjemisk potensial $\mu$ som funksjon av temperatur $T$ for fast og væske ved lavt og høyt trykk for to forskjellige stoffer. Helningen til hver kurve er gitt ved
#
# $$\frac{d\mu}{dT} = -S$$
#
# der $S$ er molarentropien. Væske har høyere entropi enn fast, og derfor blir kurven for væske brattere nedover enn kurven for fast.
#
# Smeltepunktet ved et gitt trykk er definert ved den temperaturen $T_f$ der fasene er i likevekt:
#
# $$\mu_\text{fast}(T_f) = \mu_\text{væske}(T_f)$$
#
# - i. Stoff (a) – «vanlig» oppførsel
#
# I figur (a) ser vi at ved lavt trykk har vi et smeltepunkt $T_f$ der kurvene for fast og væske krysser. Ved høyt trykk ligger kurven for fast lavere enn kurven for væske (fast har lavere $\mu$ enn væske), og de to kurvene skjærer hverandre ved en høyere temperatur $T_f'$ slik at $T_f' > T_f$. Dette kan forklares ved at fastfasen har **mindre molart volum enn væsken**:
#
# $$\Delta V_\text{fusjon} = V_\text{væske} - V_\text{fast} > 0$$
#
# Endringen i kjemisk potensial med trykk kan skrives som:
#
# $$d\mu \approx V\,dp$$
#
# Når trykket øker, vil fasen med minst volum (her fast) få størst reduksjon i $\mu$ og dermed bli mest stabil. Økt trykk favoriserer derfor fastfasen, og man trenger høyere temperatur for at væsken skal bli like stabil som fast → smeltepunktet øker med trykk. Dette er typisk oppførsel for «vanlige» stoffer, som mange metaller og salter, f.eks. aluminium eller natriumklorid.
#
# - ii. Stoff (b) – «anomal» oppførsel (vann-type)
#
# I figur (b) har vi igjen et smeltepunkt $T_f$ ved lavt trykk, der $\mu_\text{fast} = \mu_\text{væske}$. Ved høyt trykk ser vi at kurven for væske nå ligger lavere enn kurven for fast, slik at væsken er mer stabil ved høyt trykk. Skjæringspunktet (smeltepunktet) flyttes til en lavere temperatur $T_f'$ slik at $T_f' < T_f$. Dette betyr at fastfasen har **større molart volum enn væsken**:
#
# $$\Delta V_\text{fusjon} = V_\text{væske} - V_\text{fast} < 0$$
#
# Siden $d\mu \approx V\,dp$, vil økt trykk senke det kjemiske potensialet mest for fasen med minst volum, altså væsken. Økende trykk favoriserer derfor væskefasen, og det blir «lettere» å smelte — smeltepunktet synker når trykket øker. Denne oppførselen er karakteristisk for vann, der is har lavere tetthet enn flytende vann (is har større volum enn vann). Derfor synker isens smeltepunkt med økende trykk.
#
# **Oppgave 4**
#
# - a) I det første "skrå" partiet før første platå har vi fast stoff (dette er før vi når smeltepunktet). Det første, kortere platået viser smelteprosessen, da stagnerer også temperaturen på $0 \, ^{\circ} C$ frem til alle vannmolekylene har gått over i væskefase. I neste "skrå" parti har vi gått over i væskefase (dette er før vi når kokepunktet). Det andre, lengre platået viser kokeprosessen, da stagnerer temperaturen på $100 \, ^{\circ} C$ frem til alle vannmolekylene har gått over i gassfase. I det siste "skrå partiet" har vi fått vanndamp.
#
# - b) Platået ved kokepunktet (nr.2) er mye bredere enn platået ved smeltepunktet (nr.1). Ved konstant trykk vet vi at entalpiendringer er det samme som varmeoverføring:
#
# $$\Delta H = q_P$$
#
# Det bredere platået for kokepunktet tyder på at varmeoverføringen $q_{vap}$ som kreves for å gå fra vann i væskeform til vanndamp er mye større enn varmeoverføringen $q_{fus}$ som kreves for å gå fra is til vann i væskeform:
#
# $$q_{vap} > q_{fus}$$
#
# Dette blir da det samme som at:
#
# $$\Delta H_{vap} > q_{fus}$$
#
# - c) Hvordan kan vi beskrive grafen vår matematisk? Vi vet at relasjonen mellom varme og temperatur, som vi ser på i grafen vår, er gitt ved:
#
# $$ q = mC_p\DeltaT $$
#
# Der $C_P$ er varmekapasiteten. For å finne stigningstallet kan vi differensiere og kan da komme frem til uttrykket:
#
# $$\frac{dT}{dq} = \frac{1}{mc}$$
#
# Endringen i temperaturen når det skjer en endring i varmetilføringen (stigningstallet til grafen) er alstå proporsjonal med varmekapasiteten!
#
# Derfor forklares forskjellen i stigningstall i de forskjellige fasene ved at varmekapasiteten er ulik ettersom hvilken fase vann er i: Fast stoff har lav varmekapasitet, derfor kreves det lite varme for å øke temperaturen og derfor får vi en såpass bratt stigning. Væske har litt høyere varmekapasitet og det kreves derfor mer varme for å øke temperaturen og vi får en slakere stigning. Gass har aller høyest varmekapasitet og vil derfor ha den slakeste stigningen (selv om det er vanskelig å se i animasjonen).
#
# - d) Når vi krysser av for *«Vis alternativ: hva om smeltingen var andreordens i stedet?»* i simuleringen, får vi en stiplet kurve som viser hvordan oppvarmingen ville sett ut dersom smeltingen **ikke** var en førsteordens faseovergang. OBS: Det gjelder bare for smelteprosessen, ikke for resten av grafen. Vi ser at den viktigste egenskapen som forsvinner er platået ved smeltepunktet. Selv om fasen endres, fortsetter temperaturen å øke og systemet tar ikke opp noe latent varme (varmetilførsel uten å øke temperatur). Vi ser derimot en liten endring i stigningstall i det smeltningen skjer: Varmekapasiteten endres.
#
# I en førsteordens faseovergang er temperaturen konstant under overgangen: Den forblir den samme til alle molekylene i systemet har gått over i den nye fasen. Dette gir en flat del i q,T-diagrammet. Et eksempel på dette er for eksempel smelting av en isbit eller et annet fast stoff. I en andreordens faseovergang har vi ingen latent varme og temperaturen fortsetter å stige gjennom overgangen. Vi får ingen platåer i q,T-kurven, men stigningstallet får en knekk fordi den nye fasen har en annen varmekapasitet. Den andrederiverte til kurven får altså et sprang. Et eksempel på dette kan for eksempel være overgangen fra skilte væsker og gasser til en superkritisk væske hvor de to flyter inn i hverandre.
#
# - e)
#
# **Oppgave 5**
#
# Lage løsningsforslag
#
# **Oppgave 6**
#
# Lage løsningsforslag
#
# ### Regneoppgaver
#
# Her er en kode du kan bruke for å konstruere fasediagrammet:

# %%
import matplotlib.pyplot as plt

t = [20, 25, 30, 35, 40, 45, 50, 55, 60, 65, 68.8]
vann = [8.40, 8.71, 8.92, 9.34, 9.78, 10.62, 12.08, 13.88, 17.10, 22.26, 35.9]
fenol = [72.24, 71.38, 69.95, 68.28, 66.81, 65.02, 62.83, 60.18, 56.10, 49.34, 35.9]

plt.plot(vann, t, 'o-', label='Vannlag')
plt.plot(fenol, t, 's-', label='Fenollag')
plt.fill_betweenx(t, vann, fenol, alpha=0.15, color='gray')
plt.xlabel('Masseprosent fenol (%)')
plt.ylabel('Temperatur (°C)')
plt.title('Fasediagram: fenol–vann')
plt.legend()
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# - a) en fase med 8,9 % fenol og en fase med 70 % fenol
#
# - b) Den kritiske temperaturen for systemet er $69 °C$. Ved temperaturer over $69 °C$ vil væskene alltid være blandbare. Altså foreligger én fase.
#
# - c) Når en blanding med 20 masse-% fenol kjøles ned fra $70 ^{\circ} C$  vil det dannes to faser når temperaturen når $63 ^{\circ}C$ (krysser over fra énfase- til to-fase området). Ved dette punktet vil $∆G_{mix}$ gå fra å være negativ til å være positiv. Det dannes en fase med 20 % fenol og en fase med ca 53 % fenol.
#
# - d) Her kan vi bruke vekststangsregelen:
#
# $$\frac{n_{\alpha }}{n_{\beta }}=\frac{l_{\beta }}{l_{\alpha }}$$
#
# der α er vannlaget og β er fenollaget.
#
# $$\frac{n_{\alpha }}{n_{\beta }}=\frac{0.70-0.30}{0.30-0.089}=1.9$$
#
# Det er altså 1.9 ganger mer av vannlaget ved denne sammensetningen og temperaturen enn fenollag. Videre kan vi skrive:
#
# $$n_{\alpha }+n_{\beta }=1$$
#
# Siden det bare er de to fasene må summen blir 1 (100%).
#
# Vi har fra tidligere at:
#
# $$n_{\alpha }=1,9\cdot n_{\beta }$$
#
# Setter inn i likningen hvor de summeres til 1:
#
# $$1,9n_{\beta }+n_{\beta }=1\ n_{\beta }=\frac{1}{2,9}=0,34=34\%$$
#
# Det er altså 34% fenollag og (100%-34%) og 66% vannlag ved denne sammensetningen og temperaturen.
#
# - e) Her er en kode som lar deg plotte $\Delta G$:

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0.1, 0.9, 200)
for T in [273, 293, 313, 343, 373]:
    gamma = 684 / T
    dG = x*np.log(x) + (1-x)*np.log(1-x) + gamma*x*(1-x)
    plt.plot(x, dG, label=f'Temp ={T} K')

plt.xlabel('Molfraksjon x')
plt.ylabel(r'$\Delta G/nRT$')
plt.legend()
plt.show()

# %% [markdown]
# - f) Ved lave temperaturer har den frie energi kurven to minima som separeres av et maksimum rundt $x = 0.5$. I dette tilfellet foreligger det to faser og sammensetningen til disse svarer til minimumspunktene på den frie energi kurven. I det kritiske punktet ved $T = 70°C$ har $∆G$-kurven et utstrakt minimum. Her skjer det en faseovergang og systemet går fra 2 faser til en fase. Over det kritiske punktet vil en faseseperasjon gi lavere fri energi siden summen av de to fasene med lavest G (minima) er lavere. Når temperaturen ligger over den kritiske temperaturen foreligger det en fase og den frie energi parabolen har et minimum ved $x = 0.5$.
#
# **Oppgave 8**
#
# Clapeyrons likning beskriver hvordan en faseovergang påvirkes av trykk:
#
# $$\frac{dp}{dT}=\frac{∆_{trs}S_{m}}{∆_{trs}V_{m}}$$
#
# ```{admonition} Utledning
# :class: important
#
# Ved en faseovergang må de to fasene være i likevekt med hverandre, dvs. at deres kjemiske potensiale må være likt. Siden vi ser på avhengigheten av trykk og temperatur kan dette skrives som:
#
# $${\mu }_{A}(p,T)={\mu }_{B}(p,T)$$
#
# Det kjemiske potensiale svarer til den molare Gibbs fri energi: $\mu =G_{m}$
#
# Den partiell-deriverte formen av Gibbs fri energi er:
#
# $$dG_{m}=V_{m}dp-S_{m}dT$$
#
# Setter vi at $dG_{m,A\ }=dG_{m,B}$ for de to fasene får vi videre:
#
# $$V_{m,A}dp-S_{m,A}dT=V_{m,B}dp-S_{m,B}dT$$
#
# $${(V}_{m,A\ }-V_{m,B\ })\frac{dp}{dT}=(S_{m,A\ }-S_{m,B\ })$$
#
# Som igjen gir oss Clapeyron likningen!
#
# $$\ \frac{dp}{dT}=\frac{S_{m,A\ }-S_{m,B\ }}{\ V_{m,A\ }-V_{m,B\ }\ }$$
#
# ```
#
# Ved å bruke at $∆G = 0$ ved faseovergang kan denne gjøres om til:
#
# $$\frac{dp}{dT}=\frac{∆_{trs}H_{m}}{∆_{trs}V_{m}\cdot T_{trs}}$$
#
# Integrasjon gir videre:
#
# $$p=p^{\ast }+\frac{∆_{trs}H_{m}}{∆_{trs}V_{m}}ln\left(\frac{T}{T^{\ast }}\right)\approx p^{\ast }+\frac{∆_{trs}H_{m}}{∆_{trs}V_{m}}\left(\frac{T-T^{\ast }}{T^{\ast }}\right)$$
#
# Vi finner forskjellen i molart volum ved å bruke at:
#
# $$\mathrm{\rho }=\frac{m}{V}=\frac{n\cdot M}{V}=\frac{M}{V_{m}}$$
#
# Som gir:
#
# $$V_{m}=\frac{M}{\mathrm{\rho }}$$
#
# Slik at:
#
# $∆V_{m}=M\left(\frac{1}{p_{s}}-\frac{1}{{\rho }_{l}}\right)=46.1\ g.mol^{-1}\cdot \left(\frac{1}{0.789 \, g.cm^{-3}}-\frac{1}{0.801 \, g.cm^{-3}}\right)=-0.8753 \, cm^{3}.mol^{-1}$
#
# Siden det ikke er gitt noe annen informasjon antar vi at frysepunktet ved $-3.65 ^{\circ}C$ er gitt ved standard trykk = $1 \, atm$. Ved innsetting av verdiene i Clapeyrons likning fås da:
#
# $1\ MPa=1 \, atm+\frac{8680 \, J.mol^{-1}}{-0.8753 \, cm^{3}.mol^{-1}}\cdot \left(\frac{T-269.5 \, K}{269.5 \, K}\right)$
#
# $1\ MPa=0.101325 \, MPa+\frac{8680 \, J.mol^{-1}}{-0.8753 \, cm^{3}.mol^{-1}}\cdot \left(\frac{T-269.5 \, K}{269.5 \, K}\right)$
#
# $0.898675\cdot {10}^{6} \, Pa\cdot \frac{-0.8753\cdot {10}^{-6} \, m^{3}.mol^{-1}}{8680 \, J.mol^{-1}}\cdot \ 269.5\ K\ +\ 269.5\ K\ =\ T$
#
# $T = 269.48 \, K$
#
# Her ble det brukt at $Pa\cdot \ m^{3}\ =\ J$.  Selv om trykket altså øker med omtrent $1*10^6 \, mPa$, minker smeltepunktet minimalt.
#
# Til sammenlikning vet vi at forskjellen i atmosfærisk trykk mellom havnivå og toppen av Mt. Everest er ca $67 \, kPa$ ($0.067 \, MPa$), og at kokepunktet for vann da minker fra $100$ til $68 \, ^{circ}C$. Men det er her viktig å huske at for kokepunktet til vann så vil det molare volumet øke betydelig mer i væske-gass overgangen enn det gjør i dette tilfellet!
#
# **Oppgave 9**
#
# $$H_{2}O\left(l,\ 100\ °C,\ 1\ atm\right)\rightarrow \ \ H_{2}O(g,\ 100\mathrm{℃},\ 1\ atm)$$
#
# Ved atmosfæretrykk:
#
# $$1\ atm\ =\ 1,01325\cdot {10}^{5}\ Pa\ (100\mathrm{℃})$$
#
# Arbeidet som systemet gjør mot et konstant ytre trykk ($1 \, atm$) når gassen dannes er:
#
# $w=\ -p_{ex}\cdot \Delta V=\ -p_{ex}\cdot n\cdot \Delta V_{m}$
#
# Den molare endringen i volum finner vi ved hjelp av tetthetene:
#
# $$\Delta V_{m}=V_{m,vanndamp}-V_{m,vann}=\frac{M_{H_{2}O}}{{\rho }_{vanndamp}}-\frac{M_{H_{2}O}}{{\rho }_{vann}}=\frac{18.01\ gmol^{-1}}{0.000596\ g.cm^{-3}}-\frac{18.01\ g.mol^{-1}}{0.9584\ g.cm^{-3}}=3.0199\cdot {10}^{4} \, cm^{3}.mol^{-1}$$
#
#
# $$w=\ -\left(1.01325\cdot {10}^{5} \, Pa\right)\cdot \left(2.00\ mol\right)\cdot \left(3.0199\cdot {10}^{4}\cdot {10}^{-6} \, m^{3}.mol^{-1}\right)=\ -6.12\cdot {10}^{3}J$$
#
# Ettersom vi har oppgitt den molare fordampningsentalpien kan vi bruke definisjonen på entalpi for å finne endringen i indre energi:
#
# $$\Delta H=\Delta U+p\Delta V\Rightarrow {\Delta }_{vap}U={\Delta }_{vap}H-p_{ex}\Delta V={\Delta }_{vap}H+w=n\cdot {\Delta }_{vap}H_{m}+w\ $$
#
# $${\Delta }_{vap}U=\left(2.00\ mol\cdot 40.63\cdot {10}^{3}J\ mol^{-1}\right)-6.12\cdot {10}^{3}J=75.1\cdot {10}^{3}J$$
#
# Ettersom vi er ved en faseovergang må systemet være i en likevekt, og ${\Delta }_{\mathrm{vap}}G=0$.
#
# Entropien finner vi ut fra definisjonen på entropi ved varmeoverføring:
#
# $${\Delta }_{vap}S=\frac{q_{rev}}{T}=\frac{{\Delta }_{vap}H}{T_{kokepunkt}}=\frac{n\cdot {\Delta }_{vap}H_{m}}{T_{kokepunkt}}$$
#
# $${\Delta }_{vap}S=\frac{2.00\ mol\cdot 40.63\cdot {10}^{3}J\ mol^{-1}}{373.15K}=218\ JK^{-1}$$
#
# Oppsummert:
#
# $$w=\ -6.12\cdot {10}^{3}J$$
#
# $${\Delta }_{vap}U=75.1\cdot {10}^{3}J$$
#
# $${\Delta }_{\mathrm{vap}}G=0$$
#
# $${\Delta }_{vap}S=218\ JK^{-1}$$
#
# **Oppgave 10**
#
# Spesifikk fordampningsentalpi er entalpiendring per masse, og fordampningsvarmen for etylenglykol er altså $801 J.g^{-1}$, som oppgitt i oppgaveteksten. Videre har vi $M_{C_{2}H_{6}O_{2}}=62,058\ g.mol^{-1}$. For den molare fordampningsentalpien får vi:
#
# $${\Delta }_{vap}H_{m}=M\cdot {\Delta }_{vap}H_{sp}=62.058\ g\ mol^{-1}\cdot 801\ J\ g^{-1}=\ 49.71\cdot {10}^{3}J\ mol^{-1}\ $$
#
# For å finne kokepunktet ved et gitt trykk kan vi bruke Clausius-Clapeyron’s likning. Her følger en kort utledning av denne likningen, før oppgaven fortsetter under.
#
# ```{admonition} Utledning
# :class: important
#
# Som for væske/fast-stoff overgangen vi så på i oppgave 1, gjelder også Clapeyron-likningen for væske-gass overgangen, men da med fordampningsentalpi og volumendring:
#
# $$\frac{dp}{dT}=\frac{{\Delta }_{vap}H}{T{\Delta }_{vap}V}$$
#
# MEN; fordi volumendringen mellom væske og gass er mye større enn for fast-stoff til væske, kan vi her gjøre en tilnærming som vil lede oss til Clausius-Clapeyron’s likning:
#
# $$V_{m}\left(g\right)\gg V_{m}\left(l\right)\ \Rightarrow {\Delta }_{vap}V_{m}\ \approx V_{m}(g)$$
#
# Hvis vi også antar ideell gass:
#
# $$V_{m}\left(g\right)=\frac{RT}{p}$$
#
# Som gir oss:
#
# $$\frac{dp}{dT}=\frac{{\Delta }_{vap}H_{m}}{T\left(\frac{RT}{p}\right)}=\ \frac{{\mathrm{p\Delta }}_{vap}H_{m}}{RT^{2}}$$
#
# Deler begge sider på p og får:
#
# $$\frac{1}{p}\frac{dp}{dT}=\frac{d(\ln{p})}{dT}=\ \frac{{\Delta }_{vap}H_{m}}{RT^{2}}$$
# ```
#
# Clausius-Clapeyron’s likning:
#
# $$\frac{d\left(\ln{p}\right)}{dT\ }=\frac{{\Delta }_{vap}H_{m}}{R}\cdot \frac{1}{T^{2}}$$
#
# Integrert form av Clausius-Clapeyron´s ligning gir:
#
# $$\ln{\ \left(\frac{p_{2}}{p_{1}}\right)}=\frac{{\Delta }_{vap}H_{m}}{R\ }\left(\frac{1}{T_{1}}-\frac{1}{T_{2}}\right)\ $$
#
# Setter inn og får:
#
# $$\ln{\left(\frac{760\ Torr}{50.0\ Torr}\right)=\frac{49.71\cdot {10}^{3}\ J\ mol^{-1}}{8.3145\ J\ K^{-1}mol^{-1}}\cdot \left(\frac{1}{T_{1}}-\frac{1}{470.15\ K}\right)}$$
#
# $$4.5\cdot {10}^{-4}\ K^{-1}=\ \frac{1}{T_{1}}-\frac{1}{470.15\ K}$$
#
# $$0.002582\ K^{-1}=\frac{1}{T_{1}}\ \implies T_{1}=387.6\ K$$
#
# **Oppgave 11**
#
# For å finne temperaturen der faseovergangen skjer er det hensiktsmessig plotte varmekapasitet som funksjon av temperatur. Varmekapasitet er definert som $C_{V}={\left(\frac{\partial U}{\partial T}\right)}_{V}$ og vi kan derivere dataen numerisk for å approksimere varmekapasiteten i dette systemet.
#
# Dette kan f.eks. implementeres i Python på følgende måte:

# %%
import numpy as np
import matplotlib.pyplot as plt

T = [35, 40, 45, 50, 51, 51.5, 51.6, 55, 60]
U = [401, 435, 499, 582, 776, 887, 2012, 2020, 2031]
C = []

for i in range(len(T)-1):
    dT = T[i+1] - T[i]
    dU = U[i+1] - U[i]
    C.append(dU/dT)

plt.plot(T[0:-1], C)
plt.xlabel('Temperature (°C)')
plt.ylabel("Varmekapasitet")
plt.title('Varmekapasitet vs. Temperatur')
plt.show()

# %% [markdown]
# Varmekapasiteten har en tydelig topp rundt $51 ^{\circ}C$ og formen på toppen tyder på at det er en første ordens faseovergang som skjer her. Siden datamaskinen bruker diskrete tall vil vi ikke kunne observere at varmekapasiteten divergerer mot uendelig men toppen gir allikevel en god indikasjon på at faseovergangen skjer.

# %% [markdown]
# # Uke 8 - Løsninger og blandinger

# %% [markdown]
# ### Diskusjonsoppgaver
#
# #### Oppgave 1
#
# **a)**  I gittermodellen tenker vi oss et fast, regelmessig gitter der hver plass er okkupert av enten en A- eller B-partikkel. Ved å telle antall måter partiklene kan plasseres på (mikrotilstander, $\Omega$), kan vi bruke statistisk mekanikk ($S = k_B \ln \Omega$) til å finne blandingsentropien. Ved å telle nærmeste-nabo-kontakter mellom partikler og tilordne en kontaktenergi til hver type kontakt (AA, BB, AB), kan vi finne blandingsenergien. Disse to bidragene settes sammen til fri energi $F = U − TS$, og derfra kan vi utlede kjemisk potensial, aktivitet, fasediagram osv.
#
# **b)** For å utlede et bestemt uttrykk, må vi først definere systemet vårt og hvilken prosess vi er interesserte i. Så må vi såklart basere utledningen på modellen vår, gittermodellen, der vi kjenner antallet stoffer, antallet plasser $N$ og har en størrelse for mengden av hver av stoffene $N_X$. Vi starter med uttrykket for løsningsentropien gitt ved Boltzmann entropi og multiplisiteten $\Omega$, gitt ved binomialkoeffisienten. Videre bruker vi diverse tilnærminger og metoder: Stirlings approksimasjon, logaritmeregler. Mye av prosessen handler om insetting og omskrivinger for å få et uttrykk som er lett leselig og enkelt å tolke fysisk: entropien øker fordi det finnes mange flere måter å blande A og B tilfeldig på enn å holde dem separert (kun én måte). Til slutt bytter vi ut antallet molekyler med relative konsentrasjoner i form av molfraksjoner.
#
# **c)** I den enkleste versjonen av gittermodellen (ren blandingsentropi, ingen interaksjonsenergi mellom A og B, eller $w_{AA} = w_{BB} = w_{AB}$) er det ingen netto energiendring ved blanding ($\Delta U_{mix} = 0$). Da blir den frie energien $F = \Delta U_{mix} − T\Delta S_{sol} = −T\Delta S_{sol}$. Energibidraget forsvinner altså fordi vi antar at interaksjonene mellom like og ulike partikler er identiske, blandingen drives da utelukkende av entropi (statistisk sannsynlighet), ikke av energigevinst.
#
# **d)** Termene betyr:
#  - $(zw_{AA}/2)N_A$: bidrag fra AA-kontakter. $z$ er koordinasjonstallet (antall naboer per plass), $w_AA$ er kontaktenergien for en AA-nabopar. Faktoren $1/2$ unngår dobbeltelling av par.
#  - $(zw_{BB}/2)N_B$: tilsvarende bidrag fra BB-kontakter.
#  - $m_{AB}(w_{AB} − (w_{AA}+w_{BB})/2)$: $m_{AB}$ er antall AB-kontakter (blandingskontakter). Leddet i parentes er "overskuddsenergien" ved å danne en AB-kontakt sammenlignet med gjennomsnittet av å ha en ren AA- og en ren BB-kontakt. Dette leddet er selve drivkraften (eller hindringen) for blanding på energisiden: er det negativt foretrekker systemet AB-kontakter (blanding er gunstig energetisk), er det positivt foretrekker systemet å holde like partikler sammen (fasesepareringstendens).
#
# **e)** Antagelsen er at partiklene er tilfeldig fordelt på gitteret, slik at sannsynligheten for at en gitt nabo er A eller B kun avhenger av den gjennomsnittlige konsentrasjonen, uavhengig av hvor på gitteret man befinner seg. Dette lar oss erstatte det eksakte (og vanskelige) antall AB-kontakter $m_{AB}$ med et gjennomsnittsuttrykk basert på $x$. Tilnærmingen fungerer dårlig når det er sterk lokal orden/klumping, f.eks. nær fasesepareringspunktet, ved lave temperaturer der interaksjonene dominerer over tilfeldig termisk bevegelse, eller ved svært asymmetriske/sterke interaksjoner der partiklene ikke lenger er tilfeldig fordelt lokalt.
#
# **f)** $\chi_{AB} = (z/k_BT)(w_{AB} − (w_{AA}+w_{BB})/2)$
#
# Den fysiske tolkningen: $\chi$ måler styrken av den energetiske "ubalansen" mellom AB-kontakter og de rene AA/BB-kontaktene, relativt til termisk energi ($k_BT$). Stor positiv $\chi$ betyr at AB-kontakter er energetisk ugunstige sammenlignet med å holde like partikler sammen, jo større $\chi$, jo sterkere driver systemet mot fasesepareing. $\chi$ nær $0$ betyr tilnærmet ideell blanding.
#
# **g)** Modellen antar:
#
# - alle partikler/molekyler har lik størrelse og fyller gitterplassene perfekt (urealistisk for f.eks. polymerer eller store/små molekylkombinasjoner)
# - kun nærmeste-nabo-interaksjoner telles
# - tilfeldig (mean-field) fordeling selv når lokal orden faktisk oppstår
# - ingen volumendring ved blanding
# - interaksjonsenergiene $w_{ij}$ antas konstante og uavhengige av konsentrasjon og temperatur. Reelle løsninger har ofte volumendringer ved blanding, temperaturavhengige interaksjoner, og molekyler av ulik størrelse/form, modellen er derfor kun kvalitativt/semikvantitativt riktig for mange systemer.
#
#
# #### Oppgave 2
#
# **a)** En ideell gass er en gass uten interaksjoner mellom molekylene, der vi regner hvert molekyl som et lite punkt uten utstrekning. $\Delta_{mix} H$ ville vært $0$ for en blanding av to ideelle gasser siden det ikke er noen intermolekylære interaksjoner mellom molekylene.
#
# **b)** Siden væsker har interaksjoner mellom seg, kan man ikke si at intermolekylære interaksjoner er lik $0$. Det man gjør isteden er å sette de til en gjennomsnittlig styrke. Det som menes med det er at interaksjonene mellom stoffene A og B er lik interaksjonene mellom A og A, og B og B. $\Delta_{mix} H$ er fortsatt $0$ når man blander to ideelle væsker. Det betyr at det ikke er noen forskjell i intermolekylære bindinger mellom molekylene i væsken. En homogen, helt ren væske vil derfor alltid være ideell, fordi alle interaksjonene mellom molekylene er de samme.
#
# **c)** Drivkraften er entropisk: det er statistisk mye mer sannsynlig (flere mikrotilstander) at molekylene er tilfeldig blandet enn separert, noe som gir $\Delta S_{mix} > 0$ og dermed $\Delta G_{mix} = \Delta H_{mix} − T\Delta S_{mix} < 0 \rightarrow$ spontan blanding. Materie og energien blir mer spredt om væskene er mikset enn hver for seg.
#
# **d)** Både Raoults og Henrys lov beskriver sammenhengen mellom damptrykk over en blanding og dens sammensetning. For en blanding av to ideelle væsker er denne sammenhengen lineær og dette beskrives av Raoults lov. I en blanding med høy konsentrasjon av én av væskene vil de fleste molekylene rundt et gitt molekyl være like som molekylet. Derfor vil blandingen oppføre seg nesten ideell og i det tilfelle kan den godt beskrives ved hjelp av Raoults lov. For ikke-ideelle blandinger vil sammenhengen mellom damptrykk og blandingsforhold være lineær kun ved lave konsentrasjoner. En slik situasjon beskrives av Henrys lov.
#
# **e)** En væske sies ideell om den følger Raoults lov, dvs når komponentene er så kjemisk/strukturelt like at A–A, B–B og A–B-interaksjoner er tilnærmet identiske. De to væskene bør være mest mulig like for at de mest sannsynlig oppfører seg ideelt. Eksempler er benzen og toluen, n-heptan og n-heksan, etyl-bromide og etyl-jodid, klorbenzen og brombenzen.
#
# **f)** Det er fordi nettverket av hydrogenbindinger mellom vannmolekylene ikke kan opprettholdes sammen med etanol, og $\text{H}_2\text{O}$ molekylene bruker derfor mindre plass (de kommer nærmere hverandre, svakere krefter mellom dem) blandet med store mengder etanol.
#
# **g)** Nei, en blanding av etanol og vann er ikke en ideell væske. Interaksjonene mellom vann og vann, vann og etanol, og etanol og etanol er forskjellige.  Antall hydrogenbindinger som kan dannes imellom speciene varierer.
#
# **h)** Partielt molart volum er volumet som ett mol av en komponent i en blanding bidrar til det totale volumet. Partielt molart volum kan variere med sammensetning av blandingen. For en ideell væske vil det partielle molare volumet være lik som for de rene stoffene. I eksempelet med vann og etanol ville det vært $18 \text{cm}^3$.
#
# **i** Her er det flere ting man kan komme innom, for eksempel:
#
#  - Enkelt å måle
#  - Gir utrykk for de molekylære egenskapene til systemet. Store forskjeller mellom molekyler, gir en god innsikt i hva som skjer, og hvordan forskjellige faktorer påvirker.
#  - Endres ved kolligative egenskaper
#  - Gir uttrykk for kinetisk energi og entropiske bidrag
#
#
# #### Oppgave 3
#
# **a)** Den sier at kjemisk potensial er hvor mye Gibbs fri energi øker/avtar med endret mengde av komponent J. Så for ett stoff er kjemisk potensial det samme som molar Gibbs fri energi, men for flere komponenter er kjemisk potensial gitt ved stigningstallet til Gibbs fri energi når den ene komponenten endres.
#
# **b)** Den fundamentale likningen for kjemisk termodynamikk:
#
# $ \Delta G = VdP - SdT + \mu_Adn_A + \mu_Bdn_B. $
#
#  Ved konstant trykk og temperatur reduseres denne til:
#
#  $ dG = \mu_Adn_A + \mu_Bdn_B.$
#
#  Det betyr at endring i Gibbs fri energi kan komme fra endring i sammensetning i systemet, for eksempel endring i sammensetning når reaktanter blir produkter.
#
# **c)** Gibbs-Duhem likningen forteller at det kjemiske potensialet av en komponent i systemet ikke kan endres uavhengig av de andre komponentene.
#
# **d)** Gibbs energien før blanding (rene gasser A og B hver for seg ved totaltrykk $p$) sammenlignes med Gibbs energien etter blanding (samme gasser blandet, hver med partialtrykk $x_Ap$ og $x_Bp$). Bruker man $\mu = \mu° + RT \ln(p/p°)$ for hver komponent før og etter, og summerer
#
# $G = \sum n_J \mu_J$,
#
# finner man at differansen blir
#
# $\Delta_{mix}G = nRT(x_A \ln x_A + x_B \ln x_B)$
#
# fordi
#
# $\ln(x_Jp) − \ln(p) = \ln x_J$
#
# for hver komponent, og de øvrige leddene kansellerer.
#
# **e)** Samme uttrykk som for ideelle gasser: $\Delta_{mix}S = −nR(x_A \ln x_A + x_B \ln x_B)$, siden entropien for ideell blanding kun avhenger av antall måter å fordele molekylene tilfeldig på, uavhengig av om det er gass eller væske.
#
#
# #### Oppgave 4
#
# **a)** Disse egenskapene endres fordi tilstedeværelsen av oppløst stoff senker det kjemiske potensialet til løsningsmiddelet, uavhengig av hva slags stoff det er, kun avhengig av antall partikler oppløst. Dette skjer fordi det oppløste stoffet "fortynner" løsningsmiddelet og øker løsningens entropi i flytende fase, noe som forskyver likevekten mellom faser.
#
# **b)**
#
#  - Damptrykk: senkes når mengde løst stoff øker, løsningsmiddelets kjemiske potensial/aktivitet reduseres.
#  - Kokepunkt: heves. Siden damptrykket er lavere ved en gitt temperatur, må temperaturen økes mer for å nå damptrykk lik atmosfæretrykket.
#  - Frysepunkt: senkes. Det oppløste stoffet stabiliserer flytende fase relativt til fast fase, slik at lavere temperatur kreves for å nå likevekt mellom fast og flytende fase.
#
#
# #### Oppgave 5
#
# **a)** Aktiviteten er definert som $a_A = p_A/p_A^*$, altså det faktiske damptrykket delt på damptrykket til den rene væsken. Det kjemiske potensialet uttrykkes da som $\mu_A = \mu_A^* + RT \ln a_A$. For en ideell løsning er $a_A = x_A$, siden Raoults lov da gjelder eksakt.
#
# **b)** Aktiviteten nærmer seg molfraksjonen når konsentrasjonen av løsningsmiddelet er høy ($x_A \rightarrow 1$), altså i det fortynnede løsningsstoff-grensen der løsningsmiddelet oppfører seg tilnærmet ideelt, dette er Raoults-lov-grensen.
#
# **c)** $γ_A$ i $a_A = γ_A x_A$ representerer avviket fra ideell oppførsel:
#
# $γ = 1$ betyr ideell oppførsel.
#
# $γ > 1$ betyr positivt avvik: molekylene "flykter" lettere til damp enn ideelt forventet, ofte pga. svakere A–B enn A–A/B–B-interaksjoner.
#
# $γ < 1$ betyr negativt avvik: sterkere A–B-interaksjoner, f.eks. hydrogenbindinger, holder molekylene sterkere i løsning.
#
# **d)** Molaritet/molalitet beskriver kun den nominelle konsentrasjonen, men i ikke-ideelle løsninger er det den "effektive" konsentrasjonen som styrer termodynamikken, ikke den nominelle, pga. interaksjoner mellom partiklene. Aktivitet korrigerer for dette avviket, slik at de termodynamiske likningene forblir eksakte selv i ikke-ideelle systemer.
#
# **e)** Man kan ikke måle aktivitetskoeffisienten til en ionetype alene fordi man ikke kan ha en løsning med bare kationer eller bare anioner, elektronøytralitet krever begge. Derfor definerer man en gjennomsnittlig aktivitetskoeffisient $γ±$ som kombinerer bidragene fra begge ionetypene, og som er den eksperimentelt målbare/meningsfulle størrelsen.
#
#
# #### Oppgave 6
#
# **a)** Fraksjonert destillering: En separasjonsteknikk der en væskeblanding gjentatte ganger fordampes og kondenseres via en kolonne med mange "trinn" for å utnytte at damp over en blanding er beriket på den mer flyktige komponenten, slik at komponentene gradvis separeres etter kokepunkt.
#
# **b)** Azeotrop: Et sammensetningspunkt der væske- og dampfase har nøyaktig samme sammensetning, slik at videre destillering ikke kan separere komponentene ytterligere ved det punktet.
#
# **c)** Critical solution temperature: Temperaturen der to delvis blandbare væsker akkurat blir fullstendig blandbare i alle proporsjoner. Over denne temperaturen forsvinner miscibility-gapet/fasesepareringen.
#
# **d)** Faseseparering: Skjer når den frie blandingsenergien har to eller flere minima som funksjon av sammensetning i stedet for ett: systemet senker sin totale frie energi ved å dele seg i to faser med ulik sammensetning, hver ved sitt lokale minimum, i stedet for å forbli som én homogen blanding.
#
# **e)** Osmotisk trykk oppstår fordi løsningsmiddelets kjemiske potensial er lavere på siden med oppløst stoff (pga. fortynningseffekten/entropien) enn på den rene løsningsmiddelsiden. For å gjenopprette likevekt gjennom en semipermeabel membran, må trykket økes på løsningssiden for å heve det kjemiske potensialet der tilbake til likevekt med den rene siden.

# %% [markdown]
# ### Regneoppgaver
#
# #### Oppgave 7
#
# **a)**
#
# Fremgangsmåte: tell antall A-partikler (N_A) og B-partikler (N_B) i gitteret på bildet, og bruk W = N!/(N_A!·N_B!), hvor N = N_A + N_B.
#
# **b)**
#
# $\Delta S_{sol} = −Nk_B[(N_A/N)\ln(N_A/N) + (N_B/N)\ln(N_B/N)] = −Nk_B[x \ln x + (1−x)\ln(1−x)],$
#
# ved å definere $x = N_A/N$ og $(1−x) = N_B/N$.
#
# **c)**
#
# $x_A = 7/10 = 0.70$, $x_B = 3/10 = 0.30$.
#
# $\Delta S_{sol}/(Nk_B) = −[0.70\ln(0.70) + 0.30\ln(0.30)] = 0.6109$
#
# Total blandingsentropi: $\Delta S_{sol} = 0.6109Nk_B = 10\times0.6109k_B \approx 6.11 k_B \approx 8.43\times10^{-23} \text{J/K}.$
#
# **d)**
#
# Fremgangsmåte: tell antall AA-, BB- og AB-kontakter (m_AA, m_BB, m_AB) i gitteret på bildet, og sett inn i U = m_AA·w_AA + m_BB·w_BB + m_AB·w_AB med w_AA = 1, w_BB = 1, w_AB = 2.
#
#
# **e)**
#
# $\chi_{AB} = (z/k_BT)(w_{AB} − (w_{AA}+w_{BB})/2)$
#
# Når $T\rightarrow\infty$: $\chi_AB \rightarrow 0$. Termisk energi dominerer fullstendig over interaksjonsforskjellene, og entropien vinner, systemet blandes uansett interaksjonsenergi.
#
# Når $T\rightarrow 0$: $\chi_AB \rightarrow ± \infty$ avhengig av fortegn på $w_{AB} − (w_{AA}+w_{BB})/2$. Interaksjonsenergien dominerer fullstendig over entropien, og systemet vil enten fasesepareres sterkt hvis $\chi > 0$ eller danne en svært ordnet/foretrukket blanding hvis $\chi < 0$.
#
# Dette stemmer med tolkningen av χ som forholdet mellom interaksjonsenergi og termisk energi ($k_BT$), $\chi$ vokser når termisk energi blir liten relativt til energiforskjellene.
#
# **f)** Siden $\chi \approx 5$ for hydrokarbon/vann, er AB-kontakter (olje-vann) sterkt energetisk ugunstige sammenlignet med å holde like molekyler sammen, den frie energien har to separate minima, og systemet fasesepareres i stedet for å blande seg fullstendig. Ved svært lav konsentrasjon av olje er derimot entropileddet ($−x \ln x$) fortsatt stort nok til at en liten mengde olje likevel kan løses opp, dette er grunnen til at olje har en bitteliten løselighet i vann.
#
#
# #### Oppgave 8
#
# $ x(\text{N}_2) = 0.78$, $x(\text{O}_2) = 0.22$, $T = 298 \text{K}$.
#
# **a)**
#
# $\Delta_{mix}G_m = RT[x_{N_2} \ln(x_{N_2}) + x_{O_2} \ln(x_{O_2})] = 8.314\times298(−0.5269) \approx −1305 \text{J/mol} \approx −1.31 \text{kJ/mol}$.
#
# **b)**
#
# $\Delta_{mix}H_m = 0$ (ideelle gasser, ingen interaksjonsenergi endres ved blanding).
#
# **c)**
#
# $\Delta_{mix}S_m = −R[x_{N_2} \ln(x_{N_2}) + x_{O_2}\ln(x_{O_2})] \approx 4.38 \text{J/(Kmol)}$
#
# Test: $−T\Delta S = −298\times 4.38 = −1305 \text{J/mol} = \delta G$, siden $\Delta H = 0$.
#
# Blandingen er spontan. Drivkraften er utelukkende entropi, siden entalpibidraget er null.
#
#
# #### Oppgave 9
#
# $$n_{\text{tol}} = \frac{75.0 g}{92.1 g/mol} = 0.8143 \ \text{mol}, \qquad n_{\text{dfe}} = \frac{1000 g}{170.2 g/mol} = 5.875 \ \text{mol}$$
#
# $$x_{\text{tol}} = \frac{n_{\text{tol}}}{n_{\text{tol}} + n_{\text{dfe}}} = \frac{0.8143}{0.8143 + 5.875} = 0.1217, \qquad x_{\text{dfe}} = 1 - x_{\text{tol}} = 0.8783$$
#
# $$p_{\text{dfe}} = 430 \ \text{Torr} \, \qquad p_{\text{tot}} = 520 \ \text{Torr}$$
#
# $$p_{\text{tol}} = p_{\text{tot}} - p_{\text{dfe}} = 520 - 430 = 90 \ \text{Torr}$$
#
# **a)**
#
# $K_{H} = \frac{p_{\text{tol}}}{x_{\text{tol}}} = \frac{90}{0.1217} \approx 739 \ \text{Torr}$
#
# **b)**
#
# $p_{\text{tol}}(\text{Raoult}) = x_{\text{tol}} \cdot p_{\text{tol}}^{*} = 0.1217 \times 650 \approx 79.1 \ \text{Torr}$
#
# Faktisk verdi er $90 \ \text{Torr}$, altså et **positivt avvik** fra Raoults lov. Toluen følger i stedet Henrys lov med sin egen empiriske konstant.
#
# **c)**
#
# $K_{H} = p_{\text{tol}}^{*} = 650 \ \text{Torr}$.
#
#
# #### Oppgave 10
#
# $\Delta T = K_{f} \cdot m = 1.86 \times 1.0 = 1.86 \ \text{K}$
#
# Observert $\Delta T = 3.7 \ \text{K}$:
#
# $\frac{3.7}{1.86} \approx 1.99 \approx 2$
#
# Van't Hoff-faktoren $i \approx 2$, siden $\text{NaCl}$ dissosierer fullstendig i vann til $\text{Na}^{+}$ og $\text{Cl}^{-}$.
#
#
#
# #### Oppgave 11
#
# $x_{\text{CHCl}_{3}} = 0.290, \qquad x_{\text{aceton}} = 1 - x_{\text{CHCl}_{3}} = 0.710$
#
# $M_{\text{aceton}} = 58.08 \ \text{g/mol}, \qquad M_{\text{CHCl}_{3}} = 119.38 \ \text{g/mol}$
#
# $M_{\text{avg}} = 0.710 \times 58.08 + 0.290 \times 119.38 \approx 75.86 \ \text{g/mol}$
#
# $n_{\text{tot}} = \frac{1000 \ \text{g}}{75.86 \ \text{g/mol}} \approx 13.18 \ \text{mol}$
#
# $n_{\text{aceton}} = 0.710 \times 13.18 \ \text{mol} \approx 9.36 \ \text{mol}, \qquad n_{\text{CHCl}_{3}} = 0.290 \times 13.18 \ \text{mol} \approx 3.82 \ \text{mol}$
#
# $V = n_{\text{aceton}} \times V_{\text{aceton}} + n_{\text{CHCl}_{3}} \times V_{\text{CHCl}_{3}} = 9.36 \ \text{mol} \times 73.78 \ \text{cm}^{3} + 3.82 \ \text{mol} \times 80.41 \ \text{cm}^{3} \approx 998 \ \text{cm}^{3}$
#
#
#
# #### Oppgave 12
#
# $n_{\text{urea}} = \frac{6.00 \ \text{g}}{60.06 \ \text{g/mol}} \approx 0.0999 \ \text{mol}$
#
# $c = 0.0999 \ \text{mol/dm}^{3}, \qquad T = 27.0^{\circ}\text{C} = 300.15 \ \text{K}$
#
# $\Pi = cRT = 99.9  \text{mol/m}^{3} \times 8.314 \text{J/(molK)} \times 300.15 \text{K} \approx 249  \text{kPa} \approx 2.46  \text{atm}$
#
#
#
#
# #### Oppgave 13
#
# $p_{I}(\text{Raoult}) = x_{I} \times 353 \ \text{Torr}$
#
# | $x_{I}$ | Raoult-prediksjon $\text{[Torr]}$ | Faktisk $p_{I} \ \text{[Torr]}$ | Forhold |
# |:---:|:---:|:---:|:---:|
# | $1.00$ | $353$ | $353$ | $1.000$ |
# | $0.909$ | $320.9$ | $322$ | $1.003$ |
# | $0.825$ | $291.2$ | $296$ | $1.016$ |
# | $0.548$ | $193.4$ | $213$ | $1.101$ |
# | $0.235$ | $83.0$ | $105$ | $1.266$ |
# | $0.109$ | $38.5$ | $52.7$ | $1.370$ |
# | $0.0579$ | $20.4$ | $28.0$ | $1.370$ |
#
# **a)** Ved høy $x_{I}$ (nær $1.00$) følger damptrykket Raoults lov godt (avvik $< 2\%$). Ved lav $x_{I}$ er avviket betydelig (opp mot $37\%$) — løsningsmiddelet følger Raoults lov nær $x_{I} = 1$, mens den fortynnede komponenten følger Henrys lov.
#
# **b)**
#
# $K_{I} = \frac{p_{I}}{x_{I}}$
#
# Ved lave konsentrasjoner:
#
# $x_{I} = 0.0579: \quad K_{I} = \frac{28.0}{0.0579} \approx 483.6 \ \text{Torr}$
#
# $x_{I} = 0.109: \quad K_{I} = \frac{52.7}{0.109} \approx 483.5 \ \text{Torr}$
#
# $K_{I} \approx 484 \ \text{Torr} \quad (x_{I} \to 0)$
#
#
# #### Oppgave 14
#
# Finn antall mol sukrose:
#
# $n_{\text{sukrose}} = \frac{2.50}{342.3} \approx 0.00730 \ \text{mol}$
#
# Regn om til molalitet:
#
# $m = \frac{0.00730}{0.200 \ \text{kg}} \approx 0.0365 \ \text{mol/kg}$
#
# Bruk frysepunktsnedsettelsesformelen:
#
# $\Delta T_{f} = K_{f} \cdot m = 1.86 \times 0.0365 \approx 0.068 \ \text{K}$
#
# Trekk fra normalt frysepunkt ($0°\text{C}$) for å finne nytt frysepunkt:
#
# $T_{f} \approx -0.068\,°\text{C}$
#
# **Kommentar:** Endringen er svært liten fordi konsentrasjonen av sukrose er lav, og sukrose ikke dissosierer i vann.

# %% [markdown]
# #### Oppgave 15
#
# Finn total ionekonsentrasjon (Na⁺ og Cl⁻ til sammen):
#
# $c_{\text{ioner}} = 0.50 + 0.50 = 1.00 \ \text{mol/dm}^{3}$
#
# Finn mengde vann per liter løsning:
#
# $n_{\text{H}_{2}\text{O}} = \frac{1000}{18.02} \approx 55.49 \ \text{mol/dm}^{3}$
#
# Regn ut molfraksjonen av vann (resten er ioner):
#
# $x_{\text{H}_{2}\text{O}} = \frac{n_{\text{H}_{2}\text{O}}}{n_{\text{H}_{2}\text{O}} + c_{\text{ioner}}} = \frac{55.49}{55.49 + 1.00} \approx 0.9823$
#
# Bruk Raoults lov for å finne damptrykket over sjøvann:
#
# $p_{\text{H}_{2}\text{O}} = x_{\text{H}_{2}\text{O}} \cdot p_{\text{H}_{2}\text{O}}^{*} = 0.9823 \times 2.338 \approx 2.297 \ \text{kPa}$
#
# Nedsettelsen blir da:
#
# $\Delta p = 2.338 - 2.297 \approx 0.041 \ \text{kPa}$
#
# **Kommentar:** Nedsettelsen er liten fordi ionene utgjør en liten andel sammenlignet med den store mengden vann.
#
#
# #### Oppgave 16
#
# Debye-Hückels grenselov gir aktivitetskoeffisienten ut fra ionestyrken $I$:
#
# $\log \gamma_{\pm} = -A|z_{+}z_{-}|\sqrt{I}, \qquad I = \frac{1}{2}\sum_{i} c_{i}z_{i}^{2}$
#
# **$\text{KCl}$ ($m = 5.0 \ \text{mmol/kg}$):** Begge ioner har $z = \pm 1$, så ionestyrken blir lik molaliteten:
#
# $I = \frac{1}{2}(m \cdot 1^2 + m \cdot 1^2) = m = 5.0 \times 10^{-3} \ \text{mol/kg}$
#
# Sett inn i grenseloven:
#
# $\log \gamma_{\pm} = -0.509 \times 1 \times \sqrt{0.005} = -0.0360 \implies \gamma_{\pm} \approx 0.920$
#
# **$\text{CaCl}_{2}$ ($m = 1.0 \ \text{mmol/kg}$):** Her er $\text{Ca}^{2+}$ ($z=2$) og to $\text{Cl}^{-}$ ($z=1$) per formelenhet, som gir høyere ionestyrke:
#
# $I = \frac{1}{2}(m \cdot 2^{2} + 2m \cdot 1^{2}) = 3m = 3.0 \times 10^{-3} \ \text{mol/kg}$
#
# Sett inn i grenseloven:
#
# $\log \gamma_{\pm} = -0.509 \times 2 \times \sqrt{0.003} = -0.0558 \implies \gamma_{\pm} \approx 0.880$
#
#
#
# #### Oppgave 17
#
# Molfraksjonene er gitt: $x_{T} = 0.330$, som gir $x_{B} = 0.670$.
#
# Finn aktivitetene ved å dele faktisk partialtrykk på rent damptrykk:
#
# $a_{B} = \frac{p_{B}}{p_{B}^{*}} = \frac{6.677}{9.657} \approx 0.691, \qquad a_{T} = \frac{p_{T}}{p_{T}^{*}} = \frac{1.214}{3.572} \approx 0.340$
#
# Finn aktivitetskoeffisientene ved å dele aktiviteten på molfraksjonen:
#
# $\gamma_{B} = \frac{a_{B}}{x_{B}} \approx \frac{0.691}{0.670} \approx 1.032, \qquad \gamma_{T} = \frac{a_{T}}{x_{T}} \approx \frac{0.340}{0.330} \approx 1.030$
#
# **Kommentar:** Begge $\gamma$-verdier er nær $1$ med et lite positivt avvik — benzen/toluen er tilnærmet en ideell blanding.
#
#
# #### Oppgave 18
#
# Molfraksjonen av vann finnes ved å trekke molfraksjonen til det løste stoffet fra 1:
#
# $x_{\text{H}_{2}\text{O}} = 1 - x_{\text{løst}} = 1 - 0.010 = 0.990$
#
# Finn aktiviteten ved å dele faktisk damptrykk på rent damptrykk:
#
# $a_{\text{H}_{2}\text{O}} = \frac{p}{p^{*}} = \frac{2.269}{2.339} \approx 0.970$
#
# Finn aktivitetskoeffisienten ved å dele aktiviteten på molfraksjonen:
#
# $\gamma_{\text{H}_{2}\text{O}} = \frac{a_{\text{H}_{2}\text{O}}}{x_{\text{H}_{2}\text{O}}} \approx \frac{0.970}{0.990} \approx 0.980$
#
# **Kommentar:** $\gamma < 1$ indikerer et lite negativt avvik fra Raoults lov.
#
#
# #### Oppgave 19
#
# **a)** Finn molfraksjonen av oksygen løst i vann ved hjelp av Henrys lov:
#
# $p_{\text{O}_{2}} = 0.21 \ \text{atm} \implies x_{\text{O}_{2}} = \frac{p_{\text{O}_{2}}}{K_{H}} = \frac{0.21}{40\,000} = 5.25 \times 10^{-6}$
#
# Gjør om til konsentrasjon ved å gange med mengden vann per liter:
#
# $n_{\text{O}_{2}} \approx x_{\text{O}_{2}} \times 55.5 \ \text{mol/L} \approx 2.91 \times 10^{-4} \ \text{mol/L}$
#
# Gjør om til masse per liter:
#
# $m_{\text{O}_{2}} \approx 9.3 \ \text{mg/L}$
#
# **b)** Bruk van't Hoff-formen for å finne hvordan $K_H$ endrer seg med temperatur:
#
# $\ln\left(\frac{K_{H,T_{2}}}{K_{H,T_{1}}}\right) = \frac{\Delta H_{\text{sol}}}{R}\left(\frac{1}{T_{2}} - \frac{1}{T_{1}}\right)$
#
# Sett inn $T_{1} = 298.15 \ \text{K}$, $T_{2} = 299.05 \ \text{K}$ og $\Delta H_{\text{sol}} = -14.1 \ \text{kJ/mol}$:
#
# $\ln\left(\frac{K_{2}}{K_{1}}\right) \approx 0.0171 \implies \frac{K_{2}}{K_{1}} \approx 1.017 \implies K_{H}(T_{2}) \approx 40\,700 \ \text{atm}$
#
# **c)**
#
# Siden $\Delta H_{\text{sol}} < 0$, er oppløsningsprosessen **eksoterm**.
#
# **d)**
#
# Løseligheten (molfraksjonen) er omvendt proporsjonal med $K_H$, så vi finner endringen ved å snu forholdet fra b):
#
# $\frac{x_{2}}{x_{1}} = \frac{K_{1}}{K_{2}} \approx \frac{1}{1.017} \approx 0.983$
#
# Dette gir en reduksjon på $\approx 1.7\%$ i løst $\text{O}_{2}$ ved $0.9\,°\text{C}$ oppvarming.
#
# **e)**
#
# Gjentar samme beregning for $\Delta T = 2\,°\text{C}$, som gir en reduksjon på $\approx 3.7\%$. Redusert løselighet av $\text{O}_{2}$ i varmere hav øker risikoen for hypoksiske soner og legger et ekstra stressbidrag til marine økosystemer.

# %% [markdown]
# ## Uke 9 - Likevekter
#
# ### Diskusjonsoppgave
#
# #### Oppgave 1
#
# **a)**  Det finnes tre grunnleggende typer likevekt:
# * Termisk likevekt drives av temperaturforskjeller. Så lenge to systemer har ulik temperatur, strømmer det varme mellom dem, helt til temperaturen er lik.
# * Mekanisk likevekt drives av trykkforskjeller. Har to deler ulikt trykk, vil en bevegelig grense (f.eks. et stempel eller en membran) lfytter seg til trykket er utlignet.
# * Kjemisk (eller materiell) likevekt drives av forskjeller i kjemisk potensial mu. Stoffer strømmer, enten ved forflytning eller ved kjemisk reaksjon, fra høyt til lavt kjemisk potensial, til mi er likt.
# * Drivkreftene er altså temperatur (T), trykk (P) og kjemisk potensial (mi).
#
# **b)**
# Temperatur er et mål på partiklenes gjennomsnittlige kinetiske energi. Varmestrøm er rett og slett overføring av bevegelsesenergi gjennom kollisjoner: raske «varme» partikler gir energi til langsommere «kalde» til fordelingen jevner seg ut.
#
# Trykk oppstår mikroskopisk fra partiklenes støt mot en vegg, som er summer av bevegelsesmengde som overføres per areal per tid. En trykkforskjell betyr at det er flere/kraftigere støt på én side, så grensen dyttes.
#
# Kjemisk potensial beskriver hvor mye systemets (Gibbs-)energi endrer seg når man tilfører én partikkel. Det har både en energidel (bindinger og vekselvirkninger) og en entropidel (hvor mange måter partiklene kan fordeles på, altså konsentrasjon/blanding). Partikler har en tendens til å spre seg ut og til å søke lavere energi, begge deler er «bakt inn» i mu. Man kan tenke på mu som en rømningstendens.
#
# **c)**
# Da minimeres Gibbs fri energi. Kravet for likevekt er at G er på et minimum, altså dG = 0.
#
# **d)**
# Da minimeres Helmholtz fri energi F. Kravet er da dF = 0.
#
# **e)**
# Her maksimeres entropien S. Kravet er at S er på et maksimum, altsp dS = 0.
#
# Dette står i likt linje med c) og d) ettersom alle tre beskriver samme lov: termodynamikkens 2.lov, som sier at den totale entropien (system + omgivelsen) skal være maksimal ved likevekt. Forskjellen er bare hva vi holder fast og hva systemet får utveksle med omgivelsene. For det isolerte systemet ser vi direkte på systemets egen entropi, fordi det ikke er noen omgivelser å utveksle med.
#
# Ved konstant T,V og konstant T,P «pakker» vi omgivelsenes entropiendring inn i F og G. Disse størrelsene er konstruert nettopp slik at å minimere dem er det samme som å maksimere den totale entropien under de gitte betingelsene.
#
# **f)**
# Ved kjemisk likevekt er hastigheten til for- og bakover reaksjonen like. Reaksjonene stopper altså ikke. De går like fort begge veier, slik at konsentrasjonene ikke endrer seg netto.
#
# **g)**
# Alle disse likevektene er dynamiske. På makronivå ser det ut som «ingenting skjer», men på mikronivå pågår prosessene hele tiden: partikler kolliderer og utveksler energi, treffer veggen fra begge sider, og molekyler dannes og brytes ned. Det er bare netto-effekten som er null.
#
# Fra f): reaksjonene fortsetter hele tiden i begge retninger med lik hastighet. Molekyler dannes og brytes ned kontinuerlig; det er bare nettoendringen som er null.
#
# Fra b): partiklene beveger seg, kolliderer og utveksler energi hele tiden. Ved termisk likevekt overføres det fortsatt energi i hvert støt, det balanserer bare i gjennomsnitt. Enkeltpartiklene skifter stadig tilstand; det er kun de makroskopiske gjennomsnittene (T, P, konsentrasjoner) som holder seg konstante.
#
# Dette skiller seg fra en «ekte» statisk likevekt i mekanikken, som en pendel i hvile i sitt lavest punkt – der det virkelig ikke er noen bevegelse i det hele tatt. Termodynamisk likevekt er altså en balanse mellom prosesser som stadig pågår, ikke fravær av prosesser.
#
# ![likevekt](bilder/likevekt.png)
#
#
# #### Oppgave 2

# %% [markdown]
# **a)** Reaksjons-Gibbsenergi og likevektskonstanten $K$
#
# Sammenhengen mellom standard reaksjons-Gibbsenergi og likevektskonstanten:
#
# $$\Delta_r G^\circ = -RT \ln K \qquad\Longleftrightarrow\qquad K = e^{-\Delta_r G^\circ / RT}$$
#
# $K$ er ett fast tall ved en gitt temperatur, og forteller hvor likevekten ligger.
#
# | Tilfelle | $\Delta_r G^\circ$ | $K$ | Ved likevekt |
# |---|:---:|:---:|---|
# | Forover favorisert | $< 0$ | $> 1$ | $[B] > [A]$ (produkt dominerer) |
# | Bakover favorisert | $> 0$ | $< 1$ | $[B] < [A]$ (reaktant dominerer) |
# | Balansert | $= 0$ | $= 1$ | $[B] = [A]$ |
#
# Om reaksjonen faktisk går forover akkurat nå, bestemmes ikke av $K$ alene, men av
# $$\Delta_r G = \Delta_r G^\circ + RT\ln Q$$
# altså av om $Q$ er mindre eller større enn $K$. Tabellen over beskriver hvor likevekten til slutt havner — ikke retningen fra et vilkårlig startpunkt. (En reaksjon med $K < 1$ kan fortsatt gå forover en stund om man starter med ren $A$, siden $Q = 0 < K$.)
#
# Reaksjoner med piler (relativ hastighet forover/bakover):
#
# | Tilfelle | Hastigheter | Netto |
# |---|---|---|
# | Forover spontan | $v_\text{forover} \gg v_\text{bakover}$ | mot $B$ |
# | Bakover spontan | $v_\text{bakover} \gg v_\text{forover}$ | mot $A$ |
# | Likevekt | $v_\text{forover} = v_\text{bakover}$ | ingen netto endring |
#
# Ved likevekt går reaksjonen fortsatt begge veier, like fort. Så konsentrasjonene står stille (dynamisk likevekt).
#
# **b)** Reaksjonskvotienten $Q$
#
# $$Q = \frac{[B]}{[A]} \quad\text{(eventuelt med partialtrykk eller aktiviteter)}$$
#
# $Q$ er forholdet mellom produkt og reaktant på et gitt tidspunkt. Ved å sammenligne $Q$ med $K$ ser man hvilken vei reaksjonen går:
#
# - $Q < K \;\Rightarrow\;$ netto forover
# - $Q > K \;\Rightarrow\;$ netto bakover
# - $Q = K \;\Rightarrow\;$ likevekt
#
# **c)** Molekylær tolkning av $K$
#
# Likevektskonstanten kan skrives som et produkt av to faktorer:
#
# $$K = \underbrace{e^{-\Delta_r H / RT}}_{\text{entalpi-faktor}} \cdot \underbrace{e^{\Delta_r S / R}}_{\text{entropi-faktor}}$$
#
# - Entalpi-faktoren trekker mot siden med lavest energi.
# - Entropi-faktoren trekker mot siden med flest tilgjengelige (tett-liggende) energinivåer, altså flest mikrotilstander.
#
# I begge grafene ligger energinivåene til $B$ høyere enn til $A$, så reaksjonen $A \to B$ er endoterm: $\Delta_r H > 0$. Det gjør entalpi-faktoren $< 1$, slik at den favoriserer $A$. Da er det entropien(nivåtettheten) som avgjør utfallet.
#
# *Graf (a): $A$ dominerer*
#
# $A$ og $B$ har omtrent samme avstand mellom energinivåene → omtrent lik nivåtetthet → $\Delta_r S \approx 0$. Entropi-faktoren blir $\approx 1$ og gir ingen hjelp til $B$.
#
# Entalpi-faktoren vinner:
#
# $$\Delta_r H > 0,\quad \Delta_r S \approx 0 \;\Rightarrow\; \Delta_r G^\circ > 0 \;\Rightarrow\; K < 1$$
#
# Likevekten er forskjøvet mot reaktanten $A$, og reaksjonen mot $B$ er ikke-spontan.
#
# *Graf (b): $B$ dominerer*
#
# $B$ har mye **tettere** energinivåer enn $A$ → mange flere tilgjengelige mikrotilstander for $B$ → stor positiv $\Delta_r S$. Entropi-faktoren blir så stor at den overgår den ugunstige entalpien:
#
# $$\Delta_r H > 0,\quad \Delta_r S \gg 0 \;\Rightarrow\; \Delta_r G^\circ < 0 \;\Rightarrow\; K > 1$$
#
# Selv om reaksjonen er endoterm, blir $B$ det dominerende molekylet ved likevekt, fordi entropien vinner.
#
# Kort oppsummert
#
# | Graf | Nivåtetthet | $\Delta_r S$ | Hvem vinner | Dominerer |
# |:---:|---|:---:|---|:---:|
# | (a) | lik for $A$ og $B$ | $\approx 0$ | entalpi | $A$ |
# | (b) | mye høyere for $B$ | $\gg 0$ | entropi | $B$ |

# %% [markdown]
# ## Uke 10 - Kinetikk
