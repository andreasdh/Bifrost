# %% [markdown]
# # Løsningsforslag

# %% [markdown]
# Velg uke i menyen til venstre, eller bruk lenkene nedenfor.
#
# 1. {doc}`Uke 1 – Statistisk mekanikk og mikro–makro-sammenhengen <losningsforslag/uke_01>`
# 2. {doc}`Uke 2 – Statistisk mekanikk, energi, entropi og temperatur <losningsforslag/uke_02>`
# 3. {doc}`Uke 3 – Kinetisk gassteori <losningsforslag/uke_03>`
# 4. {doc}`Uke 4 – Makroskopisk termodynamikk <losningsforslag/uke_04>`
# 5. {doc}`Uke 5 – Makroskopisk termodynamikk – del 2 <losningsforslag/uke_05>`
# 6. {doc}`Uke 6 – Intermolekylære interaksjoner <losningsforslag/uke_06>`
# 7. {doc}`Uke 7 – Termokjemi <losningsforslag/uke_07>`
# 8. {doc}`Uke 8 – Faseoverganger <losningsforslag/uke_08>`
# 9. {doc}`Uke 9 – Løsninger og blandinger <losningsforslag/uke_09>`
# 10. {doc}`Uke 10 – Likevekt <losningsforslag/uke_10>`
# 11. {doc}`Uke 11 – Kinetikk <losningsforslag/uke_11>`
