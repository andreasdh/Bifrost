# %% [markdown]
# # Nyttige matematiske verktøy

# %% [markdown]
# :::{admonition} Innholdsoversikt
# :class: note
#
# 1. FYLL INN
# 2. FYLL INN
# :::

# %% [markdown]
# ## Sannsynlighet

# %% [markdown]
# **Utfall**
# Et utfall $i$ er et mulig resultat i et eksperiment.
#
# **Utfallsrom**
# Utfallsrommet $S$ er mengden av alle mulige utfall i et eksperiment.
#
# **Hendelse**
# En hendelse $A$ er delmengde av utfallsrommet, altså ett eller flere utfall vi er interessert i.

# %% [markdown]
# _Eksempel: Anta at eksperimentet ditt er ett kast av en likevektet, sekssidet terning. De mulige utfallene for eksperimentet er $1,2,3,4,5$ eller $6$, slik at utfallsrommet er $S=\{1,2,3,4,5,6\}$. Et eksempel på en hendelse i dette eksperimentet er å trille et partall. Betegner vi hendelsen ved $A$, har vi at $A=\{2,4,6\}$._

# %% [markdown]
# ### Grunnleggende aksiomer

# %% [markdown]
# Anta at vi har et eksperiment med utfallsrom $S$. La $i \in S$ være et utfall, og la $P(i)$ være sannsynligheten for $i$. Da må $P(i)$ oppfylle følgende:

# %% [markdown]
# \begin{align*}
# 0 \leq P(i) \leq 1
# \end{align*}

# %% [markdown]
# \begin{align*}
# \sum_{i} P(i) =1
# \end{align*}

# %% [markdown]
# _Intuisjon: Hvert utfall $i$ har en sannsynlighet mellom $0$ og $1$_

# %% [markdown]
# ### Uavhengighet

# %% [markdown]
# \begin{align*}
# P(A,B) = P(A) \cdot P(B)
# \end{align*}

# %% [markdown]
# ## Kombinatorikk

# %% [markdown]
# ### OG-regelen

# %% [markdown]
# :::{admonition} OG-regelen
# :class: important
#
# Anta hendelse $A$  kan skje på $m$ måter og at hendelse $B$ kan skje uavhengig på $n$ måter. Da er antallet måter $A$ OG $B$ kan skje lik $m \cdot n$.
# :::

# %% [markdown]
# ### ELLER-regelen

# %% [markdown]
# :::{admonition} ELLER-regelen
# :class: important
#
# Anta at en hendelse $A$ kan skje på $m$ ulike måter, og hendelse $B$ kan skje på $n$ måter. Anta også at hendelsene er disjunkte. Da kan hendelse $A$ ELLER $B$ skje på $m + n$ måter.
# :::

# %% [markdown]
# _Eksempel: Johan har 5 hatter og 3 solbriller. Antall måter å velge én hatt og et par solbriller blir dermed $5 \cdot 3=15$, mens antall måter å velge enten en hatt eller et par briller blir $5+3=8$._

# %% [markdown]
# ### Fakultet

# %% [markdown]
# Hvor mange måter kan vi ordne $n$ forskjellige objekter i en rekke? Intuitivt vet vi at ved plass 1 i rekken, så har vi $n$ mulige valg av objekter. Deretter, på plass 2, har vi ett valg mindre, altså $n-1$ mulige valg av objekter. Slik følger det, til vi på plass $n$ kun har 1 valg igjen av objekt. Det er nettopp dette fakultet beskriver:

# %% [markdown]
# :::{admonition} Fakultet
# :class: important
#
# Antallet måter å ordne $n$ ulike objekter i en rekke er gitt ved
#
# \begin{align*}
# n! = n \cdot (n-1) \cdot (n-2) \cdot \dots \cdot 1
# \end{align*}
# :::

# %% [markdown]
# _Eksempel: På hvor mange måter kan du ordne bokstavene i ordet "TRE"? Skriver du opp alle ordningene, får du TRE, TER, RET, RTE, ETR og ERT. Samme antall ordninger får du ved $3!=3\cdot2\cdot1$._
